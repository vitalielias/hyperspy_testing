# %% [markdown]
# # Hyperspy as an automatic metadata extractor
#
# With this notebook, I'd like to assess whether or not the Hyperspy library may be implemented to assist the automatic metadata extraction from SEM and TEM research images and data, in order to more efficiently extract metadata from them. The advantage with using this package, is that it uses its own native schema such that the extracted metadata is already structured in a more or less standardized format. While this schema is useless to us, it does allow us to bypass creating a different map for nearly every single instrument as the input to the mapping service will always be in the same format.

# %% [markdown]
# ### Load the required packages

# %%
import hyperspy.api as hs
import json
import os

# %% [markdown]
# Load a folder of test images to see how each reacts to the automatic data extraction

# %%
def getImages(folder_path):
    tiff_images_list = []
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path) and filename.lower().endswith('.tif'):
            tiff_images_list.append(os.path.join(folder_path, filename))
    return tiff_images_list

testFolder = '/Users/elias/Desktop/MatWerk_Projects/testImages'

images = getImages(testFolder)
images
# Out:
# ['/Users/elias/Desktop/MatWerk_Projects/testImages/Na3FePO43 -04-Zeiss IAM-ESS.tif',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/Nozzle Chip RIE KOH10 Zeiss EVO IMT.tif',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/NK_PA07_1-4_KA-W 136980-Zeiss-IAM ESS.tif',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/Au-Gr_06.tif',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/SEM_image_sample_Thermo_Fisher_Helios_G4_PFIB_CXe.tif',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/SEM_image_sample_FEI_Helios_Nanolab600.tif',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/SEM Image 2 - SliceImage - 001.tif']

# %% [markdown]
# # Na3FePO43 -04-Zeiss IAM-ESS.tif
#
# Zeiss Merlin Instrument

# %%
f = hs.load(images[0])

# %%
Zeiss_Merlin = f.original_metadata.as_dictionary()

del Zeiss_Merlin['ColorMap']
del Zeiss_Merlin['34119']

Zeiss_EVO
# Out:
# {'NewSubfileType': <FILETYPE.UNDEFINED: 0>,
#  'ImageWidth': 1024,
#  'ImageLength': 768,
#  'BitsPerSample': 8,
#  'Compression': <COMPRESSION.NONE: 1>,
#  'PhotometricInterpretation': <PHOTOMETRIC.PALETTE: 3>,
#  'StripOffsets': (103823,),
#  'Orientation': <ORIENTATION.TOPLEFT: 1>,
#  'SamplesPerPixel': 1,
#  'RowsPerStrip': 4294967295,
#  'StripByteCounts': (786432,),
#  'XResolution': (1, 1),
#  'YResolution': (1, 1),
#  'ResolutionUnit': <RESUNIT.NONE: 1>,
#  'SampleFormat': <SAMPLEFORMAT.UINT: 1>,
#  'CZ_SEM': {'': (0,
#    0,
#    0,
#    5.705307e-07,
#    195.695,
#    6,
#    10000.0,
#    3.294,
#    5e-10,
#    0.00953088,
#    1,
#    5.705307e-07,
#    195.695,
#    6,
#    10000.0,
#    3.294,
#    5e-10,
#    0.00953088,
#    2,
#    5.705307e-07,
#    195.695,
#    6,
#    10000.0,
#    3.294,
#    5e-10,
#    0.00953088,
#    3,
#    5.705307e-07,
#    195.695,
#    6,
#    10000.0,
#    3.294,
#    5e-10,
#    0.00953088,
#    799),
#   'dp_vent_invalid_reason': ('Vent inhibit', 'Beam Present'),
#   'dp_optimode': ('OptiBeam Mode', 'Analysis'),
#   'dp_fixed_aperture': ('VP Aperture', False),
#   'dp_bsd_autolevel_mode': ('BSD Autolevel Mode', 'Normal'),
#   'dp_recipe': ('Recipe', 'Idle'),
#   'dp_implied_detector': ('Signal B', 'SE1'),
#   'dp_4qbsd_visible': ('BSD Fast', False),
#   'dp_opt_aperture': ('Opt.Aperture', 2),
#   'dp_track_z': ('Track Z', False),
#   'dp_epse_electrode': ('EPSE Electrode', 'Ring'),
#   'dp_c3_rot_correction': ('C3 Rot Corrn.', True),
#   'dp_fisheye_mode': ('Fisheye Mode', False),
#   'dp_stage_tilted': ('Stage Tilt', 'In Y'),
#   'dp_ccd_mode_actual': ('CCD Mode Actual', 'Greyscale'),
#   'dp_ar_gun': ('Argon Gun', 'Absent'),
#   'dp_column_isolated': ('Column Isolated', False),
#   'dp_mixing': ('Mixing', False),
#   'dp_fib_fg_mode_target': ('Flood Gun Mode Target', 'Low Energy Mode'),
#   'dp_stem_gain': ('STEM Gain', 'Low'),
#   'dp_high_current': ('High Current', False),
#   'dp_dwell_time': ('Dwell Time', 50, 'ns'),
#   'dp_si_noise_reduction': ('SmartImage Noise Reduction', False),
#   'dp_right_frozen': ('Right Frozen', False),
#   'dp_fib_fg_blanked': ('Flood Gun Blanked', False),
#   'dp_fast_mode': ('Fast Mode', False),
#   'dp_compucentric_mode': ('Compuc. Mode', False),
#   'dp_anode_aperture_changer': ('Anode Aperture Changer', 'Absent'),
#   'dp_gis_shutdown_state': ('GIS Shutdown State', 'Normal'),
#   'dp_smartfib_api_status': ('SmartFIB Command Status', 'Idle'),
#   'dp_fib_column': ('FIB Column', 'None'),
#   'dp_tilted': ('Stage Tilted', True),
#   'dp_fib_suppressor': ('FIB Suppressor is', 'Absent'),
#   'dp_vpse': ('VPSE detector', 'Absent'),
#   'dp_crosshairs': ('Crosshairs', False),
#   'dp_double_deflection_state': ('Double Deflection State', 'Both On'),
#   'dp_gate_valve_position': ('WDX Gate Valve posn', 'OK'),
#   'dp_hese2_fitted': ('HE-SE2 Fitted', False),
#   'dp_ep_mode': ('EP Gas', 'Air'),
#   'dp_condenser': ('Condenser Normal', 'Normal'),
#   'dp_implied_invert': ('Invert B', False),
#   'dp_4qbsd_gain': ('BSD Gain', 'High'),
#   'dp_fib_gun_valve': ('FIB Gun Valve', 'Closed'),
#   'dp_aperture_state': ('Aperture', 'Clean'),
#   'dp_electron_counting': ('Electron Counting', False),
#   'dp_saturate_at': ('Saturate at', 'Second peak'),
#   'dp_stage_angle': ('Stage Angle corrn.', True),
#   'dp_image_store': ('Store resolution', '1024 * 768'),
#   'dp_field_mode': ('Field Mode', False),
#   'dp_coolstage_type': ('CoolStage Type', 'Cold'),
#   'dp_best_aperture': ('Best Aperture', True),
#   'dp_fib_fg_mode_actual': ('Flood Gun Actual Mode', 'Low Energy Mode'),
#   'dp_stem_auto': ('STEM Auto', False),
#   'dp_stage_init': ('Stage Initialised', True),
#   'dp_cc_on_gis_channel': ('GIS Channel with CC', 'None'),
#   'dp_channel': ('Display', 0),
#   'dp_fib_fg_fitted': ('Flood Gun Fitted', False),
#   'dp_bsd_layout': ('BSD LAYOUT', 'Four Segment Layout'),
#   'dp_bsd_mode': ('BSD Mode', 'User'),
#   'dp_fib_mode': ('FIB Mode', 'Imaging'),
#   'dp_nano_tips': ('Nano Tips', 'Absent'),
#   'dp_bsd_n_on_p': ('BSD Invert', False),
#   'dp_mgs_evac_state': ('MGS Evacuation State', False),
#   'dp_use_epd': ('Use End Point Detection', False),
#   'dp_mains_sync': ('Mains Sync', 'Single Edge'),
#   'dp_fib_pneumatic_prep_state': ('FIB preparation for pneumatic',
#    'FIB ready for system vent'),
#   'dp_mouse_adjust_disable': ('Mouse Adjust Disable', False),
#   'dp_frozen': ('Image', 'Live'),
#   'dp_filament_type': ('Filament Type', 'W (Agar A054-L)'),
#   'dp_autofocus_version': ('Autofocus Version',
#    'Line Scan based Autofocus Version'),
#   'dp_sample_holder': ('Sample Holder', 'Carousel 9x9mm'),
#   'dp_high_resolution_mode': ('High Resolution Mode', False),
#   'dp_fib_scan': ('FIB Scan', 'Continuous'),
#   'dp_beam_blanked': ('Beam Blanked', False),
#   'dp_cc_type': ('CC Type', 'None'),
#   'dp_4qbsd': ('BSD', 'Absent'),
#   'dp_image_saved': ('Image saved', True),
#   'dp_gis_location': ('GIS Location', 'Unknown'),
#   'dp_mag_range': ('Mag Range', 2),
#   'dp_user_align': ('User Align', True),
#   'dp_zone': ('Zone', 0),
#   'dp_fil_blown': ('Filament blown', False),
#   'dp_humidity_valve': ('Humidity Valve', 'Closed'),
#   'dp_fib_external_polarity': ('FIB External Polarity', 0),
#   'dp_peltier_photo': ('Peltier Photo', False),
#   'dp_main_detector': ('Control', 'Signal A'),
#   'dp_invert': ('Invert A', False),
#   'dp_fib_fg_remoting_target': ('Remoting Target', 'Flood Gun Normal'),
#   'dp_stage_is': ('Stage Is', 'Idle'),
#   'dp_fib_present': ('FIB Present', False),
#   'dp_peltier_type': ('Peltier Type', 'Deben'),
#   'dp_signalaz0': ('Signal A Z0', 'SE1'),
#   'dp_freeze_on': ('Freeze on', 'End Frame'),
#   'dp_fib_blanked': ('FIB Blanked', False),
#   'dp_stage_bias_high': ('Beam deceleration', False),
#   'dp_epse_gain': ('EPSE Gain', 'Low'),
#   'dp_end_detection': ('End Detection', False),
#   'dp_vac_comms_fail': ('Vac comms fail', False),
#   'dp_bsd_auto': ('BSD Auto Range', True),
#   'dp_pneumatic_device_in_use': ('Pneumatic Device in use', 'None'),
#   'dp_fib_wide_view': ('FIB Wide View', False),
#   'dp_anode': ('Anode Spacer', 'High KV'),
#   'dp_use_ref_mag': ('Reference Mag', 'Polaroid 545'),
#   'dp_beamsleeve_position': ('Beam sleeve', 'Out'),
#   'dp_user_mag_cal': ('User Calibration', False),
#   'dp_safe_stem_valid': ('Safe STEM Valid', False),
#   'dp_4qbsd_q5': ('S5', False),
#   'dp_scd_gain': ('SCD Gain', 'Low'),
#   'dp_all_zones': ('All Zones', False),
#   'dp_detector_channel': ('Signal A', 'SE1'),
#   'dp_eht_tripped': ('EHT tripped', False),
#   'dp_flood_state': ('Flood State', 'Idle'),
#   'dp_extractor_trip': ('Extractor Trip', False),
#   'dp_bsd_fast_scan': ('BSD Fast Scan', False),
#   'dp_inlens_duo_mode': ('InlensDuo Mode', 'SE'),
#   'dp_auto_video': ('Auto BC', False),
#   'dp_fib_fg_remoting_actual': ('Flood Gun Remoting Actual',
#    'Flood Gun Normal'),
#   'dp_signalaz1': ('Signal A Z1', 'SE1'),
#   'dp_stage_bias_hv_fitted': ('Variable stage bias fitted', False),
#   'dp_epse_auto': ('EPSE Auto Range', False),
#   'dp_stage_comms_fail': ('Stage comms fail', False),
#   'dp_optiprobe': ('OptiProbe', False),
#   'dp_cls_valve': ('C.L.S.Valve', 'Closed'),
#   'dp_newfilament': ('New Filament', False),
#   'dp_image_detect': ('Image Detect', 'Black'),
#   'dp_custom_holder': ('Custom Holder', False),
#   'dp_gis_interlock_status': ('GIS Interlock status', 'Cartesian'),
#   'dp_zoom': ('Zoom', False),
#   'dp_deconvolution_state': ('Deconvolution State', 'Idle'),
#   'dp_scd_auto': ('SCD Auto Range', False),
#   'dp_ext_scan_control': ('Ext.Scan Control', False),
#   'dp_detector_type': ('Detector', 'SE1'),
#   'dp_eht_reset': ('EHT spurious reset', False),
#   'dp_stem_q4': ('STEM Q4', False),
#   'dp_fib_fg_extractor_target': ('Extractor Target State', False),
#   'dp_gemini_large_beamshift': ('Gemini large beam shift', False),
#   'dp_jazz_gain': ('Jazz Gain', 'Low'),
#   'dp_monitor': ('Monitor', '19/21 inch'),
#   'dp_freeze_status': ('Freeze', 'Idle'),
#   'dp_fib_extractor_conflict': ('FIB Extractor Conflict', False),
#   'dp_stage_bias_carassel_fitted': ('Beam deceleration carousel', False),
#   'dp_epse_bandwidth': ('EPSE Bandwidth', 'DC'),
#   'dp_stage_bias': ('Stage bias low voltage', False),
#   'dp_stigbalance': ('Stig Balance', False),
#   'dp_gis_interlock_present': ('GIS Interlock available', False),
#   'dp_frame_grabber': ('Frame Grabber', 'ASAP'),
#   'dp_fib_ext_scan_select': ('FIB Ext Scan Select', 'Ext 0'),
#   'dp_beamsleeve_fitted': ('Beam sleeve fitted', False),
#   'dp_vpse2': ('VPSE-G3 Fitted', 'Absent'),
#   'dp_4qbsd_q1': ('S1', False),
#   'dp_fib_lock_mag': ('FIB Lock Mags', False),
#   'dp_freeze_blanks': ('Freeze Blanks', True),
#   'dp_windowing': ('Windowing', False),
#   'dp_partial_vent': ('Partial Vent on Standby', False),
#   'dp_scd_bandwidth': ('SCD Bandwidth', 'DC'),
#   'dp_calibration': ('Calibration', 'Disabled'),
#   'dp_stem_q1': ('STEM Q1', False),
#   'dp_eht_vac_ready': ('EHT Vac ready', True),
#   'dp_deconvolution_expert_mode': ('Deconvolution expert mode', False),
#   'dp_stem_q5': ('STEM Q5', False),
#   'dp_fib_fg_extractor_actual': ('Flood Gun Extractor Actual State', False),
#   'dp_bakeout_full': ('full service bakeout', False),
#   'dp_water_ok': ('Water OK', True),
#   'dp_low_mag': ('Low Mag', False),
#   'dp_vent_inhibited': ('Venting inhibited', True),
#   'dp_fib_probe': ('FIB Probe', 'Undefined'),
#   'dp_lut_mode': ('Display LUT mode', 'Normal'),
#   'dp_optibeam': ('OptiBeam Is', True),
#   'dp_4qbsd_q6': ('S6', False),
#   'dp_scangen_type': ('ScanGen Type', 'ASAP'),
#   'dp_fib_ext_scan_mode': ('FIB Ext Scan Mode', False),
#   'dp_final_lens': ('Final Lens', 'EVO: 80 deg'),
#   'dp_ehtcommsfail': ('EHT Comms Fail', False),
#   'dp_scangen': ('Scan Gen', 'Present'),
#   'dp_num_regions': ('Num. Regions', 0),
#   'dp_fib_error': ('FIB Error', 'None'),
#   'dp_gis_heating_status_1': ('GIS Heating Status Channel 1',
#    'GIS Not Heating'),
#   'dp_quattro_bandwidth': ('BSD Bandwidth', 'DC'),
#   'dp_4qbsd_q2': ('S2', False),
#   'dp_dynfocus': ('Dyn.Focus', False),
#   'dp_supervisor': ('Supervisor', 'Enabled'),
#   'dp_colour_mode': ('Colour Mode', False),
#   'dp_tilt_correction': ('Tilt Corrn.', False),
#   'dp_spot': ('Spot', False),
#   'dp_fixed_aperture2': ('EP Aperture', 'None fitted'),
#   'dp_detector_fast_scan': ('Noise reduction for fast scanspeeds', False),
#   'dp_ion_detector_mode': ('SESI Mode', 'SE'),
#   'dp_fisheye_fitted': ('Fish-Eye Fitted', False),
#   'dp_stem_q2': ('STEM Q2', False),
#   'dp_pixel_size': ('Pix Size state', 'calibrated'),
#   'dp_ebbu_mode': ('Beam Blanker Mode', 'Blanked'),
#   'dp_fib_image_probe': ('FIB Image Probe', 'Undefined'),
#   'dp_fib_large_area_patterning': ('FIB Large Area Patterning', False),
#   'dp_ar_mill': ('Argon Mill', False),
#   'dp_fib_mag_range': ('FIB Mag Range', 0),
#   'dp_user_level': ('User Level', 'Full'),
#   'dp_ar_scan': ('Argon Scan', False),
#   'dp_hp_status': ('Chamber Status', 'Power Up'),
#   'dp_column_type': ('Column', 'EVO'),
#   'dp_large_beamshift': ('Large Beam Shift', False),
#   'dp_ar_mfcvalve': ('Argon MFC Valve', 'Closed'),
#   'dp_contrast_enhancement': ('Contrast Enhanced', False),
#   'dp_4qbsd_q3': ('S3', False),
#   'dp_scan_rot': ('Scan Rot', True),
#   'dp_dc_sem_state': ('Sem drift status', 'Not Available'),
#   'dp_line_scan': ('Line Scan', False),
#   'dp_use_small_crosshair': ('Use small crosshair', False),
#   'dp_tandem_deceleration': ('Tandem deceleration', False),
#   'dp_signalaz2': ('Signal A Z2', 'SE1'),
#   'dp_scm_range': ('SCM range', '3->10 pA'),
#   'dp_fib_fg_floodgun_type': ('Flood Gun Type', 'Flood Gun Unknown Type'),
#   'dp_stem_q3': ('STEM Q3', False),
#   'dp_mag_cal': ('Mag State', 'calibrated'),
#   'dp_hv_at_shutdown': ('Go to HV @ Shutdown', False),
#   'dp_scm_status': ('SCM Status', False),
#   'dp_si_source': ('SI source-hidden', 0),
#   'dp_conjugate': ('OptiBeam conjugate', False),
#   'dp_fib_fg_status': ('Flood Gun Status', False),
#   'dp_boost_mode': ('Boost Mode', False),
#   'dp_vp_optibeam': ('VP Optibeam', False),
#   'dp_condenser_reversed': ('Condenser Reversed', False),
#   'dp_z0': ('Zone 0', 'Live'),
#   'dp_fib_mill_probe': ('FIB Milling Probe', 'Undefined'),
#   'dp_scint': ('Scint.', True),
#   'dp_optiresmode': ('OptiBeam Res Mode', 'manual'),
#   'dp_jazz_bandwidth': ('Jazz Bandwidth', 'Low'),
#   'dp_igp_enabled': ('IGP Enabled', False),
#   'dp_gate_valve': ('WDX Gate valve', 'Closed'),
#   'dp_peltier': ('Peltier', False),
#   'dp_output_reduction': ('Output Reduction', 1),
#   'dp_4qbsd_q4': ('S4', False),
#   'dp_aperture': ('Aperture No.', 2),
#   'dp_stage_bias_mode': ('Stage bias mode', 'contrast mode'),
#   'dp_sem': ('Sem', 'EVO 10'),
#   'dp_scan_orthog': ('Scan Orthog', True),
#   'dp_display_channels': ('Channels', 1),
#   'dp_dual_monitor': ('Dual Monitor', False),
#   'dp_signalaz3': ('Signal A Z3', 'SE1'),
#   'dp_c3_rot_sign': ('C3 Rotn Sign', '+'),
#   'dp_stem_fast': ('STEM Fast', False),
#   'dp_out_dev': ('Output dev', '19/21 inch display'),
#   'dp_user': ('User', 'Idle'),
#   'dp_fib_track_wd': ('FIB Tracking WD', False),
#   'dp_fib_fg_interlock': ('Flood Gun Interlock', False),
#   'dp_low_kv_lens': ('Low KV Lens', 'Absent'),
#   'dp_z1': ('Zone 1', 'Live'),
#   'dp_cc_status': ('CC Status', False),
#   'dp_fib_gun_state': ('FIB Gun State', False),
#   'dp_ar_gun_state': ('Argon Gun is', False),
#   'dp_out_type': ('Output To', 'Display/File'),
#   'dp_column_chamber_valve': ('Column Chamber valve', 'Open'),
#   'dp_column_pumping': ('Column pumping', 'Idle'),
#   'dp_scanrate': ('Scan Speed', 3),
#   'dp_left_frozen': ('All Frozen', False),
#   'dp_input_lut_mode': ('Input LUT Mode', 'Transparent'),
#   'dp_operating_mode': ('Operating Mode', 'Normal'),
#   'dp_gis_channel': ('GIS Channel', 'None'),
#   'dp_fib_imaging': ('FIB Imaging', 'SEM'),
#   'dp_c3reversal': ('C3 Reversal', 'Normal'),
#   'dp_vac_mode': ('Vacuum Mode', 'High Vacuum'),
#   'dp_column_mode': ('Column Mode', 'High Resolution'),
#   'dp_stem_seg_mode': ('STEM Seg. Mode', False),
#   'dp_calmode': ('Cal Mode', False),
#   'dp_runupstate': ('Beam State', 'Beam On'),
#   'dp_noise_reduction': ('Noise Reduction', 'Line Avg'),
#   'dp_optibeam_state': ('OptiBeam', 'Analysis'),
#   'dp_vacstatus': ('Vac Status', 'Ready'),
#   'ap_fib_fg_emission_target': ('Flood Gun Emission target', 0.0, 'µA'),
#   'ap_fib_shift_correction_y': ('FIB Shift Correction Y', 0.0, 'nm'),
#   'ap_mag': ('Mag', 196, 'X'),
#   'ap_line_time': ('Line Time', 33.59, 'ms'),
#   'ap_fib_mag_fine_gain_y': ('FIB Mag fine gain Y', 0.0),
#   'ap_spot_posn_y': ('Spot at Y', 192),
#   'ap_scanorthog_lower': ('Orthogonality Lower', 0.0, '°'),
#   'ap_angular_3': ('Aa 4', 0.0, 'kV'),
#   'ap_stage_vector_x': ('Stage vector X', 0.0, '%'),
#   'ap_detector_bandwidth_offset': ('Det BW Offset', 0),
#   'ap_ar_condenser': ('Argon Condenser', 0, 'V'),
#   'ap_aperture_at_fisheye_x': ('Aperture value at FishEye X', 0.0, '%'),
#   'ap_minmag': ('Min Mag', 17, 'X'),
#   'ap_stage_goto_r': ('Stage goto R', 0.0, '°'),
#   'ap_asap_dfe4_minus5v_analogue': ('ASAP DFE4 Minus5V Analogue', 0.0, 'V'),
#   'ap_hp_target': ('VP Target', 30, 'Pa'),
#   'ap_eht_cal_100': ('EHT Cal@0.1KV', 100, 'V'),
#   'ap_ppa_6': ('Pa 7', 0.0, 'nm'),
#   'ap_v_3': ('V 4', 0.0, 'nm'),
#   'ap_stage_delta_r': ('Stage Delta R', 0.0, '°'),
#   'ap_file_number': ('File No', 464),
#   'ap_esd_lower_y': ('ESD Lower Y', 0.0, '%'),
#   'ap_free_wd': ('Free WD', 9.53, 'mm'),
#   'ap_brightnessz3': ('Brightness D', 57.1, '%'),
#   'ap_fm_quadriture': ('Field Mode Quadriture', 1030),
#   'ap_tilt_angle': ('Tilt Angle', 45.0, '°'),
#   'ap_mill_list_elapsed_time': ('Mill List Elapsed Time', 0, 'ms'),
#   'ap_stig_x': ('Stigmation X', -9.5, '%'),
#   'ap_ppb_2': ('Pb 3', 0.0, '°'),
#   'ap_magcal_upper_y': ('Calibrate Mag Upper Y', 0.0),
#   'ap_radial_1': ('Da 2', 0.0, 'nm'),
#   'ap_reduced_raster_width': ('Reduced Raster Width', 512),
#   'ap_vpse2_bias': ('VPSE Bias', 60.0, '%'),
#   'ap_stage_low_z': ('Stage low Z', 0.0, 'mm'),
#   'ap_ar_mag': ('Argon Magnification', 0, 'X'),
#   'ap_ar_shift_ratio_y': ('Argon Shift Ratio Y', 0.0),
#   'ap_scan_offset_x': ('Scan X cal.', 0),
#   'ap_asap_dfe2_plus5v_analogue': ('ASAP DFE2 Plus5V Analogue', 5.1, 'V'),
#   'ap_stage_high_t': ('Stage high T', 90.0, '°'),
#   'ap_profile_top': ('Profile Top', 300),
#   'ap_mag_gain_x': ('Mag Gain Cal X', 878.0),
#   'ap_h_7': ('H 8', 0.0, 'nm'),
#   'ap_spacer_thickness': ('Spacer Thickness', 0.0, 'mm'),
#   'ap_stage_high_r': ('Stage high R', 380.0, '°'),
#   'ap_fib_condenser': ('FIB Condenser', 0, 'V'),
#   'ap_fib_fg_fil_current_target': ('Flood Gun Filament Target', 0, 'µA'),
#   'ap_dc_shift_x': ('Aperture Align X', 16.3, '%'),
#   'ap_sem_level_at_tilt': ('SEM Level @', 0.0, '°'),
#   'ap_vac_ready_at': ('Vac Ready @', 0.00013, 'mbar'),
#   'ap_c1rem': ('C1 Rem', -0.0011),
#   'ap_fib_slice_width': ('Slice Width', 0.0, 'nm'),
#   'ap_beamshift_y': ('Beam Shift Y', 0.0, '%'),
#   'ap_ppa_0': ('Pa 1', 0.0, 'nm'),
#   'ap_deconvolution_sigma': ('Deconvolution Sigma', 0.0),
#   'ap_tilt_align_x': ('Tilt Align X', 0.0, '%'),
#   'ap_stage_xm_r': ('Stage X+M Rotation', 0.0, '°'),
#   'ap_si_topography': ('SmartImage Topography', 10.0, '%'),
#   'ap_stage_at_field_y': ('Stage at field Y', 1),
#   'ap_ar_angle': ('Argon Column Angle', 0.0, '°'),
#   'ap_asap_dfe3_temperature': ('ASAP DFE3 Temperature', 0.0, '°C'),
#   'ap_test_n': ('Test No.', 0),
#   'ap_h_1': ('H 2', 0.0, 'nm'),
#   'ap_radial_area_0': ('Db 1', 0.0, 'nm²'),
#   'ap_opt_semiangle': ('Opt. Semi Angle', 5.739, 'mrad'),
#   'ap_fib_aperture_align_x': ('FIB Aper.Align X', 0),
#   'ap_fib_fil_i_target': ('FIB Fil I Target', 0, 'µA'),
#   'ap_dc_max_pix_error': ('Drift Max.Pix.Error', 1),
#   'ap_inlens_duo_grid_actual': ('InlensDuo Grid is', 0, 'V'),
#   'ap_fisheye_angle': ('Fisheye Angle', 180.0, '°'),
#   'ap_magcaly': ('Mag Cal Y scale', 1.295),
#   'ap_contrastz0': ('Contrast A', 21.9, '%'),
#   'ap_dual_mag_offset_y': ('Dual Mag Offset Y', 0.0),
#   'ap_mag_decl': ('Mag scaling decel', 1.0),
#   'ap_mag_gain_upper_x': ('Shift Amp Upper Gain X', 0.0),
#   'ap_holder_length': ('Holder Length', 0.0, 'mm'),
#   'ap_stage_fields_y': ('Stage fields Y', 1),
#   'ap_fib_source_lifetime': ('FIB Source lifetime', 0.0, 'µAh'),
#   'ap_ar_gas_flow_actual': ('Argon Gas Flow is', 0.0, '%'),
#   'ap_gain': ('Gain A', 100.0, '%'),
#   'ap_beam_blank_gun_y': ('Beam Blanked Gun Pos Y', 100.0, '%'),
#   'ap_conjugate': ('Conjugate posn.', -164.0, 'mm'),
#   'ap_asap_scan_offset_y': ('Scan Offset Y', 0),
#   'ap_mag_shift_x': ('Mag Shift Cal X', -10.0),
#   'ap_jazz_back_grid': ('Back Grid', 0, 'V'),
#   'ap_actualsupp': ('Suppressor V', 0, 'V'),
#   'ap_aperture_align_x': ('Aperture Align X', 0.0, '%'),
#   'ap_ppb_5': ('Pb 6', 0.0, '°'),
#   'ap_v_8': ('V 9', 0.0, 'nm'),
#   'ap_prof2_x2': ('Profile 2 X2', 0),
#   'ap_fib_magnification': ('FIB Mag', 0, 'X'),
#   'ap_fib_fg_emission_actual': ('Flood Gun Emission Actual', 0.0, 'µA'),
#   'ap_fib_shift_correction_x': ('FIB Shift Correction X', 0.0, 'nm'),
#   'ap_iprobe': ('I Probe', 500, 'pA'),
#   'ap_fcf_tilt': ('FCF Tilt Angle', 0.0, '°'),
#   'ap_fib_mag_fine_gain_x': ('FIB Mag fine gain X', 0.0),
#   'ap_stage_xm_angle': ('Stage X+M Angle', 8.0, '°'),
#   'ap_spot_posn_x': ('Spot at X', 256),
#   'ap_scanorthog_upper': ('Orthogonality Upper', 0.0, '°'),
#   'ap_angular_2': ('Aa 3', 0.0, 'kV'),
#   'ap_stage_goto_z': ('Stage goto Z', 0.0, 'mm'),
#   'ap_ar_discharge_current': ('Argon Discharge I is', 0.0, 'µA'),
#   'ap_gun_at_fisheye_y': ('Gun Value at FishEye mode Y', 0.0, '%'),
#   'ap_spotsize': ('Spot Size', 480),
#   'ap_asap_dfe3_minus5v_analogue': ('ASAP DFE3 Minus5V Analogue', 0.0, 'V'),
#   'ap_ppa_5': ('Pa 6', 0.0, 'nm'),
#   'ap_v_2': ('V 3', 0.0, 'nm'),
#   'ap_stage_delta_t': ('Stage Delta T', 0.0, '°'),
#   'ap_specimen_height': ('Specimen Height', 17, 'mm'),
#   'ap_esd_lower_x': ('ESD Lower X', 0.0, '%'),
#   'ap_fib_emission_current': ('FIB Emission I', 0.0, 'µA'),
#   'ap_fib_stig_y_centre_y': ('FIB Stig Y Centre Y', 0.0),
#   'ap_brightnessz2': ('Brightness C', 57.1, '%'),
#   'ap_fm_orthog': ('Field Mode Orthog', 358.0, '°'),
#   'ap_tilt_axis': ('Tilt Axis', 0.0, '°'),
#   'ap_mill_list_total_time': ('Mill List Total Time', 0, 'ms'),
#   'ap_apertureposn_y': ('Aperture Posn Y', 0.0, 'mm'),
#   'ap_ppb_1': ('Pb 2', 0.0, '°'),
#   'ap_magcal_upper_x': ('Calibrate Mag Upper X', 0.0),
#   'ap_radial_0': ('Da 1', 0.0, 'nm'),
#   'ap_epse_bias': ('EPSE Bias', 0.0, '%'),
#   'ap_profile_w': ('Profile width', 0.0, 'nm'),
#   'ap_stage_low_y': ('Stage low Y', 0.0, 'mm'),
#   'ap_ar_beam_shift_y': ('Argon Beam Shift Y', 0.0, 'nm'),
#   'ap_ar_shift_ratio_x': ('Argon Shift Ratio X', 0.0),
#   'ap_xtalk21': ('Xtalk21', 0.0473),
#   'ap_asap_dfe1_plus5v_analogue': ('ASAP DFE1 Plus5V Analogue', 0.0, 'V'),
#   'ap_min_ext': ('Min Extractor V', 3.0, 'kV'),
#   'ap_h_6': ('H 7', 0.0, 'nm'),
#   'ap_stage_centre_y': ('Stage Centre Y', 39.459, 'mm'),
#   'ap_beam_current_monitor': ('Beam I Monitor', 0.0, 'µA'),
#   'ap_fib_scan_size': ('FIB Scan Size', 0.0, 'nm'),
#   'ap_stig_cal_y': ('Stig. Cal Y', 0.0, '%'),
#   'ap_fib_ext_actual': ('FIB Extractor', 0.0, 'kV'),
#   'ap_fib_fg_energy_actual': ('Flood Gun Energy Actual', 0.0, 'V'),
#   'ap_fib_stig_x_centre_y': ('FIB Stig X Centre Y', 0.0),
#   'ap_piezo_goto_y': ('Piezo Goto Y', 0.0, 'µm'),
#   'ap_fib_tilt_comp': ('FIB Tilt Comp', 0.0, '°'),
#   'ap_c1cal': ('C1 Cal', 1.126),
#   'ap_fib_slice_y': ('Slice Y', 0.0, 'nm'),
#   'ap_beamshift_x': ('Beam Shift X', 0.0, '%'),
#   'ap_red_raster_h': ('Red.Raster Height', 384),
#   'ap_magcal_base': ('Calibrate Mag Base', 50000.0),
#   'ap_fib_nudge_step': ('FIB Nudge Step', 0.0, 'nm'),
#   'ap_piezo_exchange_y': ('Piezo Exchange Y', 0.0, 'µm'),
#   'ap_stage_at_field_x': ('Stage at field X', 1),
#   'ap_low_mag_focus': ('Low Mag Focus', 1.0),
#   'ap_ar_acc_i': ('Argon Acc I is', 0.0, 'µA'),
#   'ap_deconvolution_regularize': ('Deconvolution Smoothening', 0.0),
#   'ap_ar_mill_progress': ('Argon Mill Progress', 0.0, '%'),
#   'ap_asap_dfe2_temperature': ('ASAP DFE2 Temperature', 39.0, '°C'),
#   'ap_area_fraction': ('Area Fraction', 0.0, '%'),
#   'ap_nominalfil': ('Nominal Fil I', 2.0, 'A'),
#   'ap_gun_y': ('Gun at Y', 0.0, '%'),
#   'ap_stage_vector_m': ('Stage Vector M', 0.0, '%'),
#   'ap_h_0': ('H 1', 0.0, 'nm'),
#   'ap_semiangle': ('Semi Angle', 5.739, 'mrad'),
#   'ap_fib_scan_rotation': ('FIB Scan Rot', 0.0, '°'),
#   'ap_fib_fil_v': ('FIB Fil Voltage', 0.0, 'V'),
#   'ap_stageangle': ('Stage Angle', -11.2, '°'),
#   'ap_inlens_duo_grid': ('InlensDuo Grid', 0, 'V'),
#   'ap_manualcurrent': ('Fil I Target', 3.294, 'A'),
#   'ap_magcalx': ('Mag Cal X scale', 1.3),
#   'ap_brightnessz1': ('Brightness B', 57.1, '%'),
#   'ap_dual_mag_offset_x': ('Dual Mag Offset X', 0.0),
#   'ap_mag_shift_lower_y': ('Shift Amp Lower Offset Y', 0.0),
#   'ap_holder_width': ('Holder Width', 0.0, 'mm'),
#   'ap_si_factor': ('SmartImage Sharpening', 10.0, '%'),
#   'ap_stage_fields_x': ('Stage fields X', 1),
#   'ap_fib_probe_current_actual': ('FIB Probe Current Actual', 0.0, 'pA'),
#   'ap_ar_gas_flow': ('Argon Gas Flow', 0.0, '%'),
#   'ap_gamma': ('Gamma', 1.0),
#   'ap_beam_blank_gun_x': ('Beam Blanked Gun Pos X', 100.0, '%'),
#   'ap_asap_scan_offset_x': ('Scan Offset X', 0),
#   'ap_jazz_front_grid': ('Front Grid', 0, 'V'),
#   'ap_actualext': ('Extractor V', 0.0, 'kV'),
#   'ap_asap_vbe2_minus5v_analogue': ('ASAP VBE2 Minus5V Analogue', 0.0, 'V'),
#   'ap_gunalign_y': ('Gun Align Y', 0.0, '%'),
#   'ap_max_extractor_v': ('Max Extractor V', 7.0, 'kV'),
#   'ap_ppb_4': ('Pb 5', 0.0, '°'),
#   'ap_v_7': ('V 8', 0.0, 'nm'),
#   'ap_prof2_x1': ('Profile 2 X1', 0),
#   'ap_fib_objective_potential': ('FIB Objective', 0, 'V'),
#   'ap_fib_fg_extractor_voltage': ('Flood Gun Extractor Voltage', 0, 'V'),
#   'ap_piezo_at_y': ('Piezo at Y', 0.0, 'µm'),
#   'ap_emissionzoom': ('Emission Zoom', 20),
#   'ap_zoom_factor': ('Zoom factor', 2.0),
#   'ap_fib_working_distance': ('FIB Working Distance', 0.0, 'mm'),
#   'ap_linetoframe_lower': ('Line To Frame Lower', 0.0),
#   'ap_angular_1': ('Aa 2', 0.0, '°'),
#   'ap_stage_goto_y': ('Stage goto Y', 29.727, 'mm'),
#   'ap_beamsleeve_voltage': ('Beam sleeve Bias', 0, 'V'),
#   'ap_ar_discharge_actual': ('Argon Discharge is', 0, 'V'),
#   'ap_k2': ('Mix Signal', 0.0),
#   'ap_gun_at_fisheye_x': ('Gun Value at FishEye mode X', 0.0, '%'),
#   'ap_cc_pressure': ('CC Pressure', 0.0, '%'),
#   'ap_asap_dfe2_minus5v_analogue': ('ASAP DFE2 Minus5V Analogue', 0.0, 'V'),
#   'ap_ppa_4': ('Pa 5', 0.0, 'nm'),
#   'ap_v_1': ('V 2', 0.0, 'nm'),
#   'ap_stage_delta_z': ('Stage Delta Z', 0.0, 'mm'),
#   'ap_esd_upper_y': ('ESD Upper Y', 0.0, '%'),
#   'ap_fib_abs_delta_beam_shift_y': ('FIB Abs Beam Shift Y', 0.0, 'nm'),
#   'ap_fib_suppressor_target': ('FIB Suppressor', 0, 'V'),
#   'ap_fib_stig_y_centre_x': ('FIB Stig Y Centre X', 0.0),
#   'ap_purge_min': ('Purge Min', 133, 'Pa'),
#   'ap_fib_column_pressure': ('FIB Column Pressure', 0.0, 'mbar'),
#   'ap_fm_angle': ('Field Mode Angle', 352.0, '°'),
#   'ap_c3rem': ('C3 Rem', 0.0),
#   'ap_fib_pixel_size': ('FIB Pixel Size', 0.0, 'fm'),
#   'ap_apertureposn_x': ('Aperture Posn X', 0.0, 'mm'),
#   'ap_ppb_0': ('Pb 1', 0.0, '°'),
#   'ap_c3_save': ('C3 saved for beam decel', 0, 'µA'),
#   'ap_esb_grid_is': ('ESB Grid is', 0, 'V'),
#   'ap_eht_set_max': ('EHT set maximum', 30.0, 'kV'),
#   'ap_stage_low_x': ('Stage low X', 0.0, 'mm'),
#   'ap_ar_beam_shift_x': ('Argon Beam Shift X', 0.0, 'nm'),
#   'ap_ar_xy_ratio': ('Argon XY Ratio', 0.0),
#   'ap_frame_ampl': ('Frame Ampl Cal.', 0),
#   'ap_xtalk12': ('Xtalk12', 0.0473),
#   'ap_asap_dfe4_plus5v_digital': ('ASAP DFE4 Plus5V Digital', 0.0, 'V'),
#   'ap_manuallens': ('Liner Target', 8.0, 'kV'),
#   'ap_h_5': ('H 6', 0.0, 'nm'),
#   'ap_stage_centre_x': ('Stage Centre X', 39.687, 'mm'),
#   'ap_stig_cal_x': ('Stig. Cal X', 0.0, '%'),
#   'ap_fib_ext_target': ('FIB Extr.Target', 0.0, 'kV'),
#   'ap_fib_fg_energy_target': ('Flood Gun Energy Target', 0.0, 'V'),
#   'ap_fib_stig_x_centre_x': ('FIB Stig X Centre X', 0.0),
#   'ap_piezo_goto_x': ('Piezo Goto X', 0.0, 'µm'),
#   'ap_c2': ('C2 Lens I', 319.06, 'mA'),
#   'ap_mag_comp_offset': ('Mag Comp. Offset', 500),
#   'ap_fib_slice_x': ('Slice X', 0.0, 'nm'),
#   'ap_guntilt_y': ('Gun Tilt Y', 21.7, '%'),
#   'ap_red_raster_w': ('Red.Raster Width', 512),
#   'ap_scan_rotation_offset_lower': ('Scan Rotation Offset Lower', 0.0, '°'),
#   'ap_piezo_exchange_x': ('Piezo Exchange X', 0.0, 'µm'),
#   'ap_stage_goto_field_y': ('Stage goto field Y', 1),
#   'ap_ar_extractor_actual': ('Argon Extractor is', 0, 'V'),
#   'ap_auto_contrast': ('Auto C Target', 50.0, '%'),
#   'ap_implied_offset': ('Offset B', 0.0, '%'),
#   'ap_align1_y': ('Align 1 Y', 0.0, '%'),
#   'ap_beam_offset_y': ('Beam Offset Y', 0.0, 'nm'),
#   'ap_white_detect': ('White Threshold', 100.0, '%'),
#   'ap_asap_vbe2_temperature': ('ASAP VBE2 Temperature', 0.0, '°C'),
#   'ap_gun_x': ('Gun at X', 0.0, '%'),
#   'ap_water_temp_limit': ('EO Temp Limit', 35.0, '°C'),
#   'ap_spot_x_cal': ('Spot X Cal', 1),
#   'ap_fib_beam_shift_y': ('FIB Beam Shift Y', 0.0, 'nm'),
#   'ap_fib_fil_i': ('FIB Fil Current', 0, 'µA'),
#   'ap_scanorthog': ('Scan Orth corrn', -0.4, '°'),
#   'ap_manualkv': ('EHT Target', 10.0, 'kV'),
#   'ap_magcalheight': ('Mag Cal Actual Height', 0.0, 'nm'),
#   'ap_brightnessz0': ('Brightness A', 52.4, '%'),
#   'ap_c3_decl': ('Decl cal 2', 1.0),
#   'ap_mag_shift_lower_x': ('Shift Amp Lower Offset X', 0.0),
#   'ap_holder_diameter': ('Holder Diameter', 50.0, 'mm'),
#   'ap_si_threshold': ('SmartImage Threshold', 0.5, '%'),
#   'ap_stage_scan_angle': ('Stage scan angle', 0.0, '°'),
#   'ap_fib_objective_actual': ('FIB Objective Actual', 0, 'V'),
#   'ap_ar_objective_actual': ('Argon Objective is', 0, 'V'),
#   'ap_line_int_count': ('Line int. count', 1),
#   'ap_beam_blank_aperture_y': ('Beam Blanked Aperture Pos Y', 100.0, '%'),
#   'ap_filament_age': ('Filament Age', 133.8, 'Hours'),
#   'ap_dual_mag_y_slope': ('Dual Mag Gain Y', 670.0),
#   'ap_stage_vector_t': ('Stage vector T', 0.0, '%'),
#   'ap_hcstage_temp': ('Peltier Temp', 20.0, '°C'),
#   'ap_asap_vbe1_minus5v_analogue': ('ASAP VBE1 Minus5V Analogue', 0.0, 'V'),
#   'ap_gunalign_x': ('Gun Align X', 0.0, '%'),
#   'ap_eht_cal_30kv': ('EHT Cal@30KV', 30.0, 'kV'),
#   'ap_ppa_9': ('Pa 10', 0.0, 'nm'),
#   'ap_v_6': ('V 7', 0.0, 'nm'),
#   'ap_prof1_x2': ('Profile 1 X2', 0),
#   'ap_stage_bias_voltage': ('Stage bias Low Volts', 0.0, 'V'),
#   'ap_vp_limit': ('VP LaB6 Limit', 273, 'Pa'),
#   'ap_fib_eht_actual': ('FIB EHT', 0.0, 'kV'),
#   'ap_humidity_target': ('Humidity Target', 1.3, '%'),
#   'ap_piezo_at_x': ('Piezo at X', 0.0, 'µm'),
#   'ap_linetoframe_upper': ('Line To Frame Upper', 0.0),
#   'ap_angular_0': ('Aa 1', 0.0, '°'),
#   'ap_reduced_raster_y': ('Reduced Raster Y', 192),
#   'ap_laser_finder_illum': ('Laser Illumination', 0.0, '%'),
#   'ap_stage_goto_x': ('Stage goto X', 36.831, 'mm'),
#   'ap_column_vac': ('Gun Vacuum', 1000.0, 'mbar'),
#   'ap_ar_discharge': ('Argon Discharge', 0, 'V'),
#   'ap_k1': ('Signal', 1.0),
#   'ap_line_average_count': ('Line Avg.Count', 82),
#   'ap_beam_time': ('Beam Time', 546.52, 'Hours'),
#   'ap_asap_dfe1_minus5v_analogue': ('ASAP DFE1 Minus5V Analogue', 0.0, 'V'),
#   'ap_cursor_height': ('Cursor Height', 0.0, 'nm'),
#   'ap_profile_w2': ('Profile Width 2', 0.0, 'nm'),
#   'ap_deconvolution_progress': ('Deconvolution Progress', 0.0, '%'),
#   'ap_v_0': ('V 1', 0.0, 'nm'),
#   'ap_stage_delta_y': ('Stage Delta Y', 0.0, 'mm'),
#   'ap_polaris_probe_cal': ('Probe Cal Factor', 1.0),
#   'ap_esd_upper_x': ('ESD Upper X', 0.0, '%'),
#   'ap_fib_abs_delta_beam_shift_x': ('FIB Abs Beam Shift X', 0.0, 'nm'),
#   'ap_fib_drift_y': ('FIB Drift Y', 0.0, 'nm'),
#   'ap_purge_max': ('Purge Max', 400, 'Pa'),
#   'ap_fib_heating_limit': ('FIB Heating Limit', 0, 'µA'),
#   'ap_c3cal': ('C3 Cal', 1.0),
#   'ap_line_counter': ('Line Counter', 641),
#   'ap_aperturesize': ('Aperture Size', 20.0, 'µm'),
#   'ap_ppa_3': ('Pa 4', 0.0, 'nm'),
#   'ap_wd_save': ('wd saved for beam decel', 10.0, 'mm'),
#   'ap_liner_cal_at_10kv': ('Liner Cal @ 10KV', 10000, 'V'),
#   'ap_beam_current': ('Beam Current', 100.0, 'µA'),
#   'ap_stage_high_z': ('Stage high Z', 35.0, 'mm'),
#   'ap_ion_convertor_voltage': ('Convertor Voltage', 0.0, 'kV'),
#   'ap_ar_mag_factor': ('Argon Mag Factor', 0.0, 'nm'),
#   'ap_mag1': ('Mag Z1', 1.0),
#   'ap_asap_dfe3_plus5v_digital': ('ASAP DFE3 Plus5V Digital', 0.0, 'V'),
#   'ap_manualsupp': ('Suppressor V Target', 0, 'V'),
#   'ap_h_4': ('H 5', 0.0, 'nm'),
#   'ap_sample_height': ('Compu. Height', 26.685, 'mm'),
#   'ap_fib_aper_y_actual': ('FIB Aperture Y Actual', 0),
#   'ap_fib_emission_target': ('FIB Emission Target', 0.0, 'µA'),
#   'ap_c1': ('C1 Lens I', 370.95, 'mA'),
#   'ap_mag_comp_ampl': ('Mag Comp. Amplitude', 37.0, '%'),
#   'ap_fib_slice_index': ('Slice Index', 0),
#   'ap_guntilt_x': ('Gun Tilt X', 16.7, '%'),
#   'ap_red_raster_posn_y': ('Red.Raster Posn Y', 192),
#   'ap_mag_gain_lower_y': ('Shift Amp Lower Gain Y', 0.0),
#   'ap_holder_height': ('Holder Height', 16.2, 'mm'),
#   'ap_specimen_diameter': ('Specimen Diameter', 60, 'mm'),
#   'ap_stage_goto_field_x': ('Stage goto field X', 1),
#   'ap_ar_extractor': ('Argon Extractor', 0, 'V'),
#   'ap_auto_bright': ('Auto B Target', 50.0, '%'),
#   'ap_implied_gain': ('Gain B', 100.0, '%'),
#   'ap_align1_x': ('Align 1 X', 0.0, '%'),
#   'ap_beam_offset_x': ('Beam Offset X', 0.0, 'nm'),
#   'ap_black_detect': ('Black Threshold', 0.0, '%'),
#   'ap_asap_vbe1_temperature': ('ASAP VBE1 Temperature', 44.0, '°C'),
#   'ap_nominalext': ('Nominal extractor V', 3.0, 'kV'),
#   'ap_aperture_y': ('Aperture at Y', 0.0, '%'),
#   'ap_stage_high_m': ('Stage high M', 0.0, 'mm'),
#   'ap_water_temp': ('EO Temp', 24.5, '°C'),
#   'ap_user_max_eht': ('User Max EHT', 30.0, 'kV'),
#   'ap_ccd_illumination': ('CCD Illum.', 75.0, '%'),
#   'ap_fib_beam_shift_x': ('FIB Beam Shift X', 0.0, 'nm'),
#   'ap_scanrotation': ('Scan Rotation', 0.0, '°'),
#   'ap_fib_focus': ('FIB Focus', 0.0),
#   'ap_usermaxcurrent': ('Fil I (Usermax)', 4.0, 'A'),
#   'ap_magcalwidth': ('Mag Cal Actual Width', 0.0, 'nm'),
#   'ap_defect_id': ('Defect ID', 0),
#   'ap_line_posn_y': ('Line posn Y', 192),
#   'ap_wd_decl': ('Decl cal 1', 1.0),
#   'ap_mag_shift_upper_y': ('Shift Amp Upper Offset Y', 0.0),
#   'ap_si_enhancement': ('SmartImage Contrast', 30.0, '%'),
#   'ap_stage_vector_z': ('Stage vector Z', 0.0, '%'),
#   'ap_bgpl': ('BGPL', 10.0, 'mm'),
#   'ap_ar_objective': ('Argon Objective', 0, 'V'),
#   'ap_frame_int_count': ('Frames to Int.', 0),
#   'ap_beam_blank_aperture_x': ('Beam Blanked Aperture Pos X', 100.0, '%'),
#   'ap_alias_wd': ('Focus', 9.53, 'mm'),
#   'ap_stage_vector_r': ('Stage vector R', 0.0, '%'),
#   'ap_asap_vbe2_plus5v_analogue': ('ASAP VBE2 Plus5V Analogue', 0.0, 'V'),
#   'ap_eht_cal_24kv': ('EHT Cal@24KV', 24.0, 'kV'),
#   'ap_ppa_8': ('Pa 9', 0.0, 'nm'),
#   'ap_v_5': ('V 6', 0.0, 'nm'),
#   'ap_prof1_x1': ('Profile 1 X1', 0),
#   'ap_hrru_number': ('HRRU No.', 0),
#   'ap_fib_eht_target': ('FIB EHT Target', 0.0, 'kV'),
#   'ap_humidity': ('Humidity', 0.0, '%'),
#   'ap_esb_grid_max': ('ESB Grid Max', 1500, 'V'),
#   'ap_contrastz3': ('Contrast D', 22.3, '%'),
#   'ap_mill_item_elapsed_time': ('Mill Item Elapsed Time', 0, 'ms'),
#   'ap_stage_bias_voltage_high': ('Beam deceleration Volts', 0, 'V'),
#   'ap_magcal_lower_y': ('Calibrate Mag Lower Y', 0.0),
#   'ap_radial_3': ('Da 4', 0.0, 'nm'),
#   'ap_fib_condenser_actual': ('FIB Condenser actual', 0, 'V'),
#   'ap_ar_acc_actual': ('Argon Energy is', 0, 'V'),
#   'ap_scm': ('Specimen I', 0.0, 'pA'),
#   'ap_photo_number': ('Photo No.', 8339),
#   'ap_field_overlap': ('Field Overlap', 0.0, '%'),
#   'ap_spot': ('Spot signal', 0),
#   'ap_asap_dfe4_plus5v_analogue': ('ASAP DFE4 Plus5V Analogue', 0.0, 'V'),
#   'ap_cursor_width': ('Cursor Width', 0.0, 'nm'),
#   'ap_profile_w1': ('Profile Width 1', 0.0, 'nm'),
#   'ap_h_9': ('H 10', 0.0, 'nm'),
#   'ap_stage_delta_x': ('Stage Delta X', 0.0, 'mm'),
#   'ap_compu_tilt_error': ('Compu. Tilt Error', 0.0475),
#   'ap_fib_drift_x': ('FIB Drift X', 0.0, 'nm'),
#   'ap_purge_cycles': ('Purge cycles', 2),
#   'ap_c3': ('C3 Lens I', 72.03, 'mA'),
#   'ap_epd_low': ('EPD Low Limit', 0),
#   'ap_c2rem': ('C2 Rem', 0.0072),
#   'ap_fib_slice_angle': ('Slice Angle', 0.0, '°'),
#   'ap_zoompos_y': ('Zoom Posn Y', 192),
#   'ap_ppa_2': ('Pa 3', 0.0, 'nm'),
#   'ap_clip_limit': ('Clip Limit', 0),
#   'ap_liner_cal_at_100v': ('Liner cal @ 100V', 100, 'V'),
#   'ap_pixel_size': ('Pixel Size', 570.5, 'nm'),
#   'ap_stage_high_y': ('Stage high Y', 100.0, 'mm'),
#   'ap_stage_bias_wobble_amplitude': ('Stage bias wobble amplitude', 10, 'V'),
#   'ap_ion_collector_voltage': ('Collector Voltage', 0.0, 'kV'),
#   'ap_ar_pixel_size': ('Argon Pixel Size', 0.0, 'fm'),
#   'ap_mag0': ('Mag Z0', 1.0),
#   'ap_min_wd': ('Focus scan min', 1, 'mm'),
#   'ap_asap_dfe2_plus5v_digital': ('ASAP DFE2 Plus5V Digital', 5.33, 'V'),
#   'ap_manualext': ('Extractor V Target', 0.0, 'kV'),
#   'ap_h_3': ('H 4', 0.0, 'nm'),
#   'ap_image_pixel_size': ('Image Pixel Size', 570.5, 'nm'),
#   'ap_fib_aper_x_actual': ('FIB Aperture X Actual', 0),
#   'ap_fib_suppressor': ('FIB Suppressor Actual', 0, 'V'),
#   'ap_dc_max_attempts': ('Drift Max Tries', 10),
#   'ap_beam_shift_align_y': ('Beam Shift Align Y', 0.0, 'nm'),
#   'ap_brightness': ('Brightness', 52.4, '%'),
#   'ap_fisheye_quadriture': ('Fisheye quadriture', 1000),
#   'ap_gunshift_y': ('Gun Shift Y', -5.0, '%'),
#   'ap_red_raster_posn_x': ('Red.Raster Posn X', 256),
#   'ap_mag_gain_lower_x': ('Shift Amp Lower Gain X', 0.0),
#   'ap_stage_field_size_y': ('Stage field size Y', 0.0, 'mm'),
#   'ap_ar_v_int_actual': ('Argon V Int is', 0, 'V'),
#   'ap_contrast': ('Contrast', 21.9, '%'),
#   'ap_asap_cal_video_delay': ('Video Delay', 60.0, 'ms'),
#   'ap_height': ('Height', 438.2, 'µm'),
#   'ap_asap_dfe1_temperature': ('ASAP DFE1 Temperature', 0.0, '°C'),
#   'ap_eht_set_min': ('EHT Set minimum', 0.01, 'kV'),
#   'ap_asap_dfe4_temperature': ('ASAP DFE4 Temperature', 0.0, '°C'),
#   'ap_extcurrent': ('Ext I Monitor', 0.0, 'µA'),
#   'ap_aperture_x': ('Aperture at X', 0.0, '%'),
#   'ap_stage_low_m': ('Stage low M', 0.0, 'mm'),
#   'ap_fcf_setting': ('FCF Setting', 0.0, '%'),
#   'ap_radial_area_3': ('Db 4', 0.0, 'nm²'),
#   'ap_fib_stigmator_y': ('FIB Stig Y', 0.0, '%'),
#   'ap_frame_counter': ('Frame Counter', 5578),
#   'ap_fib_fg_fil_current_actual': ('Flood Gun Filament Actual', 0, 'µA'),
#   'ap_ep_target': ('EP Target', 30, 'Pa'),
#   'ap_wd': ('WD', 9.53, 'mm'),
#   'ap_hsync_delay': ('HSync delay', 100.0, 'ms'),
#   'ap_frame_time': ('Cycle Time', 33.1, 'Secs'),
#   'ap_fib_gun_pressure': ('FIB Gun Pressure', 0.0, 'mbar'),
#   'ap_line_posn_x': ('Line posn X', 0),
#   'ap_mag_shift_upper_x': ('Shift Amp Upper Offset X', 0.0),
#   'ap_compu_tilt_offset': ('Compu. Tilt Offset', -0.187, 'mm'),
#   'ap_stage_vector_y': ('Stage vector Y', 0.0, '%'),
#   'ap_ar_condenser_actual': ('Argon Condenser is', 0, 'V'),
#   'ap_frame_average_count': ('Frames to average', 47),
#   'ap_aperture_at_fisheye_y': ('Aperture value at FishEye Y', 0.0, '%'),
#   'ap_dual_mag_slope': ('Dual Mag Gain X', 670.0),
#   'ap_stage_goto_t': ('Stage goto T', 20.0, '°'),
#   'ap_asap_vbe1_plus5v_analogue': ('ASAP VBE1 Plus5V Analogue', 5.02, 'V'),
#   'ap_chamber_pressure': ('Chamber', 0.0, 'Pa'),
#   'ap_eht_cal_10kv': ('EHT Cal@10KV', 10.0, 'kV'),
#   'ap_ppa_7': ('Pa 8', 0.0, 'nm'),
#   'ap_v_4': ('V 5', 0.0, 'nm'),
#   'ap_stage_delta_m': ('Stage Delta M', 0.0, 'mm'),
#   'ap_print_number': ('Print No.', 0),
#   'ap_esd_excitation': ('ESD Excitation', 0.0, '%'),
#   'ap_peltier_target': ('Peltier Target', 20.0, '°C'),
#   'ap_esb_grid': ('ESB Grid', 0, 'V'),
#   'ap_contrastz2': ('Contrast C', 22.3, '%'),
#   'ap_mill_item_total_time': ('Mill Item Total Time', 0, 'ms'),
#   'ap_stig_y': ('Stigmation Y', -10.3, '%'),
#   'ap_ppb_3': ('Pb 4', 0.0, '°'),
#   'ap_magcal_lower_x': ('Calibrate Mag Lower X', 0.0),
#   'ap_radial_2': ('Da 3', 0.0, 'nm'),
#   'ap_system_vac': ('System Vacuum', 1.01e-05, 'mbar'),
#   'ap_ar_acc': ('Argon Energy', 0, 'V'),
#   'ap_scan_offset_y': ('Scan Y cal.', 0),
#   'ap_asap_dfe3_plus5v_analogue': ('ASAP DFE3 Plus5V Analogue', 0.0, 'V'),
#   'ap_stage_low_t': ('Stage low T', -10.0, '°'),
#   'ap_mag_gain_y': ('Mag Gain Cal Y', 859.0),
#   'ap_h_8': ('H 9', 0.0, 'nm'),
#   'ap_stage_low_r': ('Stage low R', -380.0, '°'),
#   'ap_dc_shift_y': ('Aperture Align Y', 8.0, '%'),
#   'ap_fib_sem_angle': ('FIB SEM Angle', 54.0, '°'),
#   'ap_epd_high': ('EPD High Limit', 0),
#   'ap_c2cal': ('C2 Cal', 1.085),
#   'ap_fib_slice_height': ('Slice Height', 0.0, 'nm'),
#   'ap_zoompos_x': ('Zoom Posn X', 128),
#   'ap_ppa_1': ('Pa 2', 0.0, 'nm'),
#   'ap_tilt_align_y': ('Tilt Align Y', 0.0, '%'),
#   'ap_fib_min_autoheat_current': ('FIB Min. Autoheat Current', 0, 'µA'),
#   'ap_chamber_pressure_detailed': ('Chamber Pressure Detailed', 0.0, 'Pa'),
#   'ap_stage_high_x': ('Stage high X', 80.0, 'mm'),
#   'ap_landing_energy': ('Landing energy', 10.0, 'kV'),
#   'ap_collector_bias': ('Collector Bias', 300, 'V'),
#   'ap_max_wd': ('Focus scan max', 40, 'mm'),
#   'ap_asap_dfe1_plus5v_digital': ('ASAP DFE1 Plus5V Digital', 0.0, 'V'),
#   'ap_test_val': ('Test Val', 0.0),
#   'ap_h_2': ('H 3', 0.0, 'nm'),
#   'ap_radial_area_1': ('Db 2', 0.0, 'nm²'),
#   'ap_fib_aperture_align_y': ('FIB Aper.Align Y', 0),
#   'ap_fib_fil_v_target': ('FIB Fil V target', 0.0, 'V'),
#   'ap_dc_min_conf': ('Drift Min Conf', 50.0, '%'),
#   'ap_beam_shift_align_x': ('Beam Shift Align X', 0.0, 'nm'),
#   'ap_fisheye_orthog': ('Fisheye Orthog', 180.0, '°'),
#   'ap_gunshift_x': ('Gun Shift X', 6.9, '%'),
#   'ap_contrastz1': ('Contrast B', 22.3, '%'),
#   'ap_focus_rotation_comp': ('Focus Rotation comp.', -0.009, 'kV'),
#   'ap_mag_gain_upper_y': ('Shift Amp Upper Gain Y', 0.0),
#   'ap_fib_track_wd_delta': ('FIB Track WD Delta', 0.0, 'nm'),
#   'ap_stage_field_size_x': ('Stage field size X', 0.0, 'mm'),
#   'ap_ar_v_int': ('Argon V Int', 0, 'V'),
#   'ap_offset': ('Offset A', 0.0, '%'),
#   'ap_width': ('Width', 584.2, 'µm'),
#   'ap_asap_mb_temperature': ('ASAP MB Temperature', 41.0, '°C'),
#   'ap_mag_shift_y': ('Mag Shift Cal Y', -20.0),
#   'ap_pirani_pressure': ('Pirani Pressure', 0.0, 'mbar'),
#   'ap_actuallens': ('Liner Tube', 0.0, 'kV'),
#   'ap_aperture_align_y': ('Aperture Align Y', 0.0, '%'),
#   'ap_stage_goto_m': ('Stage goto M', 0.0, 'mm'),
#   'ap_ppb_6': ('Pb 7', 0.0, '°'),
#   'ap_v_9': ('V 10', 0.0, 'nm'),
#   'ap_radial_area_2': ('Db 3', 0.0, 'nm²'),
#   'ap_fib_fg_serial_number': ('Flood Gun Serial Number', 0),
#   'ap_fib_stigmator_x': ('FIB Stig X', 0.0, '%'),
#   'ap_stage_at_m': ('Stage at M', 0.0, 'mm'),
#   'ap_stage_at_z': ('Stage at Z', 29.301, 'mm'),
#   'ap_stage_at_y': ('Stage at Y', 29.727, 'mm'),
#   'ap_actualcurrent': ('Fil I', 3.294, 'A'),
#   'ap_stage_at_x': ('Stage at X', 36.8308, 'mm'),
#   'ap_actualkv': ('EHT', 10.0, 'kV'),
#   'ap_stage_at_t': ('Stage at T', 20.0, '°'),
#   'ap_sample_at_y': ('Sample at Y', 0.0),
#   'ap_stage_at_r': ('Stage at R', 37.4, '°'),
#   'ap_sample_at_x': ('Sample at X', 0.0),
#   'ap_time': ('Time', '11:10:04'),
#   'ap_date': ('Date', '14 Mar 2022'),
#   'sv_group_id': ('Group ID', ''),
#   'sv_version': ('Version', 'V06.04.00.00 : 16-Apr-18'),
#   'sv_image_type': ('Image Type', ''),
#   'sv_serial_number': ('Serial No.', 'EVO 10-8001013820'),
#   'sv_user_text': ('User Text', ''),
#   'sv_operator': ('Operator', ''),
#   'sv_user_name': ('User Name', 'UWE'),
#   'sv_file_name': ('File Name', 'Nozzle Chip RIE KOH10.tif'),
#   'sv_image_path': ('Images', 'd:\\bildtransfer\\uwe\\'),
#   'sv_sample_id': ('Sample ID', '')}}

# %% [markdown]
# We can see simply loading the tiff image and parsing it as a dictionary using built-in hyperspy functions formats it nicely. We can also see that each element of the schema can be found within it, meaning it successfully passes this test. The conversion table for the "variable names" for each metadata variable can be [found here](https://docs.google.com/spreadsheets/d/1f_9qKa2BbA5_q47ild_fZeQFKPUJKcxcbkYkhje0EF0/edit?usp=sharing).

# %% [markdown]
# # Nozzle Chip RIE KOH10 Zeiss EVO IMT.tif
#
# Zeiss EVO instrument

# %%
f = hs.load(images[1])

# %%
Zeiss_EVO = f.original_metadata.as_dictionary()

del Zeiss_EVO['ColorMap']
del Zeiss_EVO['34119']

Zeiss_EVO
# Out:
# {'NewSubfileType': <FILETYPE.UNDEFINED: 0>,
#  'ImageWidth': 1024,
#  'ImageLength': 768,
#  'BitsPerSample': 8,
#  'Compression': <COMPRESSION.NONE: 1>,
#  'PhotometricInterpretation': <PHOTOMETRIC.PALETTE: 3>,
#  'StripOffsets': (103823,),
#  'Orientation': <ORIENTATION.TOPLEFT: 1>,
#  'SamplesPerPixel': 1,
#  'RowsPerStrip': 4294967295,
#  'StripByteCounts': (786432,),
#  'XResolution': (1, 1),
#  'YResolution': (1, 1),
#  'ResolutionUnit': <RESUNIT.NONE: 1>,
#  'SampleFormat': <SAMPLEFORMAT.UINT: 1>,
#  'CZ_SEM': {'': (0,
#    0,
#    0,
#    5.705307e-07,
#    195.695,
#    6,
#    10000.0,
#    3.294,
#    5e-10,
#    0.00953088,
#    1,
#    5.705307e-07,
#    195.695,
#    6,
#    10000.0,
#    3.294,
#    5e-10,
#    0.00953088,
#    2,
#    5.705307e-07,
#    195.695,
#    6,
#    10000.0,
#    3.294,
#    5e-10,
#    0.00953088,
#    3,
#    5.705307e-07,
#    195.695,
#    6,
#    10000.0,
#    3.294,
#    5e-10,
#    0.00953088,
#    799),
#   'dp_vent_invalid_reason': ('Vent inhibit', 'Beam Present'),
#   'dp_optimode': ('OptiBeam Mode', 'Analysis'),
#   'dp_fixed_aperture': ('VP Aperture', False),
#   'dp_bsd_autolevel_mode': ('BSD Autolevel Mode', 'Normal'),
#   'dp_recipe': ('Recipe', 'Idle'),
#   'dp_implied_detector': ('Signal B', 'SE1'),
#   'dp_4qbsd_visible': ('BSD Fast', False),
#   'dp_opt_aperture': ('Opt.Aperture', 2),
#   'dp_track_z': ('Track Z', False),
#   'dp_epse_electrode': ('EPSE Electrode', 'Ring'),
#   'dp_c3_rot_correction': ('C3 Rot Corrn.', True),
#   'dp_fisheye_mode': ('Fisheye Mode', False),
#   'dp_stage_tilted': ('Stage Tilt', 'In Y'),
#   'dp_ccd_mode_actual': ('CCD Mode Actual', 'Greyscale'),
#   'dp_ar_gun': ('Argon Gun', 'Absent'),
#   'dp_column_isolated': ('Column Isolated', False),
#   'dp_mixing': ('Mixing', False),
#   'dp_fib_fg_mode_target': ('Flood Gun Mode Target', 'Low Energy Mode'),
#   'dp_stem_gain': ('STEM Gain', 'Low'),
#   'dp_high_current': ('High Current', False),
#   'dp_dwell_time': ('Dwell Time', 50, 'ns'),
#   'dp_si_noise_reduction': ('SmartImage Noise Reduction', False),
#   'dp_right_frozen': ('Right Frozen', False),
#   'dp_fib_fg_blanked': ('Flood Gun Blanked', False),
#   'dp_fast_mode': ('Fast Mode', False),
#   'dp_compucentric_mode': ('Compuc. Mode', False),
#   'dp_anode_aperture_changer': ('Anode Aperture Changer', 'Absent'),
#   'dp_gis_shutdown_state': ('GIS Shutdown State', 'Normal'),
#   'dp_smartfib_api_status': ('SmartFIB Command Status', 'Idle'),
#   'dp_fib_column': ('FIB Column', 'None'),
#   'dp_tilted': ('Stage Tilted', True),
#   'dp_fib_suppressor': ('FIB Suppressor is', 'Absent'),
#   'dp_vpse': ('VPSE detector', 'Absent'),
#   'dp_crosshairs': ('Crosshairs', False),
#   'dp_double_deflection_state': ('Double Deflection State', 'Both On'),
#   'dp_gate_valve_position': ('WDX Gate Valve posn', 'OK'),
#   'dp_hese2_fitted': ('HE-SE2 Fitted', False),
#   'dp_ep_mode': ('EP Gas', 'Air'),
#   'dp_condenser': ('Condenser Normal', 'Normal'),
#   'dp_implied_invert': ('Invert B', False),
#   'dp_4qbsd_gain': ('BSD Gain', 'High'),
#   'dp_fib_gun_valve': ('FIB Gun Valve', 'Closed'),
#   'dp_aperture_state': ('Aperture', 'Clean'),
#   'dp_electron_counting': ('Electron Counting', False),
#   'dp_saturate_at': ('Saturate at', 'Second peak'),
#   'dp_stage_angle': ('Stage Angle corrn.', True),
#   'dp_image_store': ('Store resolution', '1024 * 768'),
#   'dp_field_mode': ('Field Mode', False),
#   'dp_coolstage_type': ('CoolStage Type', 'Cold'),
#   'dp_best_aperture': ('Best Aperture', True),
#   'dp_fib_fg_mode_actual': ('Flood Gun Actual Mode', 'Low Energy Mode'),
#   'dp_stem_auto': ('STEM Auto', False),
#   'dp_stage_init': ('Stage Initialised', True),
#   'dp_cc_on_gis_channel': ('GIS Channel with CC', 'None'),
#   'dp_channel': ('Display', 0),
#   'dp_fib_fg_fitted': ('Flood Gun Fitted', False),
#   'dp_bsd_layout': ('BSD LAYOUT', 'Four Segment Layout'),
#   'dp_bsd_mode': ('BSD Mode', 'User'),
#   'dp_fib_mode': ('FIB Mode', 'Imaging'),
#   'dp_nano_tips': ('Nano Tips', 'Absent'),
#   'dp_bsd_n_on_p': ('BSD Invert', False),
#   'dp_mgs_evac_state': ('MGS Evacuation State', False),
#   'dp_use_epd': ('Use End Point Detection', False),
#   'dp_mains_sync': ('Mains Sync', 'Single Edge'),
#   'dp_fib_pneumatic_prep_state': ('FIB preparation for pneumatic',
#    'FIB ready for system vent'),
#   'dp_mouse_adjust_disable': ('Mouse Adjust Disable', False),
#   'dp_frozen': ('Image', 'Live'),
#   'dp_filament_type': ('Filament Type', 'W (Agar A054-L)'),
#   'dp_autofocus_version': ('Autofocus Version',
#    'Line Scan based Autofocus Version'),
#   'dp_sample_holder': ('Sample Holder', 'Carousel 9x9mm'),
#   'dp_high_resolution_mode': ('High Resolution Mode', False),
#   'dp_fib_scan': ('FIB Scan', 'Continuous'),
#   'dp_beam_blanked': ('Beam Blanked', False),
#   'dp_cc_type': ('CC Type', 'None'),
#   'dp_4qbsd': ('BSD', 'Absent'),
#   'dp_image_saved': ('Image saved', True),
#   'dp_gis_location': ('GIS Location', 'Unknown'),
#   'dp_mag_range': ('Mag Range', 2),
#   'dp_user_align': ('User Align', True),
#   'dp_zone': ('Zone', 0),
#   'dp_fil_blown': ('Filament blown', False),
#   'dp_humidity_valve': ('Humidity Valve', 'Closed'),
#   'dp_fib_external_polarity': ('FIB External Polarity', 0),
#   'dp_peltier_photo': ('Peltier Photo', False),
#   'dp_main_detector': ('Control', 'Signal A'),
#   'dp_invert': ('Invert A', False),
#   'dp_fib_fg_remoting_target': ('Remoting Target', 'Flood Gun Normal'),
#   'dp_stage_is': ('Stage Is', 'Idle'),
#   'dp_fib_present': ('FIB Present', False),
#   'dp_peltier_type': ('Peltier Type', 'Deben'),
#   'dp_signalaz0': ('Signal A Z0', 'SE1'),
#   'dp_freeze_on': ('Freeze on', 'End Frame'),
#   'dp_fib_blanked': ('FIB Blanked', False),
#   'dp_stage_bias_high': ('Beam deceleration', False),
#   'dp_epse_gain': ('EPSE Gain', 'Low'),
#   'dp_end_detection': ('End Detection', False),
#   'dp_vac_comms_fail': ('Vac comms fail', False),
#   'dp_bsd_auto': ('BSD Auto Range', True),
#   'dp_pneumatic_device_in_use': ('Pneumatic Device in use', 'None'),
#   'dp_fib_wide_view': ('FIB Wide View', False),
#   'dp_anode': ('Anode Spacer', 'High KV'),
#   'dp_use_ref_mag': ('Reference Mag', 'Polaroid 545'),
#   'dp_beamsleeve_position': ('Beam sleeve', 'Out'),
#   'dp_user_mag_cal': ('User Calibration', False),
#   'dp_safe_stem_valid': ('Safe STEM Valid', False),
#   'dp_4qbsd_q5': ('S5', False),
#   'dp_scd_gain': ('SCD Gain', 'Low'),
#   'dp_all_zones': ('All Zones', False),
#   'dp_detector_channel': ('Signal A', 'SE1'),
#   'dp_eht_tripped': ('EHT tripped', False),
#   'dp_flood_state': ('Flood State', 'Idle'),
#   'dp_extractor_trip': ('Extractor Trip', False),
#   'dp_bsd_fast_scan': ('BSD Fast Scan', False),
#   'dp_inlens_duo_mode': ('InlensDuo Mode', 'SE'),
#   'dp_auto_video': ('Auto BC', False),
#   'dp_fib_fg_remoting_actual': ('Flood Gun Remoting Actual',
#    'Flood Gun Normal'),
#   'dp_signalaz1': ('Signal A Z1', 'SE1'),
#   'dp_stage_bias_hv_fitted': ('Variable stage bias fitted', False),
#   'dp_epse_auto': ('EPSE Auto Range', False),
#   'dp_stage_comms_fail': ('Stage comms fail', False),
#   'dp_optiprobe': ('OptiProbe', False),
#   'dp_cls_valve': ('C.L.S.Valve', 'Closed'),
#   'dp_newfilament': ('New Filament', False),
#   'dp_image_detect': ('Image Detect', 'Black'),
#   'dp_custom_holder': ('Custom Holder', False),
#   'dp_gis_interlock_status': ('GIS Interlock status', 'Cartesian'),
#   'dp_zoom': ('Zoom', False),
#   'dp_deconvolution_state': ('Deconvolution State', 'Idle'),
#   'dp_scd_auto': ('SCD Auto Range', False),
#   'dp_ext_scan_control': ('Ext.Scan Control', False),
#   'dp_detector_type': ('Detector', 'SE1'),
#   'dp_eht_reset': ('EHT spurious reset', False),
#   'dp_stem_q4': ('STEM Q4', False),
#   'dp_fib_fg_extractor_target': ('Extractor Target State', False),
#   'dp_gemini_large_beamshift': ('Gemini large beam shift', False),
#   'dp_jazz_gain': ('Jazz Gain', 'Low'),
#   'dp_monitor': ('Monitor', '19/21 inch'),
#   'dp_freeze_status': ('Freeze', 'Idle'),
#   'dp_fib_extractor_conflict': ('FIB Extractor Conflict', False),
#   'dp_stage_bias_carassel_fitted': ('Beam deceleration carousel', False),
#   'dp_epse_bandwidth': ('EPSE Bandwidth', 'DC'),
#   'dp_stage_bias': ('Stage bias low voltage', False),
#   'dp_stigbalance': ('Stig Balance', False),
#   'dp_gis_interlock_present': ('GIS Interlock available', False),
#   'dp_frame_grabber': ('Frame Grabber', 'ASAP'),
#   'dp_fib_ext_scan_select': ('FIB Ext Scan Select', 'Ext 0'),
#   'dp_beamsleeve_fitted': ('Beam sleeve fitted', False),
#   'dp_vpse2': ('VPSE-G3 Fitted', 'Absent'),
#   'dp_4qbsd_q1': ('S1', False),
#   'dp_fib_lock_mag': ('FIB Lock Mags', False),
#   'dp_freeze_blanks': ('Freeze Blanks', True),
#   'dp_windowing': ('Windowing', False),
#   'dp_partial_vent': ('Partial Vent on Standby', False),
#   'dp_scd_bandwidth': ('SCD Bandwidth', 'DC'),
#   'dp_calibration': ('Calibration', 'Disabled'),
#   'dp_stem_q1': ('STEM Q1', False),
#   'dp_eht_vac_ready': ('EHT Vac ready', True),
#   'dp_deconvolution_expert_mode': ('Deconvolution expert mode', False),
#   'dp_stem_q5': ('STEM Q5', False),
#   'dp_fib_fg_extractor_actual': ('Flood Gun Extractor Actual State', False),
#   'dp_bakeout_full': ('full service bakeout', False),
#   'dp_water_ok': ('Water OK', True),
#   'dp_low_mag': ('Low Mag', False),
#   'dp_vent_inhibited': ('Venting inhibited', True),
#   'dp_fib_probe': ('FIB Probe', 'Undefined'),
#   'dp_lut_mode': ('Display LUT mode', 'Normal'),
#   'dp_optibeam': ('OptiBeam Is', True),
#   'dp_4qbsd_q6': ('S6', False),
#   'dp_scangen_type': ('ScanGen Type', 'ASAP'),
#   'dp_fib_ext_scan_mode': ('FIB Ext Scan Mode', False),
#   'dp_final_lens': ('Final Lens', 'EVO: 80 deg'),
#   'dp_ehtcommsfail': ('EHT Comms Fail', False),
#   'dp_scangen': ('Scan Gen', 'Present'),
#   'dp_num_regions': ('Num. Regions', 0),
#   'dp_fib_error': ('FIB Error', 'None'),
#   'dp_gis_heating_status_1': ('GIS Heating Status Channel 1',
#    'GIS Not Heating'),
#   'dp_quattro_bandwidth': ('BSD Bandwidth', 'DC'),
#   'dp_4qbsd_q2': ('S2', False),
#   'dp_dynfocus': ('Dyn.Focus', False),
#   'dp_supervisor': ('Supervisor', 'Enabled'),
#   'dp_colour_mode': ('Colour Mode', False),
#   'dp_tilt_correction': ('Tilt Corrn.', False),
#   'dp_spot': ('Spot', False),
#   'dp_fixed_aperture2': ('EP Aperture', 'None fitted'),
#   'dp_detector_fast_scan': ('Noise reduction for fast scanspeeds', False),
#   'dp_ion_detector_mode': ('SESI Mode', 'SE'),
#   'dp_fisheye_fitted': ('Fish-Eye Fitted', False),
#   'dp_stem_q2': ('STEM Q2', False),
#   'dp_pixel_size': ('Pix Size state', 'calibrated'),
#   'dp_ebbu_mode': ('Beam Blanker Mode', 'Blanked'),
#   'dp_fib_image_probe': ('FIB Image Probe', 'Undefined'),
#   'dp_fib_large_area_patterning': ('FIB Large Area Patterning', False),
#   'dp_ar_mill': ('Argon Mill', False),
#   'dp_fib_mag_range': ('FIB Mag Range', 0),
#   'dp_user_level': ('User Level', 'Full'),
#   'dp_ar_scan': ('Argon Scan', False),
#   'dp_hp_status': ('Chamber Status', 'Power Up'),
#   'dp_column_type': ('Column', 'EVO'),
#   'dp_large_beamshift': ('Large Beam Shift', False),
#   'dp_ar_mfcvalve': ('Argon MFC Valve', 'Closed'),
#   'dp_contrast_enhancement': ('Contrast Enhanced', False),
#   'dp_4qbsd_q3': ('S3', False),
#   'dp_scan_rot': ('Scan Rot', True),
#   'dp_dc_sem_state': ('Sem drift status', 'Not Available'),
#   'dp_line_scan': ('Line Scan', False),
#   'dp_use_small_crosshair': ('Use small crosshair', False),
#   'dp_tandem_deceleration': ('Tandem deceleration', False),
#   'dp_signalaz2': ('Signal A Z2', 'SE1'),
#   'dp_scm_range': ('SCM range', '3->10 pA'),
#   'dp_fib_fg_floodgun_type': ('Flood Gun Type', 'Flood Gun Unknown Type'),
#   'dp_stem_q3': ('STEM Q3', False),
#   'dp_mag_cal': ('Mag State', 'calibrated'),
#   'dp_hv_at_shutdown': ('Go to HV @ Shutdown', False),
#   'dp_scm_status': ('SCM Status', False),
#   'dp_si_source': ('SI source-hidden', 0),
#   'dp_conjugate': ('OptiBeam conjugate', False),
#   'dp_fib_fg_status': ('Flood Gun Status', False),
#   'dp_boost_mode': ('Boost Mode', False),
#   'dp_vp_optibeam': ('VP Optibeam', False),
#   'dp_condenser_reversed': ('Condenser Reversed', False),
#   'dp_z0': ('Zone 0', 'Live'),
#   'dp_fib_mill_probe': ('FIB Milling Probe', 'Undefined'),
#   'dp_scint': ('Scint.', True),
#   'dp_optiresmode': ('OptiBeam Res Mode', 'manual'),
#   'dp_jazz_bandwidth': ('Jazz Bandwidth', 'Low'),
#   'dp_igp_enabled': ('IGP Enabled', False),
#   'dp_gate_valve': ('WDX Gate valve', 'Closed'),
#   'dp_peltier': ('Peltier', False),
#   'dp_output_reduction': ('Output Reduction', 1),
#   'dp_4qbsd_q4': ('S4', False),
#   'dp_aperture': ('Aperture No.', 2),
#   'dp_stage_bias_mode': ('Stage bias mode', 'contrast mode'),
#   'dp_sem': ('Sem', 'EVO 10'),
#   'dp_scan_orthog': ('Scan Orthog', True),
#   'dp_display_channels': ('Channels', 1),
#   'dp_dual_monitor': ('Dual Monitor', False),
#   'dp_signalaz3': ('Signal A Z3', 'SE1'),
#   'dp_c3_rot_sign': ('C3 Rotn Sign', '+'),
#   'dp_stem_fast': ('STEM Fast', False),
#   'dp_out_dev': ('Output dev', '19/21 inch display'),
#   'dp_user': ('User', 'Idle'),
#   'dp_fib_track_wd': ('FIB Tracking WD', False),
#   'dp_fib_fg_interlock': ('Flood Gun Interlock', False),
#   'dp_low_kv_lens': ('Low KV Lens', 'Absent'),
#   'dp_z1': ('Zone 1', 'Live'),
#   'dp_cc_status': ('CC Status', False),
#   'dp_fib_gun_state': ('FIB Gun State', False),
#   'dp_ar_gun_state': ('Argon Gun is', False),
#   'dp_out_type': ('Output To', 'Display/File'),
#   'dp_column_chamber_valve': ('Column Chamber valve', 'Open'),
#   'dp_column_pumping': ('Column pumping', 'Idle'),
#   'dp_scanrate': ('Scan Speed', 3),
#   'dp_left_frozen': ('All Frozen', False),
#   'dp_input_lut_mode': ('Input LUT Mode', 'Transparent'),
#   'dp_operating_mode': ('Operating Mode', 'Normal'),
#   'dp_gis_channel': ('GIS Channel', 'None'),
#   'dp_fib_imaging': ('FIB Imaging', 'SEM'),
#   'dp_c3reversal': ('C3 Reversal', 'Normal'),
#   'dp_vac_mode': ('Vacuum Mode', 'High Vacuum'),
#   'dp_column_mode': ('Column Mode', 'High Resolution'),
#   'dp_stem_seg_mode': ('STEM Seg. Mode', False),
#   'dp_calmode': ('Cal Mode', False),
#   'dp_runupstate': ('Beam State', 'Beam On'),
#   'dp_noise_reduction': ('Noise Reduction', 'Line Avg'),
#   'dp_optibeam_state': ('OptiBeam', 'Analysis'),
#   'dp_vacstatus': ('Vac Status', 'Ready'),
#   'ap_fib_fg_emission_target': ('Flood Gun Emission target', 0.0, 'µA'),
#   'ap_fib_shift_correction_y': ('FIB Shift Correction Y', 0.0, 'nm'),
#   'ap_mag': ('Mag', 196, 'X'),
#   'ap_line_time': ('Line Time', 33.59, 'ms'),
#   'ap_fib_mag_fine_gain_y': ('FIB Mag fine gain Y', 0.0),
#   'ap_spot_posn_y': ('Spot at Y', 192),
#   'ap_scanorthog_lower': ('Orthogonality Lower', 0.0, '°'),
#   'ap_angular_3': ('Aa 4', 0.0, 'kV'),
#   'ap_stage_vector_x': ('Stage vector X', 0.0, '%'),
#   'ap_detector_bandwidth_offset': ('Det BW Offset', 0),
#   'ap_ar_condenser': ('Argon Condenser', 0, 'V'),
#   'ap_aperture_at_fisheye_x': ('Aperture value at FishEye X', 0.0, '%'),
#   'ap_minmag': ('Min Mag', 17, 'X'),
#   'ap_stage_goto_r': ('Stage goto R', 0.0, '°'),
#   'ap_asap_dfe4_minus5v_analogue': ('ASAP DFE4 Minus5V Analogue', 0.0, 'V'),
#   'ap_hp_target': ('VP Target', 30, 'Pa'),
#   'ap_eht_cal_100': ('EHT Cal@0.1KV', 100, 'V'),
#   'ap_ppa_6': ('Pa 7', 0.0, 'nm'),
#   'ap_v_3': ('V 4', 0.0, 'nm'),
#   'ap_stage_delta_r': ('Stage Delta R', 0.0, '°'),
#   'ap_file_number': ('File No', 464),
#   'ap_esd_lower_y': ('ESD Lower Y', 0.0, '%'),
#   'ap_free_wd': ('Free WD', 9.53, 'mm'),
#   'ap_brightnessz3': ('Brightness D', 57.1, '%'),
#   'ap_fm_quadriture': ('Field Mode Quadriture', 1030),
#   'ap_tilt_angle': ('Tilt Angle', 45.0, '°'),
#   'ap_mill_list_elapsed_time': ('Mill List Elapsed Time', 0, 'ms'),
#   'ap_stig_x': ('Stigmation X', -9.5, '%'),
#   'ap_ppb_2': ('Pb 3', 0.0, '°'),
#   'ap_magcal_upper_y': ('Calibrate Mag Upper Y', 0.0),
#   'ap_radial_1': ('Da 2', 0.0, 'nm'),
#   'ap_reduced_raster_width': ('Reduced Raster Width', 512),
#   'ap_vpse2_bias': ('VPSE Bias', 60.0, '%'),
#   'ap_stage_low_z': ('Stage low Z', 0.0, 'mm'),
#   'ap_ar_mag': ('Argon Magnification', 0, 'X'),
#   'ap_ar_shift_ratio_y': ('Argon Shift Ratio Y', 0.0),
#   'ap_scan_offset_x': ('Scan X cal.', 0),
#   'ap_asap_dfe2_plus5v_analogue': ('ASAP DFE2 Plus5V Analogue', 5.1, 'V'),
#   'ap_stage_high_t': ('Stage high T', 90.0, '°'),
#   'ap_profile_top': ('Profile Top', 300),
#   'ap_mag_gain_x': ('Mag Gain Cal X', 878.0),
#   'ap_h_7': ('H 8', 0.0, 'nm'),
#   'ap_spacer_thickness': ('Spacer Thickness', 0.0, 'mm'),
#   'ap_stage_high_r': ('Stage high R', 380.0, '°'),
#   'ap_fib_condenser': ('FIB Condenser', 0, 'V'),
#   'ap_fib_fg_fil_current_target': ('Flood Gun Filament Target', 0, 'µA'),
#   'ap_dc_shift_x': ('Aperture Align X', 16.3, '%'),
#   'ap_sem_level_at_tilt': ('SEM Level @', 0.0, '°'),
#   'ap_vac_ready_at': ('Vac Ready @', 0.00013, 'mbar'),
#   'ap_c1rem': ('C1 Rem', -0.0011),
#   'ap_fib_slice_width': ('Slice Width', 0.0, 'nm'),
#   'ap_beamshift_y': ('Beam Shift Y', 0.0, '%'),
#   'ap_ppa_0': ('Pa 1', 0.0, 'nm'),
#   'ap_deconvolution_sigma': ('Deconvolution Sigma', 0.0),
#   'ap_tilt_align_x': ('Tilt Align X', 0.0, '%'),
#   'ap_stage_xm_r': ('Stage X+M Rotation', 0.0, '°'),
#   'ap_si_topography': ('SmartImage Topography', 10.0, '%'),
#   'ap_stage_at_field_y': ('Stage at field Y', 1),
#   'ap_ar_angle': ('Argon Column Angle', 0.0, '°'),
#   'ap_asap_dfe3_temperature': ('ASAP DFE3 Temperature', 0.0, '°C'),
#   'ap_test_n': ('Test No.', 0),
#   'ap_h_1': ('H 2', 0.0, 'nm'),
#   'ap_radial_area_0': ('Db 1', 0.0, 'nm²'),
#   'ap_opt_semiangle': ('Opt. Semi Angle', 5.739, 'mrad'),
#   'ap_fib_aperture_align_x': ('FIB Aper.Align X', 0),
#   'ap_fib_fil_i_target': ('FIB Fil I Target', 0, 'µA'),
#   'ap_dc_max_pix_error': ('Drift Max.Pix.Error', 1),
#   'ap_inlens_duo_grid_actual': ('InlensDuo Grid is', 0, 'V'),
#   'ap_fisheye_angle': ('Fisheye Angle', 180.0, '°'),
#   'ap_magcaly': ('Mag Cal Y scale', 1.295),
#   'ap_contrastz0': ('Contrast A', 21.9, '%'),
#   'ap_dual_mag_offset_y': ('Dual Mag Offset Y', 0.0),
#   'ap_mag_decl': ('Mag scaling decel', 1.0),
#   'ap_mag_gain_upper_x': ('Shift Amp Upper Gain X', 0.0),
#   'ap_holder_length': ('Holder Length', 0.0, 'mm'),
#   'ap_stage_fields_y': ('Stage fields Y', 1),
#   'ap_fib_source_lifetime': ('FIB Source lifetime', 0.0, 'µAh'),
#   'ap_ar_gas_flow_actual': ('Argon Gas Flow is', 0.0, '%'),
#   'ap_gain': ('Gain A', 100.0, '%'),
#   'ap_beam_blank_gun_y': ('Beam Blanked Gun Pos Y', 100.0, '%'),
#   'ap_conjugate': ('Conjugate posn.', -164.0, 'mm'),
#   'ap_asap_scan_offset_y': ('Scan Offset Y', 0),
#   'ap_mag_shift_x': ('Mag Shift Cal X', -10.0),
#   'ap_jazz_back_grid': ('Back Grid', 0, 'V'),
#   'ap_actualsupp': ('Suppressor V', 0, 'V'),
#   'ap_aperture_align_x': ('Aperture Align X', 0.0, '%'),
#   'ap_ppb_5': ('Pb 6', 0.0, '°'),
#   'ap_v_8': ('V 9', 0.0, 'nm'),
#   'ap_prof2_x2': ('Profile 2 X2', 0),
#   'ap_fib_magnification': ('FIB Mag', 0, 'X'),
#   'ap_fib_fg_emission_actual': ('Flood Gun Emission Actual', 0.0, 'µA'),
#   'ap_fib_shift_correction_x': ('FIB Shift Correction X', 0.0, 'nm'),
#   'ap_iprobe': ('I Probe', 500, 'pA'),
#   'ap_fcf_tilt': ('FCF Tilt Angle', 0.0, '°'),
#   'ap_fib_mag_fine_gain_x': ('FIB Mag fine gain X', 0.0),
#   'ap_stage_xm_angle': ('Stage X+M Angle', 8.0, '°'),
#   'ap_spot_posn_x': ('Spot at X', 256),
#   'ap_scanorthog_upper': ('Orthogonality Upper', 0.0, '°'),
#   'ap_angular_2': ('Aa 3', 0.0, 'kV'),
#   'ap_stage_goto_z': ('Stage goto Z', 0.0, 'mm'),
#   'ap_ar_discharge_current': ('Argon Discharge I is', 0.0, 'µA'),
#   'ap_gun_at_fisheye_y': ('Gun Value at FishEye mode Y', 0.0, '%'),
#   'ap_spotsize': ('Spot Size', 480),
#   'ap_asap_dfe3_minus5v_analogue': ('ASAP DFE3 Minus5V Analogue', 0.0, 'V'),
#   'ap_ppa_5': ('Pa 6', 0.0, 'nm'),
#   'ap_v_2': ('V 3', 0.0, 'nm'),
#   'ap_stage_delta_t': ('Stage Delta T', 0.0, '°'),
#   'ap_specimen_height': ('Specimen Height', 17, 'mm'),
#   'ap_esd_lower_x': ('ESD Lower X', 0.0, '%'),
#   'ap_fib_emission_current': ('FIB Emission I', 0.0, 'µA'),
#   'ap_fib_stig_y_centre_y': ('FIB Stig Y Centre Y', 0.0),
#   'ap_brightnessz2': ('Brightness C', 57.1, '%'),
#   'ap_fm_orthog': ('Field Mode Orthog', 358.0, '°'),
#   'ap_tilt_axis': ('Tilt Axis', 0.0, '°'),
#   'ap_mill_list_total_time': ('Mill List Total Time', 0, 'ms'),
#   'ap_apertureposn_y': ('Aperture Posn Y', 0.0, 'mm'),
#   'ap_ppb_1': ('Pb 2', 0.0, '°'),
#   'ap_magcal_upper_x': ('Calibrate Mag Upper X', 0.0),
#   'ap_radial_0': ('Da 1', 0.0, 'nm'),
#   'ap_epse_bias': ('EPSE Bias', 0.0, '%'),
#   'ap_profile_w': ('Profile width', 0.0, 'nm'),
#   'ap_stage_low_y': ('Stage low Y', 0.0, 'mm'),
#   'ap_ar_beam_shift_y': ('Argon Beam Shift Y', 0.0, 'nm'),
#   'ap_ar_shift_ratio_x': ('Argon Shift Ratio X', 0.0),
#   'ap_xtalk21': ('Xtalk21', 0.0473),
#   'ap_asap_dfe1_plus5v_analogue': ('ASAP DFE1 Plus5V Analogue', 0.0, 'V'),
#   'ap_min_ext': ('Min Extractor V', 3.0, 'kV'),
#   'ap_h_6': ('H 7', 0.0, 'nm'),
#   'ap_stage_centre_y': ('Stage Centre Y', 39.459, 'mm'),
#   'ap_beam_current_monitor': ('Beam I Monitor', 0.0, 'µA'),
#   'ap_fib_scan_size': ('FIB Scan Size', 0.0, 'nm'),
#   'ap_stig_cal_y': ('Stig. Cal Y', 0.0, '%'),
#   'ap_fib_ext_actual': ('FIB Extractor', 0.0, 'kV'),
#   'ap_fib_fg_energy_actual': ('Flood Gun Energy Actual', 0.0, 'V'),
#   'ap_fib_stig_x_centre_y': ('FIB Stig X Centre Y', 0.0),
#   'ap_piezo_goto_y': ('Piezo Goto Y', 0.0, 'µm'),
#   'ap_fib_tilt_comp': ('FIB Tilt Comp', 0.0, '°'),
#   'ap_c1cal': ('C1 Cal', 1.126),
#   'ap_fib_slice_y': ('Slice Y', 0.0, 'nm'),
#   'ap_beamshift_x': ('Beam Shift X', 0.0, '%'),
#   'ap_red_raster_h': ('Red.Raster Height', 384),
#   'ap_magcal_base': ('Calibrate Mag Base', 50000.0),
#   'ap_fib_nudge_step': ('FIB Nudge Step', 0.0, 'nm'),
#   'ap_piezo_exchange_y': ('Piezo Exchange Y', 0.0, 'µm'),
#   'ap_stage_at_field_x': ('Stage at field X', 1),
#   'ap_low_mag_focus': ('Low Mag Focus', 1.0),
#   'ap_ar_acc_i': ('Argon Acc I is', 0.0, 'µA'),
#   'ap_deconvolution_regularize': ('Deconvolution Smoothening', 0.0),
#   'ap_ar_mill_progress': ('Argon Mill Progress', 0.0, '%'),
#   'ap_asap_dfe2_temperature': ('ASAP DFE2 Temperature', 39.0, '°C'),
#   'ap_area_fraction': ('Area Fraction', 0.0, '%'),
#   'ap_nominalfil': ('Nominal Fil I', 2.0, 'A'),
#   'ap_gun_y': ('Gun at Y', 0.0, '%'),
#   'ap_stage_vector_m': ('Stage Vector M', 0.0, '%'),
#   'ap_h_0': ('H 1', 0.0, 'nm'),
#   'ap_semiangle': ('Semi Angle', 5.739, 'mrad'),
#   'ap_fib_scan_rotation': ('FIB Scan Rot', 0.0, '°'),
#   'ap_fib_fil_v': ('FIB Fil Voltage', 0.0, 'V'),
#   'ap_stageangle': ('Stage Angle', -11.2, '°'),
#   'ap_inlens_duo_grid': ('InlensDuo Grid', 0, 'V'),
#   'ap_manualcurrent': ('Fil I Target', 3.294, 'A'),
#   'ap_magcalx': ('Mag Cal X scale', 1.3),
#   'ap_brightnessz1': ('Brightness B', 57.1, '%'),
#   'ap_dual_mag_offset_x': ('Dual Mag Offset X', 0.0),
#   'ap_mag_shift_lower_y': ('Shift Amp Lower Offset Y', 0.0),
#   'ap_holder_width': ('Holder Width', 0.0, 'mm'),
#   'ap_si_factor': ('SmartImage Sharpening', 10.0, '%'),
#   'ap_stage_fields_x': ('Stage fields X', 1),
#   'ap_fib_probe_current_actual': ('FIB Probe Current Actual', 0.0, 'pA'),
#   'ap_ar_gas_flow': ('Argon Gas Flow', 0.0, '%'),
#   'ap_gamma': ('Gamma', 1.0),
#   'ap_beam_blank_gun_x': ('Beam Blanked Gun Pos X', 100.0, '%'),
#   'ap_asap_scan_offset_x': ('Scan Offset X', 0),
#   'ap_jazz_front_grid': ('Front Grid', 0, 'V'),
#   'ap_actualext': ('Extractor V', 0.0, 'kV'),
#   'ap_asap_vbe2_minus5v_analogue': ('ASAP VBE2 Minus5V Analogue', 0.0, 'V'),
#   'ap_gunalign_y': ('Gun Align Y', 0.0, '%'),
#   'ap_max_extractor_v': ('Max Extractor V', 7.0, 'kV'),
#   'ap_ppb_4': ('Pb 5', 0.0, '°'),
#   'ap_v_7': ('V 8', 0.0, 'nm'),
#   'ap_prof2_x1': ('Profile 2 X1', 0),
#   'ap_fib_objective_potential': ('FIB Objective', 0, 'V'),
#   'ap_fib_fg_extractor_voltage': ('Flood Gun Extractor Voltage', 0, 'V'),
#   'ap_piezo_at_y': ('Piezo at Y', 0.0, 'µm'),
#   'ap_emissionzoom': ('Emission Zoom', 20),
#   'ap_zoom_factor': ('Zoom factor', 2.0),
#   'ap_fib_working_distance': ('FIB Working Distance', 0.0, 'mm'),
#   'ap_linetoframe_lower': ('Line To Frame Lower', 0.0),
#   'ap_angular_1': ('Aa 2', 0.0, '°'),
#   'ap_stage_goto_y': ('Stage goto Y', 29.727, 'mm'),
#   'ap_beamsleeve_voltage': ('Beam sleeve Bias', 0, 'V'),
#   'ap_ar_discharge_actual': ('Argon Discharge is', 0, 'V'),
#   'ap_k2': ('Mix Signal', 0.0),
#   'ap_gun_at_fisheye_x': ('Gun Value at FishEye mode X', 0.0, '%'),
#   'ap_cc_pressure': ('CC Pressure', 0.0, '%'),
#   'ap_asap_dfe2_minus5v_analogue': ('ASAP DFE2 Minus5V Analogue', 0.0, 'V'),
#   'ap_ppa_4': ('Pa 5', 0.0, 'nm'),
#   'ap_v_1': ('V 2', 0.0, 'nm'),
#   'ap_stage_delta_z': ('Stage Delta Z', 0.0, 'mm'),
#   'ap_esd_upper_y': ('ESD Upper Y', 0.0, '%'),
#   'ap_fib_abs_delta_beam_shift_y': ('FIB Abs Beam Shift Y', 0.0, 'nm'),
#   'ap_fib_suppressor_target': ('FIB Suppressor', 0, 'V'),
#   'ap_fib_stig_y_centre_x': ('FIB Stig Y Centre X', 0.0),
#   'ap_purge_min': ('Purge Min', 133, 'Pa'),
#   'ap_fib_column_pressure': ('FIB Column Pressure', 0.0, 'mbar'),
#   'ap_fm_angle': ('Field Mode Angle', 352.0, '°'),
#   'ap_c3rem': ('C3 Rem', 0.0),
#   'ap_fib_pixel_size': ('FIB Pixel Size', 0.0, 'fm'),
#   'ap_apertureposn_x': ('Aperture Posn X', 0.0, 'mm'),
#   'ap_ppb_0': ('Pb 1', 0.0, '°'),
#   'ap_c3_save': ('C3 saved for beam decel', 0, 'µA'),
#   'ap_esb_grid_is': ('ESB Grid is', 0, 'V'),
#   'ap_eht_set_max': ('EHT set maximum', 30.0, 'kV'),
#   'ap_stage_low_x': ('Stage low X', 0.0, 'mm'),
#   'ap_ar_beam_shift_x': ('Argon Beam Shift X', 0.0, 'nm'),
#   'ap_ar_xy_ratio': ('Argon XY Ratio', 0.0),
#   'ap_frame_ampl': ('Frame Ampl Cal.', 0),
#   'ap_xtalk12': ('Xtalk12', 0.0473),
#   'ap_asap_dfe4_plus5v_digital': ('ASAP DFE4 Plus5V Digital', 0.0, 'V'),
#   'ap_manuallens': ('Liner Target', 8.0, 'kV'),
#   'ap_h_5': ('H 6', 0.0, 'nm'),
#   'ap_stage_centre_x': ('Stage Centre X', 39.687, 'mm'),
#   'ap_stig_cal_x': ('Stig. Cal X', 0.0, '%'),
#   'ap_fib_ext_target': ('FIB Extr.Target', 0.0, 'kV'),
#   'ap_fib_fg_energy_target': ('Flood Gun Energy Target', 0.0, 'V'),
#   'ap_fib_stig_x_centre_x': ('FIB Stig X Centre X', 0.0),
#   'ap_piezo_goto_x': ('Piezo Goto X', 0.0, 'µm'),
#   'ap_c2': ('C2 Lens I', 319.06, 'mA'),
#   'ap_mag_comp_offset': ('Mag Comp. Offset', 500),
#   'ap_fib_slice_x': ('Slice X', 0.0, 'nm'),
#   'ap_guntilt_y': ('Gun Tilt Y', 21.7, '%'),
#   'ap_red_raster_w': ('Red.Raster Width', 512),
#   'ap_scan_rotation_offset_lower': ('Scan Rotation Offset Lower', 0.0, '°'),
#   'ap_piezo_exchange_x': ('Piezo Exchange X', 0.0, 'µm'),
#   'ap_stage_goto_field_y': ('Stage goto field Y', 1),
#   'ap_ar_extractor_actual': ('Argon Extractor is', 0, 'V'),
#   'ap_auto_contrast': ('Auto C Target', 50.0, '%'),
#   'ap_implied_offset': ('Offset B', 0.0, '%'),
#   'ap_align1_y': ('Align 1 Y', 0.0, '%'),
#   'ap_beam_offset_y': ('Beam Offset Y', 0.0, 'nm'),
#   'ap_white_detect': ('White Threshold', 100.0, '%'),
#   'ap_asap_vbe2_temperature': ('ASAP VBE2 Temperature', 0.0, '°C'),
#   'ap_gun_x': ('Gun at X', 0.0, '%'),
#   'ap_water_temp_limit': ('EO Temp Limit', 35.0, '°C'),
#   'ap_spot_x_cal': ('Spot X Cal', 1),
#   'ap_fib_beam_shift_y': ('FIB Beam Shift Y', 0.0, 'nm'),
#   'ap_fib_fil_i': ('FIB Fil Current', 0, 'µA'),
#   'ap_scanorthog': ('Scan Orth corrn', -0.4, '°'),
#   'ap_manualkv': ('EHT Target', 10.0, 'kV'),
#   'ap_magcalheight': ('Mag Cal Actual Height', 0.0, 'nm'),
#   'ap_brightnessz0': ('Brightness A', 52.4, '%'),
#   'ap_c3_decl': ('Decl cal 2', 1.0),
#   'ap_mag_shift_lower_x': ('Shift Amp Lower Offset X', 0.0),
#   'ap_holder_diameter': ('Holder Diameter', 50.0, 'mm'),
#   'ap_si_threshold': ('SmartImage Threshold', 0.5, '%'),
#   'ap_stage_scan_angle': ('Stage scan angle', 0.0, '°'),
#   'ap_fib_objective_actual': ('FIB Objective Actual', 0, 'V'),
#   'ap_ar_objective_actual': ('Argon Objective is', 0, 'V'),
#   'ap_line_int_count': ('Line int. count', 1),
#   'ap_beam_blank_aperture_y': ('Beam Blanked Aperture Pos Y', 100.0, '%'),
#   'ap_filament_age': ('Filament Age', 133.8, 'Hours'),
#   'ap_dual_mag_y_slope': ('Dual Mag Gain Y', 670.0),
#   'ap_stage_vector_t': ('Stage vector T', 0.0, '%'),
#   'ap_hcstage_temp': ('Peltier Temp', 20.0, '°C'),
#   'ap_asap_vbe1_minus5v_analogue': ('ASAP VBE1 Minus5V Analogue', 0.0, 'V'),
#   'ap_gunalign_x': ('Gun Align X', 0.0, '%'),
#   'ap_eht_cal_30kv': ('EHT Cal@30KV', 30.0, 'kV'),
#   'ap_ppa_9': ('Pa 10', 0.0, 'nm'),
#   'ap_v_6': ('V 7', 0.0, 'nm'),
#   'ap_prof1_x2': ('Profile 1 X2', 0),
#   'ap_stage_bias_voltage': ('Stage bias Low Volts', 0.0, 'V'),
#   'ap_vp_limit': ('VP LaB6 Limit', 273, 'Pa'),
#   'ap_fib_eht_actual': ('FIB EHT', 0.0, 'kV'),
#   'ap_humidity_target': ('Humidity Target', 1.3, '%'),
#   'ap_piezo_at_x': ('Piezo at X', 0.0, 'µm'),
#   'ap_linetoframe_upper': ('Line To Frame Upper', 0.0),
#   'ap_angular_0': ('Aa 1', 0.0, '°'),
#   'ap_reduced_raster_y': ('Reduced Raster Y', 192),
#   'ap_laser_finder_illum': ('Laser Illumination', 0.0, '%'),
#   'ap_stage_goto_x': ('Stage goto X', 36.831, 'mm'),
#   'ap_column_vac': ('Gun Vacuum', 1000.0, 'mbar'),
#   'ap_ar_discharge': ('Argon Discharge', 0, 'V'),
#   'ap_k1': ('Signal', 1.0),
#   'ap_line_average_count': ('Line Avg.Count', 82),
#   'ap_beam_time': ('Beam Time', 546.52, 'Hours'),
#   'ap_asap_dfe1_minus5v_analogue': ('ASAP DFE1 Minus5V Analogue', 0.0, 'V'),
#   'ap_cursor_height': ('Cursor Height', 0.0, 'nm'),
#   'ap_profile_w2': ('Profile Width 2', 0.0, 'nm'),
#   'ap_deconvolution_progress': ('Deconvolution Progress', 0.0, '%'),
#   'ap_v_0': ('V 1', 0.0, 'nm'),
#   'ap_stage_delta_y': ('Stage Delta Y', 0.0, 'mm'),
#   'ap_polaris_probe_cal': ('Probe Cal Factor', 1.0),
#   'ap_esd_upper_x': ('ESD Upper X', 0.0, '%'),
#   'ap_fib_abs_delta_beam_shift_x': ('FIB Abs Beam Shift X', 0.0, 'nm'),
#   'ap_fib_drift_y': ('FIB Drift Y', 0.0, 'nm'),
#   'ap_purge_max': ('Purge Max', 400, 'Pa'),
#   'ap_fib_heating_limit': ('FIB Heating Limit', 0, 'µA'),
#   'ap_c3cal': ('C3 Cal', 1.0),
#   'ap_line_counter': ('Line Counter', 641),
#   'ap_aperturesize': ('Aperture Size', 20.0, 'µm'),
#   'ap_ppa_3': ('Pa 4', 0.0, 'nm'),
#   'ap_wd_save': ('wd saved for beam decel', 10.0, 'mm'),
#   'ap_liner_cal_at_10kv': ('Liner Cal @ 10KV', 10000, 'V'),
#   'ap_beam_current': ('Beam Current', 100.0, 'µA'),
#   'ap_stage_high_z': ('Stage high Z', 35.0, 'mm'),
#   'ap_ion_convertor_voltage': ('Convertor Voltage', 0.0, 'kV'),
#   'ap_ar_mag_factor': ('Argon Mag Factor', 0.0, 'nm'),
#   'ap_mag1': ('Mag Z1', 1.0),
#   'ap_asap_dfe3_plus5v_digital': ('ASAP DFE3 Plus5V Digital', 0.0, 'V'),
#   'ap_manualsupp': ('Suppressor V Target', 0, 'V'),
#   'ap_h_4': ('H 5', 0.0, 'nm'),
#   'ap_sample_height': ('Compu. Height', 26.685, 'mm'),
#   'ap_fib_aper_y_actual': ('FIB Aperture Y Actual', 0),
#   'ap_fib_emission_target': ('FIB Emission Target', 0.0, 'µA'),
#   'ap_c1': ('C1 Lens I', 370.95, 'mA'),
#   'ap_mag_comp_ampl': ('Mag Comp. Amplitude', 37.0, '%'),
#   'ap_fib_slice_index': ('Slice Index', 0),
#   'ap_guntilt_x': ('Gun Tilt X', 16.7, '%'),
#   'ap_red_raster_posn_y': ('Red.Raster Posn Y', 192),
#   'ap_mag_gain_lower_y': ('Shift Amp Lower Gain Y', 0.0),
#   'ap_holder_height': ('Holder Height', 16.2, 'mm'),
#   'ap_specimen_diameter': ('Specimen Diameter', 60, 'mm'),
#   'ap_stage_goto_field_x': ('Stage goto field X', 1),
#   'ap_ar_extractor': ('Argon Extractor', 0, 'V'),
#   'ap_auto_bright': ('Auto B Target', 50.0, '%'),
#   'ap_implied_gain': ('Gain B', 100.0, '%'),
#   'ap_align1_x': ('Align 1 X', 0.0, '%'),
#   'ap_beam_offset_x': ('Beam Offset X', 0.0, 'nm'),
#   'ap_black_detect': ('Black Threshold', 0.0, '%'),
#   'ap_asap_vbe1_temperature': ('ASAP VBE1 Temperature', 44.0, '°C'),
#   'ap_nominalext': ('Nominal extractor V', 3.0, 'kV'),
#   'ap_aperture_y': ('Aperture at Y', 0.0, '%'),
#   'ap_stage_high_m': ('Stage high M', 0.0, 'mm'),
#   'ap_water_temp': ('EO Temp', 24.5, '°C'),
#   'ap_user_max_eht': ('User Max EHT', 30.0, 'kV'),
#   'ap_ccd_illumination': ('CCD Illum.', 75.0, '%'),
#   'ap_fib_beam_shift_x': ('FIB Beam Shift X', 0.0, 'nm'),
#   'ap_scanrotation': ('Scan Rotation', 0.0, '°'),
#   'ap_fib_focus': ('FIB Focus', 0.0),
#   'ap_usermaxcurrent': ('Fil I (Usermax)', 4.0, 'A'),
#   'ap_magcalwidth': ('Mag Cal Actual Width', 0.0, 'nm'),
#   'ap_defect_id': ('Defect ID', 0),
#   'ap_line_posn_y': ('Line posn Y', 192),
#   'ap_wd_decl': ('Decl cal 1', 1.0),
#   'ap_mag_shift_upper_y': ('Shift Amp Upper Offset Y', 0.0),
#   'ap_si_enhancement': ('SmartImage Contrast', 30.0, '%'),
#   'ap_stage_vector_z': ('Stage vector Z', 0.0, '%'),
#   'ap_bgpl': ('BGPL', 10.0, 'mm'),
#   'ap_ar_objective': ('Argon Objective', 0, 'V'),
#   'ap_frame_int_count': ('Frames to Int.', 0),
#   'ap_beam_blank_aperture_x': ('Beam Blanked Aperture Pos X', 100.0, '%'),
#   'ap_alias_wd': ('Focus', 9.53, 'mm'),
#   'ap_stage_vector_r': ('Stage vector R', 0.0, '%'),
#   'ap_asap_vbe2_plus5v_analogue': ('ASAP VBE2 Plus5V Analogue', 0.0, 'V'),
#   'ap_eht_cal_24kv': ('EHT Cal@24KV', 24.0, 'kV'),
#   'ap_ppa_8': ('Pa 9', 0.0, 'nm'),
#   'ap_v_5': ('V 6', 0.0, 'nm'),
#   'ap_prof1_x1': ('Profile 1 X1', 0),
#   'ap_hrru_number': ('HRRU No.', 0),
#   'ap_fib_eht_target': ('FIB EHT Target', 0.0, 'kV'),
#   'ap_humidity': ('Humidity', 0.0, '%'),
#   'ap_esb_grid_max': ('ESB Grid Max', 1500, 'V'),
#   'ap_contrastz3': ('Contrast D', 22.3, '%'),
#   'ap_mill_item_elapsed_time': ('Mill Item Elapsed Time', 0, 'ms'),
#   'ap_stage_bias_voltage_high': ('Beam deceleration Volts', 0, 'V'),
#   'ap_magcal_lower_y': ('Calibrate Mag Lower Y', 0.0),
#   'ap_radial_3': ('Da 4', 0.0, 'nm'),
#   'ap_fib_condenser_actual': ('FIB Condenser actual', 0, 'V'),
#   'ap_ar_acc_actual': ('Argon Energy is', 0, 'V'),
#   'ap_scm': ('Specimen I', 0.0, 'pA'),
#   'ap_photo_number': ('Photo No.', 8339),
#   'ap_field_overlap': ('Field Overlap', 0.0, '%'),
#   'ap_spot': ('Spot signal', 0),
#   'ap_asap_dfe4_plus5v_analogue': ('ASAP DFE4 Plus5V Analogue', 0.0, 'V'),
#   'ap_cursor_width': ('Cursor Width', 0.0, 'nm'),
#   'ap_profile_w1': ('Profile Width 1', 0.0, 'nm'),
#   'ap_h_9': ('H 10', 0.0, 'nm'),
#   'ap_stage_delta_x': ('Stage Delta X', 0.0, 'mm'),
#   'ap_compu_tilt_error': ('Compu. Tilt Error', 0.0475),
#   'ap_fib_drift_x': ('FIB Drift X', 0.0, 'nm'),
#   'ap_purge_cycles': ('Purge cycles', 2),
#   'ap_c3': ('C3 Lens I', 72.03, 'mA'),
#   'ap_epd_low': ('EPD Low Limit', 0),
#   'ap_c2rem': ('C2 Rem', 0.0072),
#   'ap_fib_slice_angle': ('Slice Angle', 0.0, '°'),
#   'ap_zoompos_y': ('Zoom Posn Y', 192),
#   'ap_ppa_2': ('Pa 3', 0.0, 'nm'),
#   'ap_clip_limit': ('Clip Limit', 0),
#   'ap_liner_cal_at_100v': ('Liner cal @ 100V', 100, 'V'),
#   'ap_pixel_size': ('Pixel Size', 570.5, 'nm'),
#   'ap_stage_high_y': ('Stage high Y', 100.0, 'mm'),
#   'ap_stage_bias_wobble_amplitude': ('Stage bias wobble amplitude', 10, 'V'),
#   'ap_ion_collector_voltage': ('Collector Voltage', 0.0, 'kV'),
#   'ap_ar_pixel_size': ('Argon Pixel Size', 0.0, 'fm'),
#   'ap_mag0': ('Mag Z0', 1.0),
#   'ap_min_wd': ('Focus scan min', 1, 'mm'),
#   'ap_asap_dfe2_plus5v_digital': ('ASAP DFE2 Plus5V Digital', 5.33, 'V'),
#   'ap_manualext': ('Extractor V Target', 0.0, 'kV'),
#   'ap_h_3': ('H 4', 0.0, 'nm'),
#   'ap_image_pixel_size': ('Image Pixel Size', 570.5, 'nm'),
#   'ap_fib_aper_x_actual': ('FIB Aperture X Actual', 0),
#   'ap_fib_suppressor': ('FIB Suppressor Actual', 0, 'V'),
#   'ap_dc_max_attempts': ('Drift Max Tries', 10),
#   'ap_beam_shift_align_y': ('Beam Shift Align Y', 0.0, 'nm'),
#   'ap_brightness': ('Brightness', 52.4, '%'),
#   'ap_fisheye_quadriture': ('Fisheye quadriture', 1000),
#   'ap_gunshift_y': ('Gun Shift Y', -5.0, '%'),
#   'ap_red_raster_posn_x': ('Red.Raster Posn X', 256),
#   'ap_mag_gain_lower_x': ('Shift Amp Lower Gain X', 0.0),
#   'ap_stage_field_size_y': ('Stage field size Y', 0.0, 'mm'),
#   'ap_ar_v_int_actual': ('Argon V Int is', 0, 'V'),
#   'ap_contrast': ('Contrast', 21.9, '%'),
#   'ap_asap_cal_video_delay': ('Video Delay', 60.0, 'ms'),
#   'ap_height': ('Height', 438.2, 'µm'),
#   'ap_asap_dfe1_temperature': ('ASAP DFE1 Temperature', 0.0, '°C'),
#   'ap_eht_set_min': ('EHT Set minimum', 0.01, 'kV'),
#   'ap_asap_dfe4_temperature': ('ASAP DFE4 Temperature', 0.0, '°C'),
#   'ap_extcurrent': ('Ext I Monitor', 0.0, 'µA'),
#   'ap_aperture_x': ('Aperture at X', 0.0, '%'),
#   'ap_stage_low_m': ('Stage low M', 0.0, 'mm'),
#   'ap_fcf_setting': ('FCF Setting', 0.0, '%'),
#   'ap_radial_area_3': ('Db 4', 0.0, 'nm²'),
#   'ap_fib_stigmator_y': ('FIB Stig Y', 0.0, '%'),
#   'ap_frame_counter': ('Frame Counter', 5578),
#   'ap_fib_fg_fil_current_actual': ('Flood Gun Filament Actual', 0, 'µA'),
#   'ap_ep_target': ('EP Target', 30, 'Pa'),
#   'ap_wd': ('WD', 9.53, 'mm'),
#   'ap_hsync_delay': ('HSync delay', 100.0, 'ms'),
#   'ap_frame_time': ('Cycle Time', 33.1, 'Secs'),
#   'ap_fib_gun_pressure': ('FIB Gun Pressure', 0.0, 'mbar'),
#   'ap_line_posn_x': ('Line posn X', 0),
#   'ap_mag_shift_upper_x': ('Shift Amp Upper Offset X', 0.0),
#   'ap_compu_tilt_offset': ('Compu. Tilt Offset', -0.187, 'mm'),
#   'ap_stage_vector_y': ('Stage vector Y', 0.0, '%'),
#   'ap_ar_condenser_actual': ('Argon Condenser is', 0, 'V'),
#   'ap_frame_average_count': ('Frames to average', 47),
#   'ap_aperture_at_fisheye_y': ('Aperture value at FishEye Y', 0.0, '%'),
#   'ap_dual_mag_slope': ('Dual Mag Gain X', 670.0),
#   'ap_stage_goto_t': ('Stage goto T', 20.0, '°'),
#   'ap_asap_vbe1_plus5v_analogue': ('ASAP VBE1 Plus5V Analogue', 5.02, 'V'),
#   'ap_chamber_pressure': ('Chamber', 0.0, 'Pa'),
#   'ap_eht_cal_10kv': ('EHT Cal@10KV', 10.0, 'kV'),
#   'ap_ppa_7': ('Pa 8', 0.0, 'nm'),
#   'ap_v_4': ('V 5', 0.0, 'nm'),
#   'ap_stage_delta_m': ('Stage Delta M', 0.0, 'mm'),
#   'ap_print_number': ('Print No.', 0),
#   'ap_esd_excitation': ('ESD Excitation', 0.0, '%'),
#   'ap_peltier_target': ('Peltier Target', 20.0, '°C'),
#   'ap_esb_grid': ('ESB Grid', 0, 'V'),
#   'ap_contrastz2': ('Contrast C', 22.3, '%'),
#   'ap_mill_item_total_time': ('Mill Item Total Time', 0, 'ms'),
#   'ap_stig_y': ('Stigmation Y', -10.3, '%'),
#   'ap_ppb_3': ('Pb 4', 0.0, '°'),
#   'ap_magcal_lower_x': ('Calibrate Mag Lower X', 0.0),
#   'ap_radial_2': ('Da 3', 0.0, 'nm'),
#   'ap_system_vac': ('System Vacuum', 1.01e-05, 'mbar'),
#   'ap_ar_acc': ('Argon Energy', 0, 'V'),
#   'ap_scan_offset_y': ('Scan Y cal.', 0),
#   'ap_asap_dfe3_plus5v_analogue': ('ASAP DFE3 Plus5V Analogue', 0.0, 'V'),
#   'ap_stage_low_t': ('Stage low T', -10.0, '°'),
#   'ap_mag_gain_y': ('Mag Gain Cal Y', 859.0),
#   'ap_h_8': ('H 9', 0.0, 'nm'),
#   'ap_stage_low_r': ('Stage low R', -380.0, '°'),
#   'ap_dc_shift_y': ('Aperture Align Y', 8.0, '%'),
#   'ap_fib_sem_angle': ('FIB SEM Angle', 54.0, '°'),
#   'ap_epd_high': ('EPD High Limit', 0),
#   'ap_c2cal': ('C2 Cal', 1.085),
#   'ap_fib_slice_height': ('Slice Height', 0.0, 'nm'),
#   'ap_zoompos_x': ('Zoom Posn X', 128),
#   'ap_ppa_1': ('Pa 2', 0.0, 'nm'),
#   'ap_tilt_align_y': ('Tilt Align Y', 0.0, '%'),
#   'ap_fib_min_autoheat_current': ('FIB Min. Autoheat Current', 0, 'µA'),
#   'ap_chamber_pressure_detailed': ('Chamber Pressure Detailed', 0.0, 'Pa'),
#   'ap_stage_high_x': ('Stage high X', 80.0, 'mm'),
#   'ap_landing_energy': ('Landing energy', 10.0, 'kV'),
#   'ap_collector_bias': ('Collector Bias', 300, 'V'),
#   'ap_max_wd': ('Focus scan max', 40, 'mm'),
#   'ap_asap_dfe1_plus5v_digital': ('ASAP DFE1 Plus5V Digital', 0.0, 'V'),
#   'ap_test_val': ('Test Val', 0.0),
#   'ap_h_2': ('H 3', 0.0, 'nm'),
#   'ap_radial_area_1': ('Db 2', 0.0, 'nm²'),
#   'ap_fib_aperture_align_y': ('FIB Aper.Align Y', 0),
#   'ap_fib_fil_v_target': ('FIB Fil V target', 0.0, 'V'),
#   'ap_dc_min_conf': ('Drift Min Conf', 50.0, '%'),
#   'ap_beam_shift_align_x': ('Beam Shift Align X', 0.0, 'nm'),
#   'ap_fisheye_orthog': ('Fisheye Orthog', 180.0, '°'),
#   'ap_gunshift_x': ('Gun Shift X', 6.9, '%'),
#   'ap_contrastz1': ('Contrast B', 22.3, '%'),
#   'ap_focus_rotation_comp': ('Focus Rotation comp.', -0.009, 'kV'),
#   'ap_mag_gain_upper_y': ('Shift Amp Upper Gain Y', 0.0),
#   'ap_fib_track_wd_delta': ('FIB Track WD Delta', 0.0, 'nm'),
#   'ap_stage_field_size_x': ('Stage field size X', 0.0, 'mm'),
#   'ap_ar_v_int': ('Argon V Int', 0, 'V'),
#   'ap_offset': ('Offset A', 0.0, '%'),
#   'ap_width': ('Width', 584.2, 'µm'),
#   'ap_asap_mb_temperature': ('ASAP MB Temperature', 41.0, '°C'),
#   'ap_mag_shift_y': ('Mag Shift Cal Y', -20.0),
#   'ap_pirani_pressure': ('Pirani Pressure', 0.0, 'mbar'),
#   'ap_actuallens': ('Liner Tube', 0.0, 'kV'),
#   'ap_aperture_align_y': ('Aperture Align Y', 0.0, '%'),
#   'ap_stage_goto_m': ('Stage goto M', 0.0, 'mm'),
#   'ap_ppb_6': ('Pb 7', 0.0, '°'),
#   'ap_v_9': ('V 10', 0.0, 'nm'),
#   'ap_radial_area_2': ('Db 3', 0.0, 'nm²'),
#   'ap_fib_fg_serial_number': ('Flood Gun Serial Number', 0),
#   'ap_fib_stigmator_x': ('FIB Stig X', 0.0, '%'),
#   'ap_stage_at_m': ('Stage at M', 0.0, 'mm'),
#   'ap_stage_at_z': ('Stage at Z', 29.301, 'mm'),
#   'ap_stage_at_y': ('Stage at Y', 29.727, 'mm'),
#   'ap_actualcurrent': ('Fil I', 3.294, 'A'),
#   'ap_stage_at_x': ('Stage at X', 36.8308, 'mm'),
#   'ap_actualkv': ('EHT', 10.0, 'kV'),
#   'ap_stage_at_t': ('Stage at T', 20.0, '°'),
#   'ap_sample_at_y': ('Sample at Y', 0.0),
#   'ap_stage_at_r': ('Stage at R', 37.4, '°'),
#   'ap_sample_at_x': ('Sample at X', 0.0),
#   'ap_time': ('Time', '11:10:04'),
#   'ap_date': ('Date', '14 Mar 2022'),
#   'sv_group_id': ('Group ID', ''),
#   'sv_version': ('Version', 'V06.04.00.00 : 16-Apr-18'),
#   'sv_image_type': ('Image Type', ''),
#   'sv_serial_number': ('Serial No.', 'EVO 10-8001013820'),
#   'sv_user_text': ('User Text', ''),
#   'sv_operator': ('Operator', ''),
#   'sv_user_name': ('User Name', 'UWE'),
#   'sv_file_name': ('File Name', 'Nozzle Chip RIE KOH10.tif'),
#   'sv_image_path': ('Images', 'd:\\bildtransfer\\uwe\\'),
#   'sv_sample_id': ('Sample ID', '')}}

# %% [markdown]
# The metadata is extracted from this next test image in exactly the same way with the exact same variable names.

# %% [markdown]
# # NK_PA07_1-4_KA-W 136980-Zeiss-IAM ESS.tif
#
# Zeiss Supra 55 FE-SEM Instrument

# %%
f = hs.load(images[2])
Zeiss_Supra = f.original_metadata.as_dictionary()

del Zeiss_Supra['ColorMap']
del Zeiss_Supra['34119']

Zeiss_Supra
# Out:
# {'NewSubfileType': <FILETYPE.UNDEFINED: 0>,
#  'ImageWidth': 2048,
#  'ImageLength': 1536,
#  'BitsPerSample': 8,
#  'Compression': <COMPRESSION.NONE: 1>,
#  'PhotometricInterpretation': <PHOTOMETRIC.PALETTE: 3>,
#  'StripOffsets': (100950,),
#  'Orientation': <ORIENTATION.TOPLEFT: 1>,
#  'SamplesPerPixel': 1,
#  'RowsPerStrip': 4294967295,
#  'StripByteCounts': (3145728,),
#  'XResolution': (1, 1),
#  'YResolution': (1, 1),
#  'ResolutionUnit': <RESUNIT.NONE: 1>,
#  'SampleFormat': <SAMPLEFORMAT.UINT: 1>,
#  'CZ_SEM': {'': (0,
#    0,
#    0,
#    1.1165e-07,
#    1000.0,
#    6,
#    4000.0,
#    2.28,
#    2e-07,
#    0.008856386,
#    1,
#    1.1165e-07,
#    1000.0,
#    6,
#    4000.0,
#    2.28,
#    2e-07,
#    0.008856386,
#    2,
#    1.1165e-07,
#    1000.0,
#    6,
#    4000.0,
#    2.28,
#    2e-07,
#    0.008856386,
#    3,
#    1.1165e-07,
#    1000.0,
#    6,
#    4000.0,
#    2.28,
#    2e-07,
#    0.008856386,
#    778),
#   'dp_vent_invalid_reason': ('Vent inhibit', 'Beam Present'),
#   'dp_optimode': ('OptiBeam Mode', 'Resolution'),
#   'dp_fixed_aperture': ('VP Aperture', False),
#   'dp_bsd_autolevel_mode': ('BSD Autolevel Mode', 'Normal'),
#   'dp_recipe': ('Recipe', 'Idle'),
#   'dp_implied_detector': ('Signal B', 'SE2'),
#   'dp_4qbsd_visible': ('BSD Fast', False),
#   'dp_opt_aperture': ('Opt.Aperture', 2),
#   'dp_track_z': ('Track Z', True),
#   'dp_epse_electrode': ('EPSE Electrode', 'Ring'),
#   'dp_c3_rot_correction': ('C3 Rot Corrn.', True),
#   'dp_fisheye_mode': ('Fisheye Mode', False),
#   'dp_stage_tilted': ('Stage Tilt', 'in X'),
#   'dp_ar_gun': ('Argon Gun', 'Absent'),
#   'dp_column_isolated': ('Column Isolated', False),
#   'dp_mixing': ('Mixing', False),
#   'dp_fib_fg_mode_target': ('Flood Gun Mode Target', 'Low Energy Mode'),
#   'dp_stem_gain': ('STEM Gain', 'Low'),
#   'dp_high_current': ('High Current', True),
#   'dp_dwell_time': ('Dwell Time', 100, 'ns'),
#   'dp_si_noise_reduction': ('SmartImage Noise Reduction', False),
#   'dp_right_frozen': ('Right Frozen', True),
#   'dp_fib_fg_blanked': ('Flood Gun Blanked', False),
#   'dp_fast_mode': ('Fast Mode', False),
#   'dp_compucentric_mode': ('Compuc. Mode', False),
#   'dp_anode_aperture_changer': ('Anode Aperture Changer', 'Absent'),
#   'dp_gis_shutdown_state': ('GIS Shutdown State', 'Normal'),
#   'dp_fib_column': ('FIB Column', 'None'),
#   'dp_tilted': ('Stage Tilted', False),
#   'dp_fib_suppressor': ('FIB Suppressor is', 'Absent'),
#   'dp_vpse': ('VPSE detector', 'Absent'),
#   'dp_crosshairs': ('Crosshairs', False),
#   'dp_double_deflection_state': ('Double Deflection State', False),
#   'dp_gate_valve_position': ('WDX Gate Valve posn', 'OK'),
#   'dp_hese2_fitted': ('HE-SE2 Fitted', False),
#   'dp_ep_mode': ('EP Gas', 'Air'),
#   'dp_condenser': ('Condenser Normal', 'Normal'),
#   'dp_implied_invert': ('Invert B', False),
#   'dp_4qbsd_gain': ('BSD Gain', 'Very High'),
#   'dp_fib_gun_valve': ('FIB Gun Valve', 'Closed'),
#   'dp_aperture_state': ('Aperture', 'Clean'),
#   'dp_electron_counting': ('Electron Counting', False),
#   'dp_saturate_at': ('Saturate at', 'Second peak'),
#   'dp_stage_angle': ('Stage Angle corrn.', True),
#   'dp_image_store': ('Store resolution', '2048 * 1536'),
#   'dp_field_mode': ('Field Mode', False),
#   'dp_coolstage_type': ('CoolStage Type', 'Cold'),
#   'dp_best_aperture': ('Best Aperture', True),
#   'dp_fib_fg_mode_actual': ('Flood Gun Actual Mode', 'Low Energy Mode'),
#   'dp_stem_auto': ('STEM Auto', False),
#   'dp_stage_init': ('Stage Initialised', True),
#   'dp_cc_on_gis_channel': ('GIS Channel with CC', 'None'),
#   'dp_channel': ('Display', 0),
#   'dp_fib_fg_fitted': ('Flood Gun Fitted', False),
#   'dp_bsd_mode': ('BSD Mode', 'Compo'),
#   'dp_fib_mode': ('FIB Mode', 'Imaging'),
#   'dp_nano_tips': ('Nano Tips', 'Absent'),
#   'dp_bsd_n_on_p': ('BSD Invert', False),
#   'dp_mgs_evac_state': ('MGS Evacuation State', False),
#   'dp_use_epd': ('Use End Point Detection', False),
#   'dp_mains_sync': ('Mains Sync', False),
#   'dp_fib_pneumatic_prep_state': ('FIB preparation for pneumatic',
#    'FIB ready for system vent'),
#   'dp_frozen': ('Image', 'Frozen'),
#   'dp_filament_type': ('Filament Type', 'FE FEI'),
#   'dp_sample_holder': ('Sample Holder', 'Carousel 8x6.5mm'),
#   'dp_high_resolution_mode': ('High Resolution Mode', False),
#   'dp_fib_scan': ('FIB Scan', 'Continuous'),
#   'dp_beam_blanked': ('Beam Blanked', True),
#   'dp_cc_type': ('CC Type', 'None'),
#   'dp_4qbsd': ('BSD', 'Present'),
#   'dp_image_saved': ('Image saved', True),
#   'dp_mag_range': ('Mag Range', 2),
#   'dp_user_align': ('User Align', False),
#   'dp_zone': ('Zone', 0),
#   'dp_fil_blown': ('Filament blown', False),
#   'dp_humidity_valve': ('Humidity Valve', 'Closed'),
#   'dp_fib_external_polarity': ('FIB External Polarity', 0),
#   'dp_peltier_photo': ('Peltier Photo', False),
#   'dp_main_detector': ('Control', 'Signal A'),
#   'dp_invert': ('Invert A', False),
#   'dp_fib_fg_remoting_target': ('Remoting Target', 'Flood Gun Normal'),
#   'dp_stage_is': ('Stage Is', 'Idle'),
#   'dp_fib_present': ('FIB Present', False),
#   'dp_peltier_type': ('Peltier Type', 'Deben'),
#   'dp_signalaz0': ('Signal A Z0', 'SE2'),
#   'dp_freeze_on': ('Freeze on', 'End Frame'),
#   'dp_fib_blanked': ('FIB Blanked', False),
#   'dp_stage_bias_high': ('Beam deceleration', False),
#   'dp_epse_gain': ('EPSE Gain', 'Low'),
#   'dp_end_detection': ('End Detection', False),
#   'dp_vac_comms_fail': ('Vac comms fail', False),
#   'dp_bsd_auto': ('BSD Auto Range', True),
#   'dp_pneumatic_device_in_use': ('Pneumatic Device in use', 'None'),
#   'dp_fib_wide_view': ('FIB Wide View', False),
#   'dp_anode': ('Anode Spacer', 'High KV'),
#   'dp_use_ref_mag': ('Reference Mag', 'Polaroid 545'),
#   'dp_beamsleeve_position': ('Beam sleeve', 'Out'),
#   'dp_user_mag_cal': ('User Calibration', False),
#   'dp_safe_stem_valid': ('Safe STEM Valid', False),
#   'dp_4qbsd_q5': ('Q5', False),
#   'dp_scd_gain': ('SCD Gain', 'Low'),
#   'dp_all_zones': ('All Zones', False),
#   'dp_detector_channel': ('Signal A', 'SE2'),
#   'dp_eht_tripped': ('EHT tripped', False),
#   'dp_flood_state': ('Flood State', 'Idle'),
#   'dp_extractor_trip': ('Extractor Trip', False),
#   'dp_bsd_fast_scan': ('BSD Fast Scan', False),
#   'dp_inlens_duo_mode': ('InlensDuo Mode', 'SE'),
#   'dp_auto_video': ('Auto BC', False),
#   'dp_fib_fg_remoting_actual': ('Flood Gun Remoting Actual',
#    'Flood Gun Normal'),
#   'dp_signalaz1': ('Signal A Z1', 'InLens'),
#   'dp_stage_bias_hv_fitted': ('Variable stage bias fitted', False),
#   'dp_epse_auto': ('EPSE Auto Range', False),
#   'dp_stage_comms_fail': ('Stage comms fail', False),
#   'dp_optiprobe': ('OptiProbe', False),
#   'dp_cls_valve': ('C.L.S.Valve', 'Closed'),
#   'dp_newfilament': ('New Filament', False),
#   'dp_image_detect': ('Image Detect', 'Black'),
#   'dp_custom_holder': ('Custom Holder', False),
#   'dp_zoom': ('Zoom', False),
#   'dp_scd_auto': ('SCD Auto Range', False),
#   'dp_ext_scan_control': ('Ext.Scan Control', False),
#   'dp_detector_type': ('Detector', 'SE2'),
#   'dp_eht_reset': ('EHT spurious reset', False),
#   'dp_stem_q4': ('STEM Q4', False),
#   'dp_fib_fg_extractor_target': ('Extractor Target State', False),
#   'dp_gemini_large_beamshift': ('Gemini large beam shift', False),
#   'dp_jazz_gain': ('Jazz Gain', 'Low'),
#   'dp_monitor': ('Monitor', '19/21 inch'),
#   'dp_freeze_status': ('Freeze', 'Idle'),
#   'dp_fib_extractor_conflict': ('FIB Extractor Conflict', False),
#   'dp_stage_bias_carassel_fitted': ('Beam deceleration carousel', False),
#   'dp_epse_bandwidth': ('EPSE Bandwidth', 'DC'),
#   'dp_stage_bias': ('Stage bias low voltage', False),
#   'dp_stigbalance': ('Stig Balance', False),
#   'dp_frame_grabber': ('Frame Grabber', 'Matrix Titan'),
#   'dp_fib_ext_scan_select': ('FIB Ext Scan Select', 'Ext 0'),
#   'dp_beamsleeve_fitted': ('Beam sleeve fitted', False),
#   'dp_vpse2': ('VPSE-G3 Fitted', 'Absent'),
#   'dp_4qbsd_q1': ('Q1', 'Normal'),
#   'dp_fib_lock_mag': ('FIB Lock Mags', False),
#   'dp_freeze_blanks': ('Freeze Blanks', True),
#   'dp_windowing': ('Windowing', False),
#   'dp_partial_vent': ('Partial Vent on Standby', False),
#   'dp_scd_bandwidth': ('SCD Bandwidth', 'DC'),
#   'dp_calibration': ('Calibration', 'Disabled'),
#   'dp_stem_q1': ('STEM Q1', False),
#   'dp_eht_vac_ready': ('EHT Vac ready', True),
#   'dp_stem_q5': ('STEM Q5', False),
#   'dp_fib_fg_extractor_actual': ('Flood Gun Extractor Actual State', False),
#   'dp_bakeout_full': ('full service bakeout', False),
#   'dp_water_ok': ('Water OK', True),
#   'dp_low_mag': ('Low Mag', False),
#   'dp_vent_inhibited': ('Venting inhibited', True),
#   'dp_fib_probe': ('FIB Probe', 'Undefined'),
#   'dp_lut_mode': ('Display LUT mode', 'Normal'),
#   'dp_optibeam': ('OptiBeam Is', False),
#   'dp_scangen_type': ('ScanGen Type', 'L-REM'),
#   'dp_fib_ext_scan_mode': ('FIB Ext Scan Mode', False),
#   'dp_final_lens': ('Final Lens', '1500: Gemini'),
#   'dp_ehtcommsfail': ('EHT Comms Fail', False),
#   'dp_scangen': ('Scan Gen', 'Present'),
#   'dp_num_regions': ('Num. Regions', 0),
#   'dp_fib_error': ('FIB Error', 'None'),
#   'dp_gis_heating_status_1': ('GIS Heating Status Channel 1',
#    'GIS Not Heating'),
#   'dp_quattro_bandwidth': ('BSD Bandwidth', 'DC'),
#   'dp_4qbsd_q2': ('Q2', 'Normal'),
#   'dp_dynfocus': ('Dyn.Focus', False),
#   'dp_supervisor': ('Supervisor', 'Enabled'),
#   'dp_colour_mode': ('Colour Mode', False),
#   'dp_tilt_correction': ('Tilt Corrn.', False),
#   'dp_spot': ('Spot', False),
#   'dp_fixed_aperture2': ('EP Aperture', 'None fitted'),
#   'dp_detector_fast_scan': ('Noise reduction for fast scanspeeds', False),
#   'dp_ion_detector_mode': ('SESI Mode', 'SE'),
#   'dp_fisheye_fitted': ('Fish-Eye Fitted', True),
#   'dp_stem_q2': ('STEM Q2', False),
#   'dp_pixel_size': ('Pix Size state', 'calibrated'),
#   'dp_ebbu_mode': ('Beam Blanker Mode', 'Blanked'),
#   'dp_fib_image_probe': ('FIB Image Probe', 'Undefined'),
#   'dp_ar_mill': ('Argon Mill', False),
#   'dp_fib_mag_range': ('FIB Mag Range', 0),
#   'dp_user_level': ('User Level', 'Expert'),
#   'dp_ar_scan': ('Argon Scan', False),
#   'dp_hp_status': ('Chamber Status', 'Power Up'),
#   'dp_column_type': ('Column', 1500),
#   'dp_large_beamshift': ('Large Beam Shift', False),
#   'dp_ar_mfcvalve': ('Argon MFC Valve', 'Closed'),
#   'dp_contrast_enhancement': ('Contrast Enhanced', False),
#   'dp_4qbsd_q3': ('Q3', 'Normal'),
#   'dp_scan_rot': ('Scan Rot', True),
#   'dp_dc_sem_state': ('Sem drift status', 'Not Available'),
#   'dp_line_scan': ('Line Scan', False),
#   'dp_tandem_deceleration': ('Tandem deceleration', False),
#   'dp_signalaz2': ('Signal A Z2', 'InLens'),
#   'dp_scm_range': ('SCM range', '3->10 pA'),
#   'dp_fib_fg_floodgun_type': ('Flood Gun Type', 'Flood Gun Unknown Type'),
#   'dp_stem_q3': ('STEM Q3', False),
#   'dp_mag_cal': ('Mag State', 'calibrated'),
#   'dp_hv_at_shutdown': ('Go to HV @ Shutdown', False),
#   'dp_scm_status': ('SCM Status', False),
#   'dp_si_source': ('SI source-hidden', 0),
#   'dp_conjugate': ('OptiBeam conjugate', False),
#   'dp_fib_fg_status': ('Flood Gun Status', False),
#   'dp_vp_optibeam': ('VP Optibeam', False),
#   'dp_condenser_reversed': ('Condenser Reversed', False),
#   'dp_z0': ('Zone 0', 'Frozen'),
#   'dp_fib_mill_probe': ('FIB Milling Probe', 'Undefined'),
#   'dp_scint': ('Scint.', True),
#   'dp_optiresmode': ('OptiBeam Res Mode', 'manual'),
#   'dp_jazz_bandwidth': ('Jazz Bandwidth', 'Low'),
#   'dp_igp_enabled': ('IGP Enabled', True),
#   'dp_gate_valve': ('WDX Gate valve', 'Closed'),
#   'dp_peltier': ('Peltier', False),
#   'dp_output_reduction': ('Output Reduction', 1),
#   'dp_4qbsd_q4': ('Q4', 'Normal'),
#   'dp_aperture': ('Aperture No.', 5),
#   'dp_stage_bias_mode': ('Stage bias mode', 'contrast mode'),
#   'dp_sem': ('Sem', 'Supra 55'),
#   'dp_scan_orthog': ('Scan Orthog', True),
#   'dp_display_channels': ('Channels', 1),
#   'dp_dual_monitor': ('Dual Monitor', False),
#   'dp_signalaz3': ('Signal A Z3', 'InLens'),
#   'dp_c3_rot_sign': ('C3 Rotn Sign', '+'),
#   'dp_stem_fast': ('STEM Fast', False),
#   'dp_out_dev': ('Output dev', '19/21 inch display'),
#   'dp_user': ('User', 'Idle'),
#   'dp_fib_track_wd': ('FIB Tracking WD', False),
#   'dp_fib_fg_interlock': ('Flood Gun Interlock', False),
#   'dp_low_kv_lens': ('Low KV Lens', 'Absent'),
#   'dp_z1': ('Zone 1', 'Frozen'),
#   'dp_cc_status': ('CC Status', False),
#   'dp_fib_gun_state': ('FIB Gun State', False),
#   'dp_ar_gun_state': ('Argon Gun is', False),
#   'dp_out_type': ('Output To', 'Display/File'),
#   'dp_column_chamber_valve': ('Column Chamber valve', 'Open'),
#   'dp_column_pumping': ('Column pumping', 'Ready'),
#   'dp_scanrate': ('Scan Speed', 9),
#   'dp_left_frozen': ('All Frozen', True),
#   'dp_input_lut_mode': ('Input LUT Mode', 'Transparent'),
#   'dp_operating_mode': ('Operating Mode', 'Normal'),
#   'dp_gis_channel': ('GIS Channel', 'None'),
#   'dp_fib_imaging': ('FIB Imaging', 'SEM'),
#   'dp_c3reversal': ('C3 Reversal', 'Normal'),
#   'dp_vac_mode': ('Vacuum Mode', 'High Vacuum'),
#   'dp_column_mode': ('Column Mode', 'High Resolution'),
#   'dp_stem_seg_mode': ('STEM Seg. Mode', False),
#   'dp_calmode': ('Cal Mode', False),
#   'dp_runupstate': ('Beam State', 'Beam On'),
#   'dp_noise_reduction': ('Noise Reduction', 'Pixel Avg.'),
#   'dp_optibeam_state': ('OptiBeam', False),
#   'dp_vacstatus': ('Vac Status', 'Ready'),
#   'ap_fib_fg_emission_target': ('Flood Gun Emission target', 0.0, 'µA'),
#   'ap_fib_shift_correction_y': ('FIB Shift Correction Y', 0.0, 'nm'),
#   'ap_mag': ('Mag', '1.00 K X'),
#   'ap_line_time': ('Line Time', 52.53, 'ms'),
#   'ap_fib_mag_fine_gain_y': ('FIB Mag fine gain Y', 0.0),
#   'ap_spot_posn_y': ('Spot at Y', 192),
#   'ap_scanorthog_lower': ('Orthogonality Lower', 0.0, '°'),
#   'ap_angular_3': ('Aa 4', 0.0, 'kV'),
#   'ap_stage_vector_x': ('Stage vector X', 0.0, '%'),
#   'ap_detector_bandwidth_offset': ('Det BW Offset', 0),
#   'ap_ar_condenser': ('Argon Condenser', 0, 'V'),
#   'ap_aperture_at_fisheye_x': ('Aperture value at FishEye X', 0.0, '%'),
#   'ap_minmag': ('Min Mag', 23, 'X'),
#   'ap_stage_goto_r': ('Stage goto R', 19.0, '°'),
#   'ap_asap_dfe4_minus5v_analogue': ('ASAP DFE4 Minus5V Analogue', 0.0, 'V'),
#   'ap_hp_target': ('VP Target', 10, 'Pa'),
#   'ap_eht_cal_100': ('EHT Cal@0.1KV', 113, 'V'),
#   'ap_ppa_6': ('Pa 7', 0.0, 'nm'),
#   'ap_v_3': ('V 4', 0.0, 'nm'),
#   'ap_stage_delta_r': ('Stage Delta R', 0.0, '°'),
#   'ap_file_number': ('File No', 50449),
#   'ap_esd_lower_y': ('ESD Lower Y', 0.0, '%'),
#   'ap_free_wd': ('Free WD', 8.9, 'mm'),
#   'ap_brightnessz3': ('Brightness D', 49.0, '%'),
#   'ap_fm_quadriture': ('Field Mode Quadriture', -1),
#   'ap_tilt_angle': ('Tilt Angle', 0.0, '°'),
#   'ap_mill_list_elapsed_time': ('Mill List Elapsed Time', 0, 'ms'),
#   'ap_stig_x': ('Stigmation X', -0.8, '%'),
#   'ap_ppb_2': ('Pb 3', 0.0, '°'),
#   'ap_magcal_upper_y': ('Calibrate Mag Upper Y', 0.0),
#   'ap_radial_1': ('Da 2', 0.0, 'nm'),
#   'ap_reduced_raster_width': ('Reduced Raster Width', 512),
#   'ap_vpse2_bias': ('VPSE Bias', 60.0, '%'),
#   'ap_stage_low_z': ('Stage low Z', 0.0, 'mm'),
#   'ap_ar_mag': ('Argon Magnification', 0, 'X'),
#   'ap_ar_shift_ratio_y': ('Argon Shift Ratio Y', 0.0),
#   'ap_scan_offset_x': ('Scan X cal.', 0),
#   'ap_asap_dfe2_plus5v_analogue': ('ASAP DFE2 Plus5V Analogue', 0.0, 'V'),
#   'ap_stage_high_t': ('Stage high T', 70.0, '°'),
#   'ap_profile_top': ('Profile Top', 300),
#   'ap_mag_gain_x': ('Mag Gain Cal X', 700.0),
#   'ap_h_7': ('H 8', 0.0, 'nm'),
#   'ap_spacer_thickness': ('Spacer Thickness', 0.0, 'mm'),
#   'ap_stage_high_r': ('Stage high R', 380.0, '°'),
#   'ap_fib_condenser': ('FIB Condenser', 0, 'V'),
#   'ap_fib_fg_fil_current_target': ('Flood Gun Filament Target', 0, 'µA'),
#   'ap_dc_shift_x': ('Aperture Align X', 0.0, '%'),
#   'ap_sem_level_at_tilt': ('SEM Level @', 0.0, '°'),
#   'ap_vac_ready_at': ('Vac Ready @', 5e-05, 'mbar'),
#   'ap_c1rem': ('C1 Rem', 0.0105),
#   'ap_fib_slice_width': ('Slice Width', 0.0, 'nm'),
#   'ap_beamshift_y': ('Beam Shift Y', -0.0, '%'),
#   'ap_ppa_0': ('Pa 1', 0.0, 'nm'),
#   'ap_tilt_align_x': ('Tilt Align X', 0.0, '%'),
#   'ap_stage_xm_r': ('Stage X+M Rotation', 0.0, '°'),
#   'ap_si_topography': ('SmartImage Topography', 0.0, '%'),
#   'ap_stage_at_field_y': ('Stage at field Y', 1),
#   'ap_ar_angle': ('Argon Column Angle', 0.0, '°'),
#   'ap_asap_dfe3_temperature': ('ASAP DFE3 Temperature', 0.0, '°C'),
#   'ap_test_n': ('Test No.', 0),
#   'ap_h_1': ('H 2', 0.0, 'nm'),
#   'ap_radial_area_0': ('Db 1', 0.0, 'nm²'),
#   'ap_opt_semiangle': ('Opt. Semi Angle', 0.0, 'µrad'),
#   'ap_fib_aperture_align_x': ('FIB Aper.Align X', 0),
#   'ap_fib_fil_i_target': ('FIB Fil I Target', 0, 'µA'),
#   'ap_dc_max_pix_error': ('Drift Max.Pix.Error', 1),
#   'ap_inlens_duo_grid_actual': ('InlensDuo Grid is', 0, 'V'),
#   'ap_fisheye_angle': ('Fisheye Angle', 0.0, '°'),
#   'ap_contrastz0': ('Contrast A', 28.4, '%'),
#   'ap_dual_mag_offset_y': ('Dual Mag Offset Y', 2.0),
#   'ap_mag_decl': ('Mag scaling decel', 1.0),
#   'ap_mag_gain_upper_x': ('Shift Amp Upper Gain X', 0.0),
#   'ap_holder_length': ('Holder Length', 0.0, 'mm'),
#   'ap_stage_fields_y': ('Stage fields Y', 1),
#   'ap_fib_source_lifetime': ('FIB Source Lifetime', 0.0, 'µAh'),
#   'ap_ar_gas_flow_actual': ('Argon Gas Flow is', 0.0, '%'),
#   'ap_gain': ('Gain A', 100.0, '%'),
#   'ap_beam_blank_gun_y': ('Beam Blanked Gun Pos Y', 100.0, '%'),
#   'ap_conjugate': ('Conjugate posn.', -164.0, 'mm'),
#   'ap_asap_scan_offset_y': ('Scan Offset Y', 0),
#   'ap_mag_shift_x': ('Mag Shift Cal X', -19.0),
#   'ap_jazz_back_grid': ('Back Grid', 0, 'V'),
#   'ap_actualsupp': ('Suppressor V', 300, 'V'),
#   'ap_aperture_align_x': ('Aperture Align X', -7.0, '%'),
#   'ap_ppb_5': ('Pb 6', 0.0, '°'),
#   'ap_v_8': ('V 9', 0.0, 'nm'),
#   'ap_prof2_x2': ('Profile 2 X2', 0),
#   'ap_fib_magnification': ('FIB Mag', 0, 'X'),
#   'ap_fib_fg_emission_actual': ('Flood Gun Emission Actual', 0.0, 'µA'),
#   'ap_fib_shift_correction_x': ('FIB Shift Correction X', 0.0, 'nm'),
#   'ap_iprobe': ('I Probe', 200.0, 'nA'),
#   'ap_fcf_tilt': ('FCF Tilt Angle', 0.0, '°'),
#   'ap_fib_mag_fine_gain_x': ('FIB Mag fine gain X', 0.0),
#   'ap_stage_xm_angle': ('Stage X+M Angle', 8.0, '°'),
#   'ap_spot_posn_x': ('Spot at X', 256),
#   'ap_scanorthog_upper': ('Orthogonality Upper', 0.0, '°'),
#   'ap_angular_2': ('Aa 3', 0.0, 'kV'),
#   'ap_stage_goto_z': ('Stage goto Z', 34.121, 'mm'),
#   'ap_ar_discharge_current': ('Argon Discharge I is', 0.0, 'µA'),
#   'ap_gun_at_fisheye_y': ('Gun Value at FishEye mode Y', 0.0, '%'),
#   'ap_spotsize': ('Spot Size', 1),
#   'ap_asap_dfe3_minus5v_analogue': ('ASAP DFE3 Minus5V Analogue', 0.0, 'V'),
#   'ap_ppa_5': ('Pa 6', 0.0, 'nm'),
#   'ap_v_2': ('V 3', 0.0, 'nm'),
#   'ap_stage_delta_t': ('Stage Delta T', 0.0, '°'),
#   'ap_specimen_height': ('Specimen Height', 0, 'mm'),
#   'ap_esd_lower_x': ('ESD Lower X', 0.0, '%'),
#   'ap_fib_emission_current': ('FIB Emission I', 0.0, 'µA'),
#   'ap_fib_stig_y_centre_y': ('FIB Stig Y Centre Y', 0.0),
#   'ap_brightnessz2': ('Brightness C', 49.0, '%'),
#   'ap_fm_orthog': ('Field Mode Orthog', -1.0, '°'),
#   'ap_tilt_axis': ('Tilt Axis', 90.0, '°'),
#   'ap_mill_list_total_time': ('Mill List Total Time', 0, 'ms'),
#   'ap_apertureposn_y': ('Aperture Posn Y', 1.0, 'mm'),
#   'ap_ppb_1': ('Pb 2', 0.0, '°'),
#   'ap_magcal_upper_x': ('Calibrate Mag Upper X', 0.0),
#   'ap_radial_0': ('Da 1', 0.0, 'nm'),
#   'ap_epse_bias': ('EPSE Bias', 0.0, '%'),
#   'ap_profile_w': ('Profile width', 0.0, 'nm'),
#   'ap_stage_low_y': ('Stage low Y', 0.0, 'mm'),
#   'ap_ar_beam_shift_y': ('Argon Beam Shift Y', 0.0, 'nm'),
#   'ap_ar_shift_ratio_x': ('Argon Shift Ratio X', 0.0),
#   'ap_xtalk21': ('Xtalk21', 0.0),
#   'ap_asap_dfe1_plus5v_analogue': ('ASAP DFE1 Plus5V Analogue', 0.0, 'V'),
#   'ap_min_ext': ('Min Extractor V', 4.0, 'kV'),
#   'ap_h_6': ('H 7', 0.0, 'nm'),
#   'ap_stage_centre_y': ('Stage Centre Y', 64.88, 'mm'),
#   'ap_beam_current_monitor': ('Beam I Monitor', 0.0, 'µA'),
#   'ap_fib_scan_size': ('FIB Scan Size', 0.0, 'nm'),
#   'ap_stig_cal_y': ('Stig. Cal Y', 6.2, '%'),
#   'ap_fib_ext_actual': ('FIB Extractor', 0.0, 'kV'),
#   'ap_fib_fg_energy_actual': ('Flood Gun Energy Actual', 0.0, 'V'),
#   'ap_fib_stig_x_centre_y': ('FIB Stig X Centre Y', 0.0),
#   'ap_piezo_goto_y': ('Piezo Goto Y', 0.0, 'µm'),
#   'ap_fib_tilt_comp': ('FIB Tilt Comp', 0.0, '°'),
#   'ap_c1cal': ('C1 Cal', 0.958),
#   'ap_fib_slice_y': ('Slice Y', 0.0, 'nm'),
#   'ap_beamshift_x': ('Beam Shift X', 0.0, '%'),
#   'ap_red_raster_h': ('Red.Raster Height', 257),
#   'ap_magcal_base': ('Calibrate Mag Base', 50000.0),
#   'ap_fib_nudge_step': ('FIB Nudge Step', 0.0, 'nm'),
#   'ap_piezo_exchange_y': ('Piezo Exchange Y', 0.0, 'µm'),
#   'ap_stage_at_field_x': ('Stage at field X', 1),
#   'ap_low_mag_focus': ('Low Mag Focus', 1.0),
#   'ap_ar_acc_i': ('Argon Acc I is', 0.0, 'µA'),
#   'ap_ar_mill_progress': ('Argon Mill Progress', 0.0, '%'),
#   'ap_asap_dfe2_temperature': ('ASAP DFE2 Temperature', 0.0, '°C'),
#   'ap_area_fraction': ('Area Fraction', 0.0, '%'),
#   'ap_nominalfil': ('Nominal Fil I', 2.28, 'A'),
#   'ap_gun_y': ('Gun at Y', -21.4, '%'),
#   'ap_stage_vector_m': ('Stage Vector M', 0.0, '%'),
#   'ap_h_0': ('H 1', 0.0, 'nm'),
#   'ap_semiangle': ('Semi Angle', 0.0, 'µrad'),
#   'ap_fib_scan_rotation': ('FIB Scan Rot', 0.0, '°'),
#   'ap_fib_fil_v': ('FIB Fil Voltage', 0.0, 'V'),
#   'ap_stageangle': ('Stage Angle', 167.1, '°'),
#   'ap_inlens_duo_grid': ('InlensDuo Grid', 0, 'V'),
#   'ap_manualcurrent': ('Fil I Target', 2.28, 'A'),
#   'ap_brightnessz1': ('Brightness B', 49.0, '%'),
#   'ap_dual_mag_offset_x': ('Dual Mag Offset X', 3.0),
#   'ap_mag_shift_lower_y': ('Shift Amp Lower Offset Y', 0.0),
#   'ap_holder_width': ('Holder Width', 0.0, 'mm'),
#   'ap_si_factor': ('SmartImage Sharpening', 0.0, '%'),
#   'ap_stage_fields_x': ('Stage fields X', 1),
#   'ap_fib_probe_current_actual': ('FIB Probe Current Actual', 0.0, 'pA'),
#   'ap_ar_gas_flow': ('Argon Gas Flow', 0.0, '%'),
#   'ap_gamma': ('Gamma', 1.0),
#   'ap_beam_blank_gun_x': ('Beam Blanked Gun Pos X', 100.0, '%'),
#   'ap_asap_scan_offset_x': ('Scan Offset X', 0),
#   'ap_jazz_front_grid': ('Front Grid', 0, 'V'),
#   'ap_actualext': ('Extractor V', 4.65, 'kV'),
#   'ap_asap_vbe2_minus5v_analogue': ('ASAP VBE2 Minus5V Analogue', 0.0, 'V'),
#   'ap_gunalign_y': ('Gun Align Y', 0.0, '%'),
#   'ap_max_extractor_v': ('Max Extractor V', 7.0, 'kV'),
#   'ap_ppb_4': ('Pb 5', 0.0, '°'),
#   'ap_v_7': ('V 8', 0.0, 'nm'),
#   'ap_prof2_x1': ('Profile 2 X1', 0),
#   'ap_fib_objective_potential': ('FIB Objective', 0, 'V'),
#   'ap_fib_fg_extractor_voltage': ('Flood Gun Extractor Voltage', 0, 'V'),
#   'ap_piezo_at_y': ('Piezo at Y', 0.0, 'µm'),
#   'ap_emissionzoom': ('Emission Zoom', 100),
#   'ap_zoom_factor': ('Zoom factor', 2.0),
#   'ap_fib_working_distance': ('FIB Working Distance', 0.0, 'mm'),
#   'ap_linetoframe_lower': ('Line To Frame Lower', 0.0),
#   'ap_angular_1': ('Aa 2', 0.0, '°'),
#   'ap_stage_goto_y': ('Stage goto Y', 81.776, 'mm'),
#   'ap_beamsleeve_voltage': ('Beam sleeve Bias', 0, 'V'),
#   'ap_ar_discharge_actual': ('Argon Discharge is', 0, 'V'),
#   'ap_k2': ('Mix Signal', 0.0),
#   'ap_gun_at_fisheye_x': ('Gun Value at FishEye mode X', 0.0, '%'),
#   'ap_cc_pressure': ('CC Pressure', 0.0, '%'),
#   'ap_asap_dfe2_minus5v_analogue': ('ASAP DFE2 Minus5V Analogue', 0.0, 'V'),
#   'ap_ppa_4': ('Pa 5', 0.0, 'nm'),
#   'ap_v_1': ('V 2', 0.0, 'nm'),
#   'ap_stage_delta_z': ('Stage Delta Z', 0.0, 'mm'),
#   'ap_esd_upper_y': ('ESD Upper Y', 0.0, '%'),
#   'ap_fib_abs_delta_beam_shift_y': ('FIB Abs Beam Shift Y', 0.0, 'nm'),
#   'ap_fib_suppressor_target': ('FIB Suppressor Target', 0, 'V'),
#   'ap_fib_stig_y_centre_x': ('FIB Stig Y Centre X', 0.0),
#   'ap_purge_min': ('Purge Min', 133, 'Pa'),
#   'ap_fib_column_pressure': ('FIB Column Pressure', 0.0, 'mbar'),
#   'ap_fm_angle': ('Field Mode Angle', -1.0, '°'),
#   'ap_c3rem': ('C3 Rem', 0.0137),
#   'ap_fib_pixel_size': ('FIB Pixel Size', 0.0, 'fm'),
#   'ap_apertureposn_x': ('Aperture Posn X', 5.0, 'mm'),
#   'ap_ppb_0': ('Pb 1', 0.0, '°'),
#   'ap_c3_save': ('C3 saved for beam decel', 0, 'µA'),
#   'ap_esb_grid_is': ('ESB Grid is', 0, 'V'),
#   'ap_eht_set_max': ('EHT set maximum', 30.0, 'kV'),
#   'ap_stage_low_x': ('Stage low X', 0.0, 'mm'),
#   'ap_ar_beam_shift_x': ('Argon Beam Shift X', 0.0, 'nm'),
#   'ap_ar_xy_ratio': ('Argon XY Ratio', 0.0),
#   'ap_frame_ampl': ('Frame Ampl Cal.', 0),
#   'ap_xtalk12': ('Xtalk12', 0.0),
#   'ap_asap_dfe4_plus5v_digital': ('ASAP DFE4 Plus5V Digital', 0.0, 'V'),
#   'ap_manuallens': ('Liner Target', 8.0, 'kV'),
#   'ap_h_5': ('H 6', 0.0, 'nm'),
#   'ap_stage_centre_x': ('Stage Centre X', 64.22, 'mm'),
#   'ap_stig_cal_x': ('Stig. Cal X', 2.3, '%'),
#   'ap_fib_ext_target': ('FIB Extr.Target', 0.0, 'kV'),
#   'ap_fib_fg_energy_target': ('Flood Gun Energy Target', 0.0, 'V'),
#   'ap_fib_stig_x_centre_x': ('FIB Stig X Centre X', 0.0),
#   'ap_piezo_goto_x': ('Piezo Goto X', 0.0, 'µm'),
#   'ap_c2': ('C2 Lens I', 0, 'µA'),
#   'ap_mag_comp_offset': ('Mag Comp. Offset', 520),
#   'ap_fib_slice_x': ('Slice X', 0.0, 'nm'),
#   'ap_guntilt_y': ('Gun Tilt Y', 0.0, '%'),
#   'ap_red_raster_w': ('Red.Raster Width', 360),
#   'ap_scan_rotation_offset_lower': ('Scan Rotation Offset Lower', 0.0, '°'),
#   'ap_piezo_exchange_x': ('Piezo Exchange X', 0.0, 'µm'),
#   'ap_stage_goto_field_y': ('Stage goto field Y', 1),
#   'ap_ar_extractor_actual': ('Argon Extractor is', 0, 'V'),
#   'ap_auto_contrast': ('Auto C Target', 33.9, '%'),
#   'ap_implied_offset': ('Offset B', 0.0, '%'),
#   'ap_align1_y': ('Align 1 Y', 0.0, '%'),
#   'ap_beam_offset_y': ('Beam Offset Y', -0.0, 'nm'),
#   'ap_white_detect': ('White Threshold', 100.0, '%'),
#   'ap_asap_vbe2_temperature': ('ASAP VBE2 Temperature', 0.0, '°C'),
#   'ap_gun_x': ('Gun at X', -45.5, '%'),
#   'ap_water_temp_limit': ('EO Temp Limit', 35.0, '°C'),
#   'ap_spot_x_cal': ('Spot X Cal', -1),
#   'ap_fib_beam_shift_y': ('FIB Beam Shift Y', 0.0, 'nm'),
#   'ap_fib_fil_i': ('FIB Fil Current', 0, 'µA'),
#   'ap_scanorthog': ('Scan Orth corrn', 0.3, '°'),
#   'ap_manualkv': ('EHT Target', 4.0, 'kV'),
#   'ap_magcalheight': ('Mag Cal Actual Height', 0.0, 'nm'),
#   'ap_brightnessz0': ('Brightness A', 48.7, '%'),
#   'ap_c3_decl': ('Decl cal 2', 1.0),
#   'ap_mag_shift_lower_x': ('Shift Amp Lower Offset X', 0.0),
#   'ap_holder_diameter': ('Holder Diameter', 50.0, 'mm'),
#   'ap_si_threshold': ('SmartImage Threshold', 0.0, '%'),
#   'ap_stage_scan_angle': ('Stage scan angle', 0.0, '°'),
#   'ap_fib_objective_actual': ('FIB Objective Actual', 0, 'V'),
#   'ap_ar_objective_actual': ('Argon Objective is', 0, 'V'),
#   'ap_line_int_count': ('Line int. count', 1),
#   'ap_beam_blank_aperture_y': ('Beam Blanked Aperture Pos Y', 100.0, '%'),
#   'ap_filament_age': ('Filament Age', 11194.79, 'Hours'),
#   'ap_dual_mag_y_slope': ('Dual Mag Gain Y', 660.22),
#   'ap_stage_vector_t': ('Stage vector T', 0.0, '%'),
#   'ap_hcstage_temp': ('Peltier Temp', 20.0, '°C'),
#   'ap_asap_vbe1_minus5v_analogue': ('ASAP VBE1 Minus5V Analogue', 0.0, 'V'),
#   'ap_gunalign_x': ('Gun Align X', 0.0, '%'),
#   'ap_eht_cal_30kv': ('EHT Cal@30KV', 30.13, 'kV'),
#   'ap_ppa_9': ('Pa 10', 0.0, 'nm'),
#   'ap_v_6': ('V 7', 0.0, 'nm'),
#   'ap_prof1_x2': ('Profile 1 X2', 0),
#   'ap_stage_bias_voltage': ('Stage bias Low Volts', 0.0, 'V'),
#   'ap_vp_limit': ('VP LaB6 Limit', 274, 'Pa'),
#   'ap_fib_eht_actual': ('FIB EHT', 0.0, 'kV'),
#   'ap_humidity_target': ('Humidity Target', 0.0, '%'),
#   'ap_piezo_at_x': ('Piezo at X', 0.0, 'µm'),
#   'ap_linetoframe_upper': ('Line To Frame Upper', 0.0),
#   'ap_angular_0': ('Aa 1', 0.0, '°'),
#   'ap_reduced_raster_y': ('Reduced Raster Y', 192),
#   'ap_laser_finder_illum': ('Laser Illumination', 0.0, '%'),
#   'ap_stage_goto_x': ('Stage goto X', 69.622, 'mm'),
#   'ap_column_vac': ('Gun Vacuum', 1.32e-09, 'mbar'),
#   'ap_ar_discharge': ('Argon Discharge', 0, 'V'),
#   'ap_k1': ('Signal', 1.0),
#   'ap_line_average_count': ('Line Avg.Count', 35),
#   'ap_beam_time': ('Beam Time', 7980.92, 'Hours'),
#   'ap_asap_dfe1_minus5v_analogue': ('ASAP DFE1 Minus5V Analogue', 0.0, 'V'),
#   'ap_cursor_height': ('Cursor Height', 0.0, 'nm'),
#   'ap_profile_w2': ('Profile Width 2', 0.0, 'nm'),
#   'ap_v_0': ('V 1', 0.0, 'nm'),
#   'ap_stage_delta_y': ('Stage Delta Y', 0.0, 'mm'),
#   'ap_polaris_probe_cal': ('Probe Cal Factor', 1.0),
#   'ap_esd_upper_x': ('ESD Upper X', 0.0, '%'),
#   'ap_fib_abs_delta_beam_shift_x': ('FIB Abs Beam Shift X', 0.0, 'nm'),
#   'ap_fib_drift_y': ('FIB Drift Y', 0.0, 'nm'),
#   'ap_purge_max': ('Purge Max', 1066, 'Pa'),
#   'ap_fib_heating_limit': ('FIB Heating Limit', 0, 'µA'),
#   'ap_c3cal': ('C3 Cal', 0.939),
#   'ap_line_counter': ('Line Counter', 1535),
#   'ap_aperturesize': ('Aperture Size', 60.0, 'µm'),
#   'ap_ppa_3': ('Pa 4', 0.0, 'nm'),
#   'ap_wd_save': ('wd saved for beam decel', 10.0, 'mm'),
#   'ap_liner_cal_at_10kv': ('Liner Cal @ 10KV', 9990, 'V'),
#   'ap_beam_current': ('Beam Current', 80.0, 'µA'),
#   'ap_stage_high_z': ('Stage high Z', 50.0, 'mm'),
#   'ap_ion_convertor_voltage': ('Convertor Voltage', 0.0, 'kV'),
#   'ap_ar_mag_factor': ('Argon Mag Factor', 0.0, 'nm'),
#   'ap_mag1': ('Mag Z1', 1.0),
#   'ap_asap_dfe3_plus5v_digital': ('ASAP DFE3 Plus5V Digital', 0.0, 'V'),
#   'ap_manualsupp': ('Suppressor V Target', 300, 'V'),
#   'ap_h_4': ('H 5', 0.0, 'nm'),
#   'ap_sample_height': ('Compu. Height', 0.0, 'mm'),
#   'ap_fib_aper_y_actual': ('FIB Aperture Y Actual', 0),
#   'ap_fib_emission_target': ('FIB Emission Target', 0.0, 'µA'),
#   'ap_c1': ('C1 Lens I', 0, 'µA'),
#   'ap_mag_comp_ampl': ('Mag Comp. Amplitude', 37.0, '%'),
#   'ap_fib_slice_index': ('Slice Index', 0),
#   'ap_guntilt_x': ('Gun Tilt X', 0.0, '%'),
#   'ap_red_raster_posn_y': ('Red.Raster Posn Y', 192),
#   'ap_mag_gain_lower_y': ('Shift Amp Lower Gain Y', 0.0),
#   'ap_holder_height': ('Holder Height', 13.7, 'mm'),
#   'ap_specimen_diameter': ('Specimen Diameter', 10, 'mm'),
#   'ap_stage_goto_field_x': ('Stage goto field X', 1),
#   'ap_ar_extractor': ('Argon Extractor', 0, 'V'),
#   'ap_auto_bright': ('Auto B Target', 38.7, '%'),
#   'ap_implied_gain': ('Gain B', 100.0, '%'),
#   'ap_align1_x': ('Align 1 X', 0.0, '%'),
#   'ap_beam_offset_x': ('Beam Offset X', 0.0, 'nm'),
#   'ap_black_detect': ('Black Threshold', 0.0, '%'),
#   'ap_asap_vbe1_temperature': ('ASAP VBE1 Temperature', 0.0, '°C'),
#   'ap_nominalext': ('Nominal extractor V', 4.65, 'kV'),
#   'ap_aperture_y': ('Aperture at Y', 7.3, '%'),
#   'ap_stage_high_m': ('Stage high M', 0.0, 'mm'),
#   'ap_water_temp': ('EO Temp', 22.1, '°C'),
#   'ap_user_max_eht': ('User Max EHT', 30.0, 'kV'),
#   'ap_ccd_illumination': ('CCD Illum.', 36.0, '%'),
#   'ap_fib_beam_shift_x': ('FIB Beam Shift X', 0.0, 'nm'),
#   'ap_scanrotation': ('Scan Rotation', 1.2, '°'),
#   'ap_fib_focus': ('FIB Focus', 0.0),
#   'ap_usermaxcurrent': ('Fil I (Usermax)', 4.0, 'A'),
#   'ap_magcalwidth': ('Mag Cal Actual Width', 0.0, 'nm'),
#   'ap_defect_id': ('Defect ID', 0),
#   'ap_line_posn_y': ('Line posn Y', 192),
#   'ap_wd_decl': ('Decl cal 1', 0.0),
#   'ap_mag_shift_upper_y': ('Shift Amp Upper Offset Y', 0.0),
#   'ap_si_enhancement': ('SmartImage Contrast', 0.0, '%'),
#   'ap_stage_vector_z': ('Stage vector Z', 0.0, '%'),
#   'ap_bgpl': ('BGPL', 10.0, 'mm'),
#   'ap_ar_objective': ('Argon Objective', 0, 'V'),
#   'ap_frame_int_count': ('Frames to Int.', 0),
#   'ap_beam_blank_aperture_x': ('Beam Blanked Aperture Pos X', 100.0, '%'),
#   'ap_alias_wd': ('Focus', 8.9, 'mm'),
#   'ap_stage_vector_r': ('Stage vector R', 0.0, '%'),
#   'ap_asap_vbe2_plus5v_analogue': ('ASAP VBE2 Plus5V Analogue', 0.0, 'V'),
#   'ap_eht_cal_24kv': ('EHT Cal@24KV', 24.11, 'kV'),
#   'ap_ppa_8': ('Pa 9', 0.0, 'nm'),
#   'ap_v_5': ('V 6', 0.0, 'nm'),
#   'ap_prof1_x1': ('Profile 1 X1', 0),
#   'ap_hrru_number': ('HRRU No.', 0),
#   'ap_fib_eht_target': ('FIB EHT Target', 0.0, 'kV'),
#   'ap_humidity': ('Humidity', 0.0, '%'),
#   'ap_esb_grid_max': ('ESB Grid Max', 100, 'V'),
#   'ap_contrastz3': ('Contrast D', 39.3, '%'),
#   'ap_mill_item_elapsed_time': ('Mill Item Elapsed Time', 0, 'ms'),
#   'ap_stage_bias_voltage_high': ('Beam deceleration Volts', 0, 'V'),
#   'ap_magcal_lower_y': ('Calibrate Mag Lower Y', 0.0),
#   'ap_radial_3': ('Da 4', 0.0, 'nm'),
#   'ap_fib_condenser_actual': ('FIB Condenser actual', 0, 'V'),
#   'ap_ar_acc_actual': ('Argon Energy is', 0, 'V'),
#   'ap_scm': ('Specimen I', 0.0, 'pA'),
#   'ap_photo_number': ('Photo No.', 136980),
#   'ap_field_overlap': ('Field Overlap', 0.0, '%'),
#   'ap_spot': ('Spot signal', 0),
#   'ap_asap_dfe4_plus5v_analogue': ('ASAP DFE4 Plus5V Analogue', 0.0, 'V'),
#   'ap_cursor_width': ('Cursor Width', 0.0, 'nm'),
#   'ap_profile_w1': ('Profile Width 1', 0.0, 'nm'),
#   'ap_h_9': ('H 10', 0.0, 'nm'),
#   'ap_stage_delta_x': ('Stage Delta X', 0.0, 'mm'),
#   'ap_compu_tilt_error': ('Compu. Tilt Error', 0.0),
#   'ap_fib_drift_x': ('FIB Drift X', 0.0, 'nm'),
#   'ap_purge_cycles': ('Purge cycles', 2),
#   'ap_c3': ('C3 Lens I', 622.4, 'mA'),
#   'ap_epd_low': ('EPD Low Limit', 0),
#   'ap_c2rem': ('C2 Rem', 0.0318),
#   'ap_fib_slice_angle': ('Slice Angle', 0.0, '°'),
#   'ap_zoompos_y': ('Zoom Posn Y', 192),
#   'ap_ppa_2': ('Pa 3', 0.0, 'nm'),
#   'ap_clip_limit': ('Clip Limit', 0),
#   'ap_liner_cal_at_100v': ('Liner cal @ 100V', 94, 'V'),
#   'ap_pixel_size': ('Pixel Size', 111.6, 'nm'),
#   'ap_stage_high_y': ('Stage high Y', 130.0, 'mm'),
#   'ap_stage_bias_wobble_amplitude': ('Stage bias wobble amplitude', 0, 'V'),
#   'ap_ion_collector_voltage': ('Collector Voltage', 0.0, 'kV'),
#   'ap_ar_pixel_size': ('Argon Pixel Size', 0.0, 'fm'),
#   'ap_mag0': ('Mag Z0', 1.0),
#   'ap_min_wd': ('Focus scan min', 1, 'mm'),
#   'ap_asap_dfe2_plus5v_digital': ('ASAP DFE2 Plus5V Digital', 0.0, 'V'),
#   'ap_manualext': ('Extractor V Target', 4.65, 'kV'),
#   'ap_h_3': ('H 4', 0.0, 'nm'),
#   'ap_image_pixel_size': ('Image Pixel Size', 55.82, 'nm'),
#   'ap_fib_aper_x_actual': ('FIB Aperture X Actual', 0),
#   'ap_fib_suppressor': ('FIB Suppressor', 0, 'V'),
#   'ap_dc_max_attempts': ('Drift Max Tries', 10),
#   'ap_beam_shift_align_y': ('Beam Shift Align Y', 0.0, 'nm'),
#   'ap_brightness': ('Brightness', 48.7, '%'),
#   'ap_fisheye_quadriture': ('Fisheye quadriture', 1000),
#   'ap_gunshift_y': ('Gun Shift Y', 0.0, '%'),
#   'ap_red_raster_posn_x': ('Red.Raster Posn X', 408),
#   'ap_mag_gain_lower_x': ('Shift Amp Lower Gain X', 0.0),
#   'ap_stage_field_size_y': ('Stage field size Y', 0.0, 'mm'),
#   'ap_ar_v_int_actual': ('Argon V Int is', 0, 'V'),
#   'ap_contrast': ('Contrast', 28.4, '%'),
#   'ap_asap_cal_video_delay': ('Video Delay', 0, 'ns'),
#   'ap_height': ('Height', 85.75, 'µm'),
#   'ap_asap_dfe1_temperature': ('ASAP DFE1 Temperature', 0.0, '°C'),
#   'ap_eht_set_min': ('EHT Set minimum', 0.01, 'kV'),
#   'ap_asap_dfe4_temperature': ('ASAP DFE4 Temperature', 0.0, '°C'),
#   'ap_extcurrent': ('Ext I Monitor', 102.5, 'µA'),
#   'ap_aperture_x': ('Aperture at X', 44.8, '%'),
#   'ap_stage_low_m': ('Stage low M', 0.0, 'mm'),
#   'ap_fcf_setting': ('FCF Setting', 0.0, '%'),
#   'ap_radial_area_3': ('Db 4', 0.0, 'nm²'),
#   'ap_fib_stigmator_y': ('FIB Stig Y', 0.0, '%'),
#   'ap_frame_counter': ('Frame Counter', 30218),
#   'ap_fib_fg_fil_current_actual': ('Flood Gun Filament Actual', 0, 'µA'),
#   'ap_ep_target': ('EP Target', 10, 'Pa'),
#   'ap_wd': ('WD', 8.9, 'mm'),
#   'ap_hsync_delay': ('HSync delay', 0, 'ns'),
#   'ap_frame_time': ('Cycle Time', 1.3, 'Mins'),
#   'ap_fib_gun_pressure': ('FIB Gun Pressure', 0.0, 'mbar'),
#   'ap_line_posn_x': ('Line posn X', 0),
#   'ap_mag_shift_upper_x': ('Shift Amp Upper Offset X', 0.0),
#   'ap_compu_tilt_offset': ('Compu. Tilt Offset', 0.0, 'mm'),
#   'ap_stage_vector_y': ('Stage vector Y', 0.0, '%'),
#   'ap_ar_condenser_actual': ('Argon Condenser is', 0, 'V'),
#   'ap_frame_average_count': ('Frames to average', 30),
#   'ap_aperture_at_fisheye_y': ('Aperture value at FishEye Y', 0.0, '%'),
#   'ap_dual_mag_slope': ('Dual Mag Gain X', 659.16),
#   'ap_stage_goto_t': ('Stage goto T', 0.0, '°'),
#   'ap_asap_vbe1_plus5v_analogue': ('ASAP VBE1 Plus5V Analogue', 0.0, 'V'),
#   'ap_chamber_pressure': ('Chamber', 0.0, 'Pa'),
#   'ap_eht_cal_10kv': ('EHT Cal@10KV', 10.06, 'kV'),
#   'ap_ppa_7': ('Pa 8', 0.0, 'nm'),
#   'ap_v_4': ('V 5', 0.0, 'nm'),
#   'ap_stage_delta_m': ('Stage Delta M', 0.0, 'mm'),
#   'ap_print_number': ('Print No.', 0),
#   'ap_esd_excitation': ('ESD Excitation', 0.0, '%'),
#   'ap_peltier_target': ('Peltier Target', 20.0, '°C'),
#   'ap_esb_grid': ('ESB Grid', 100, 'V'),
#   'ap_contrastz2': ('Contrast C', 39.3, '%'),
#   'ap_mill_item_total_time': ('Mill Item Total Time', 0, 'ms'),
#   'ap_stig_y': ('Stigmation Y', -7.3, '%'),
#   'ap_ppb_3': ('Pb 4', 0.0, '°'),
#   'ap_magcal_lower_x': ('Calibrate Mag Lower X', 0.0),
#   'ap_radial_2': ('Da 3', 0.0, 'nm'),
#   'ap_system_vac': ('System Vacuum', 2.16e-06, 'mbar'),
#   'ap_ar_acc': ('Argon Energy', 0, 'V'),
#   'ap_scan_offset_y': ('Scan Y cal.', 0),
#   'ap_asap_dfe3_plus5v_analogue': ('ASAP DFE3 Plus5V Analogue', 0.0, 'V'),
#   'ap_stage_low_t': ('Stage low T', -4.0, '°'),
#   'ap_mag_gain_y': ('Mag Gain Cal Y', 724.0),
#   'ap_h_8': ('H 9', 0.0, 'nm'),
#   'ap_stage_low_r': ('Stage low R', -380.0, '°'),
#   'ap_dc_shift_y': ('Aperture Align Y', 0.0, '%'),
#   'ap_fib_sem_angle': ('FIB SEM Angle', 54.0, '°'),
#   'ap_epd_high': ('EPD High Limit', 0),
#   'ap_c2cal': ('C2 Cal', 1.063),
#   'ap_fib_slice_height': ('Slice Height', 0.0, 'nm'),
#   'ap_zoompos_x': ('Zoom Posn X', 128),
#   'ap_ppa_1': ('Pa 2', 0.0, 'nm'),
#   'ap_tilt_align_y': ('Tilt Align Y', 0.0, '%'),
#   'ap_fib_min_autoheat_current': ('FIB Min. Autoheat Current', 0, 'µA'),
#   'ap_chamber_pressure_detailed': ('Chamber Pressure Detailed', 0.0, 'Pa'),
#   'ap_stage_high_x': ('Stage high X', 130.0, 'mm'),
#   'ap_landing_energy': ('Landing energy', 4.0, 'kV'),
#   'ap_collector_bias': ('Collector Bias', 300, 'V'),
#   'ap_max_wd': ('Focus scan max', 40, 'mm'),
#   'ap_asap_dfe1_plus5v_digital': ('ASAP DFE1 Plus5V Digital', 0.0, 'V'),
#   'ap_test_val': ('Test Val', 0.0),
#   'ap_h_2': ('H 3', 0.0, 'nm'),
#   'ap_radial_area_1': ('Db 2', 0.0, 'nm²'),
#   'ap_fib_aperture_align_y': ('FIB Aper.Align Y', 0),
#   'ap_fib_fil_v_target': ('FIB Fil V target', 0.0, 'V'),
#   'ap_dc_min_conf': ('Drift Min Conf', 50.0, '%'),
#   'ap_beam_shift_align_x': ('Beam Shift Align X', 0.0, 'nm'),
#   'ap_fisheye_orthog': ('Fisheye Orthog', 0.0, '°'),
#   'ap_gunshift_x': ('Gun Shift X', 0.0, '%'),
#   'ap_contrastz1': ('Contrast B', 39.3, '%'),
#   'ap_focus_rotation_comp': ('Focus Rotation comp.', -0.009, 'kV'),
#   'ap_mag_gain_upper_y': ('Shift Amp Upper Gain Y', 0.0),
#   'ap_fib_track_wd_delta': ('FIB Track WD Delta', 0.0, 'nm'),
#   'ap_stage_field_size_x': ('Stage field size X', 0.0, 'mm'),
#   'ap_ar_v_int': ('Argon V Int', 0, 'V'),
#   'ap_offset': ('Offset A', 0.0, '%'),
#   'ap_width': ('Width', 114.3, 'µm'),
#   'ap_asap_mb_temperature': ('ASAP MB Temperature', 0.0, '°C'),
#   'ap_mag_shift_y': ('Mag Shift Cal Y', 1.0),
#   'ap_pirani_pressure': ('Pirani Pressure', 0.0, 'mbar'),
#   'ap_actuallens': ('Liner Tube', 7.99, 'kV'),
#   'ap_aperture_align_y': ('Aperture Align Y', 4.6, '%'),
#   'ap_stage_goto_m': ('Stage goto M', 0.0, 'mm'),
#   'ap_ppb_6': ('Pb 7', 0.0, '°'),
#   'ap_v_9': ('V 10', 0.0, 'nm'),
#   'ap_radial_area_2': ('Db 3', 0.0, 'nm²'),
#   'ap_fib_fg_serial_number': ('Flood Gun Serial Number', 0),
#   'ap_fib_stigmator_x': ('FIB Stig X', 0.0, '%'),
#   'ap_stage_at_m': ('Stage at M', 0.0, 'mm'),
#   'ap_stage_at_z': ('Stage at Z', 42.289, 'mm'),
#   'ap_stage_at_y': ('Stage at Y', 81.776, 'mm'),
#   'ap_actualcurrent': ('Fil I', 2.28, 'A'),
#   'ap_stage_at_x': ('Stage at X', 69.6219, 'mm'),
#   'ap_actualkv': ('EHT', 4.0, 'kV'),
#   'ap_stage_at_t': ('Stage at T', 0.0, '°'),
#   'ap_sample_at_y': ('Sample at Y', 0.0),
#   'ap_stage_at_r': ('Stage at R', 19.0, '°'),
#   'ap_sample_at_x': ('Sample at X', 0.0),
#   'ap_time': ('Time', '9:05:51'),
#   'ap_date': ('Date', '5 May 2023'),
#   'sv_version': ('Version', 'V06.00.00.00 : 09-Jun-16'),
#   'sv_user_text': ('User Text', ''),
#   'sv_file_name': ('File Name', 'NK_PA07_1-4_KA-W 136980.tif'),
#   'sv_image_path': ('Images', 'd:\\images\\müller\\2023\\230505\\'),
#   'sv_user_name': ('User Name', 'MUELLER'),
#   'sv_sample_id': ('Sample ID', ''),
#   'sv_serial_number': ('Serial No.', 'SUPRA 55-30-73'),
#   'sv_operator': ('Operator', '')}}

# %% [markdown]
# This image also passes the test, but it's expected as it's the same instrument as the first image.

# %% [markdown]
# # Au-Gr_06.tif
#
# Zeiss CNR-IOM instrument

# %%
f = hs.load(images[3])
Zeiss_CNRIOM = f.original_metadata.as_dictionary()

del Zeiss_CNRIOM['ColorMap']

Zeiss_CNRIOM
# Out:
# {'NewSubfileType': <FILETYPE.UNDEFINED: 0>,
#  'ImageWidth': 1024,
#  'ImageLength': 768,
#  'BitsPerSample': 8,
#  'Compression': <COMPRESSION.NONE: 1>,
#  'PhotometricInterpretation': <PHOTOMETRIC.PALETTE: 3>,
#  'StripOffsets': (31700,),
#  'SamplesPerPixel': 1,
#  'RowsPerStrip': 4294967295,
#  'StripByteCounts': (786432,),
#  'XResolution': (1, 1),
#  'YResolution': (1, 1),
#  'ResolutionUnit': <RESUNIT.NONE: 1>,
#  'CZ_SEM': {'': (0,
#    0,
#    0,
#    9.183126e-10,
#    399850.2,
#    6,
#    5000.0,
#    2.25,
#    2e-07,
#    0.004021607,
#    1,
#    9.183126e-10,
#    399850.2,
#    6,
#    5000.0,
#    2.25,
#    2e-07,
#    0.004021607,
#    2,
#    3.696236e-06,
#    99.3409,
#    6,
#    0.0,
#    2.25,
#    2e-07,
#    0.00246,
#    3,
#    3.696236e-06,
#    99.3409,
#    6,
#    0.0,
#    2.25,
#    2e-07,
#    0.00246,
#    724),
#   'dp_vent_invalid_reason': ('Vent inhibit', 'Beam Present'),
#   'dp_optimode': ('OptiBeam Mode', 'Resolution'),
#   'dp_fixed_aperture': ('VP Aperture', False),
#   'dp_input_lut_mode': ('Input LUT Mode', 'Transparent'),
#   'dp_bsd_autolevel_mode': ('BSD Autolevel Mode', 'Normal'),
#   'dp_recipe': ('Recipe', 'Idle'),
#   'dp_implied_detector': ('Signal B', ''),
#   'dp_4qbsd_visible': ('BSD Fast', False),
#   'dp_opt_aperture': ('Opt.Aperture', 2),
#   'dp_track_z': ('Track Z', False),
#   'dp_epse_electrode': ('EPSE Electrode', 'Ring'),
#   'dp_c3_rot_correction': ('C3 Rot Corrn.', True),
#   'dp_fisheye_mode': ('Fisheye Mode', False),
#   'dp_stage_tilted': ('Stage Tilt', 'in X'),
#   'dp_ar_gun': ('Argon Gun', 'Absent'),
#   'dp_column_isolated': ('Column Isolated', False),
#   'dp_mixing': ('Mixing', False),
#   'dp_fib_fg_mode_target': ('Flood Gun Mode Target', 'Low Energy Mode'),
#   'dp_stem_gain': ('STEM Gain', 'Low'),
#   'dp_high_current': ('High Current', False),
#   'dp_dwell_time': ('Dwell Time', 100, 'ns'),
#   'dp_si_noise_reduction': ('SmartImage Noise Reduction', False),
#   'dp_right_frozen': ('Right Frozen', True),
#   'dp_fib_fg_blanked': ('Flood Gun Blanked', False),
#   'dp_fast_mode': ('Fast Mode', False),
#   'dp_compucentric_mode': ('Compuc. Mode', False),
#   'dp_anode_aperture_changer': ('Anode Aperture Changer', 'Absent'),
#   'dp_gis_shutdown_state': ('GIS Shutdown State', 'Normal'),
#   'dp_fib_column': ('FIB Column', 'None'),
#   'dp_tilted': ('Stage Tilted', False),
#   'dp_fib_suppressor': ('FIB Suppressor is', 'Absent'),
#   'dp_vpse': ('VPSE detector', 'Absent'),
#   'dp_crosshairs': ('Crosshairs', False),
#   'dp_double_deflection_state': ('Double Deflection State', False),
#   'dp_gate_valve_position': ('WDX Gate Valve posn', 'OK'),
#   'dp_hese2_fitted': ('HE-SE2 Fitted', False),
#   'dp_ep_mode': ('EP Gas', 'Air'),
#   'dp_condenser': ('Condenser Normal', 'Normal'),
#   'dp_implied_invert': ('Invert B', False),
#   'dp_4qbsd_gain': ('BSD Gain', 'High'),
#   'dp_fib_gun_valve': ('FIB Gun Valve', 'Closed'),
#   'dp_aperture_state': ('Aperture', 'Clean'),
#   'dp_electron_counting': ('Electron Counting', False),
#   'dp_saturate_at': ('Saturate at', 'Second peak'),
#   'dp_stage_angle': ('Stage Angle corrn.', True),
#   'dp_image_store': ('Store resolution', '1024 * 768'),
#   'dp_field_mode': ('Field Mode', False),
#   'dp_coolstage_type': ('CoolStage Type', 'Cold'),
#   'dp_best_aperture': ('Best Aperture', True),
#   'dp_fib_fg_mode_actual': ('Flood Gun Actual Mode', 'Low Energy Mode'),
#   'dp_stem_auto': ('STEM Auto', False),
#   'dp_stage_init': ('Stage Initialised', True),
#   'dp_cc_on_gis_channel': ('GIS Channel with CC', 'None'),
#   'dp_channel': ('Display', 0),
#   'dp_fib_fg_fitted': ('Flood Gun Fitted', False),
#   'dp_bsd_mode': ('BSD Mode', 'Topo'),
#   'dp_fib_mode': ('FIB Mode', 'Imaging'),
#   'dp_nano_tips': ('Nano Tips', 'Absent'),
#   'dp_bsd_n_on_p': ('BSD Invert', False),
#   'dp_mgs_evac_state': ('MGS Evacuation State', False),
#   'dp_use_epd': ('Use End Point Detection', False),
#   'dp_mains_sync': ('Mains Sync', 'Single Edge'),
#   'dp_fib_pneumatic_prep_state': ('FIB preparation for pneumatic',
#    'FIB ready for system vent'),
#   'dp_frozen': ('Image', 'Frozen'),
#   'dp_filament_type': ('Filament Type', 'FE FEI'),
#   'dp_sample_holder': ('Sample Holder', ''),
#   'dp_fib_scan': ('FIB Scan', 'Continuous'),
#   'dp_beam_blanked': ('Beam Blanked', True),
#   'dp_cc_type': ('CC Type', 'None'),
#   'dp_4qbsd': ('BSD', 'Absent'),
#   'dp_image_saved': ('Image saved', True),
#   'dp_mag_range': ('Mag Range', 3),
#   'dp_user_align': ('User Align', True),
#   'dp_zone': ('Zone', 0),
#   'dp_fil_blown': ('Filament blown', False),
#   'dp_humidity_valve': ('Humidity Valve', 'Closed'),
#   'dp_peltier_photo': ('Peltier Photo', False),
#   'dp_main_detector': ('Control', 'Signal A'),
#   'dp_invert': ('Invert A', False),
#   'dp_fib_fg_remoting_target': ('Remoting Target', 'Flood Gun Normal'),
#   'dp_stage_is': ('Stage Is', 'Idle'),
#   'dp_fib_present': ('FIB Present', False),
#   'dp_peltier_type': ('Peltier Type', 'Deben'),
#   'dp_signalaz0': ('Signal A Z0', 'InLens'),
#   'dp_freeze_on': ('Freeze on', 'End Frame'),
#   'dp_fib_blanked': ('FIB Blanked', False),
#   'dp_stage_bias_high': ('Beam deceleration', False),
#   'dp_epse_gain': ('EPSE Gain', 'Low'),
#   'dp_end_detection': ('End Detection', False),
#   'dp_vac_comms_fail': ('Vac comms fail', False),
#   'dp_bsd_auto': ('BSD Auto Range', True),
#   'dp_pneumatic_device_in_use': ('Pneumatic Device in use', 'None'),
#   'dp_fib_wide_view': ('FIB Wide View', False),
#   'dp_anode': ('Anode Spacer', 'High KV'),
#   'dp_use_ref_mag': ('Reference Mag', 'Out Dev.'),
#   'dp_stage_bias_nse': ('Stage Bias', False),
#   'dp_user_mag_cal': ('User Calibration', False),
#   'dp_safe_stem_valid': ('Safe STEM Valid', False),
#   'dp_4qbsd_q5': ('Q5', False),
#   'dp_scd_gain': ('SCD Gain', 'Low'),
#   'dp_all_zones': ('All Zones', False),
#   'dp_detector_channel': ('Signal A', 'InLens'),
#   'dp_eht_tripped': ('EHT tripped', False),
#   'dp_flood_state': ('Flood State', 'Idle'),
#   'dp_extractor_trip': ('Extractor Trip', False),
#   'dp_bsd_fast_scan': ('BSD Fast Scan', False),
#   'dp_inlens_duo_mode': ('InlensDuo Mode', 'SE'),
#   'dp_auto_video': ('Auto BC', False),
#   'dp_fib_fg_remoting_actual': ('Flood Gun Remoting Actual',
#    'Flood Gun Normal'),
#   'dp_signalaz1': ('Signal A Z1', 'InLens'),
#   'dp_stage_bias_hv_fitted': ('Variable stage bias fitted', False),
#   'dp_epse_auto': ('EPSE Auto Range', False),
#   'dp_stage_comms_fail': ('Stage comms fail', False),
#   'dp_optiprobe': ('OptiProbe', False),
#   'dp_cls_valve': ('C.L.S.Valve', 'Closed'),
#   'dp_newfilament': ('New Filament', False),
#   'dp_image_detect': ('Image Detect', 'Black'),
#   'dp_custom_holder': ('Custom Holder', False),
#   'dp_zoom': ('Zoom', False),
#   'dp_scd_auto': ('SCD Auto Range', False),
#   'dp_ext_scan_control': ('Ext.Scan Control', False),
#   'dp_detector_type': ('Detector', 'InLens'),
#   'dp_eht_reset': ('EHT spurious reset', False),
#   'dp_stem_q4': ('STEM Q4', False),
#   'dp_fib_fg_extractor_target': ('Extractor Target State', False),
#   'dp_jazz_gain': ('Jazz Gain', 'Low'),
#   'dp_monitor': ('Monitor', '19/21 inch'),
#   'dp_freeze_status': ('Freeze', 'Idle'),
#   'dp_fib_extractor_conflict': ('FIB Extractor Conflict', False),
#   'dp_stage_bias_carassel_fitted': ('Beam deceleration carousel', False),
#   'dp_epse_bandwidth': ('EPSE Bandwidth', 'DC'),
#   'dp_stage_bias': ('Stage bias low voltage', False),
#   'dp_stigbalance': ('Stig Balance', False),
#   'dp_frame_grabber': ('Frame Grabber', 'Matrix Titan'),
#   'dp_vpse2': ('VPSE-G3 Fitted', 'Absent'),
#   'dp_4qbsd_q1': ('Q1', False),
#   'dp_fib_lock_mag': ('FIB Lock Mags', False),
#   'dp_freeze_blanks': ('Freeze Blanks', True),
#   'dp_windowing': ('Windowing', False),
#   'dp_partial_vent': ('Partial Vent on Standby', False),
#   'dp_scd_bandwidth': ('SCD Bandwidth', 'DC'),
#   'dp_calibration': ('Calibration', 'Disabled'),
#   'dp_stem_q1': ('STEM Q1', False),
#   'dp_eht_vac_ready': ('EHT Vac ready', True),
#   'dp_stem_q5': ('STEM Q5', False),
#   'dp_fib_fg_extractor_actual': ('Flood Gun Extractor Actual State', False),
#   'dp_bakeout_full': ('full service bakeout', False),
#   'dp_water_ok': ('Water OK', True),
#   'dp_low_mag': ('Low Mag', False),
#   'dp_vent_inhibited': ('Venting inhibited', True),
#   'dp_fib_probe': ('FIB Probe', 'Undefined'),
#   'dp_lut_mode': ('Display LUT mode', 'Normal'),
#   'dp_optibeam': ('OptiBeam Is', False),
#   'dp_scangen_type': ('ScanGen Type', 'L-REM'),
#   'dp_final_lens': ('Final Lens', '1500: Gemini'),
#   'dp_ehtcommsfail': ('EHT Comms Fail', False),
#   'dp_scangen': ('Scan Gen', 'Present'),
#   'dp_num_regions': ('Num. Regions', 0),
#   'dp_fib_error': ('FIB Error', 'None'),
#   'dp_gis_heating_status_1': ('GIS Heating Status Channel 1',
#    'GIS Not Heating'),
#   'dp_quattro_bandwidth': ('BSD Bandwidth', 'DC'),
#   'dp_4qbsd_q2': ('Q2', False),
#   'dp_dynfocus': ('Dyn.Focus', False),
#   'dp_supervisor': ('Supervisor', 'Disabled'),
#   'dp_colour_mode': ('Colour Mode', False),
#   'dp_tilt_correction': ('Tilt Corrn.', False),
#   'dp_spot': ('Spot', False),
#   'dp_fixed_aperture2': ('EP Aperture', 'None fitted'),
#   'dp_detector_fast_scan': ('Noise reduction for fast scanspeeds', False),
#   'dp_ion_detector_mode': ('SESI Mode', 'SE'),
#   'dp_fisheye_fitted': ('Fish-Eye Fitted', True),
#   'dp_stem_q2': ('STEM Q2', False),
#   'dp_pixel_size': ('Pix Size state', 'calibrated'),
#   'dp_ebbu_mode': ('Beam Blanker Mode', 'Blanked'),
#   'dp_fib_image_probe': ('FIB Image Probe', 'Undefined'),
#   'dp_ar_mill': ('Argon Mill', False),
#   'dp_fib_mag_range': ('FIB Mag Range', 0),
#   'dp_user_level': ('User Level', 'Expert'),
#   'dp_ar_scan': ('Argon Scan', False),
#   'dp_hp_status': ('Chamber Status', 'Power Up'),
#   'dp_column_type': ('Column', 1500),
#   'dp_large_beamshift': ('Large Beam Shift', False),
#   'dp_ar_mfcvalve': ('Argon MFC Valve', 'Closed'),
#   'dp_contrast_enhancement': ('Contrast Enhanced', False),
#   'dp_4qbsd_q3': ('Q3', False),
#   'dp_scan_rot': ('Scan Rot', False),
#   'dp_dc_sem_state': ('Sem drift status', 'Not Available'),
#   'dp_line_scan': ('Line Scan', False),
#   'dp_signalaz2': ('Signal A Z2', 'InLens'),
#   'dp_scm_range': ('SCM range', '3->10 pA'),
#   'dp_fib_fg_floodgun_type': ('Flood Gun Type', 'Flood Gun Unknown Type'),
#   'dp_stem_q3': ('STEM Q3', False),
#   'dp_mag_cal': ('Mag State', 'calibrated'),
#   'dp_hv_at_shutdown': ('Go to HV @ Shutdown', False),
#   'dp_scm_status': ('SCM Status', False),
#   'dp_si_source': ('SI source-hidden', 0),
#   'dp_conjugate': ('OptiBeam conjugate', False),
#   'dp_fib_fg_status': ('Flood Gun Status', False),
#   'dp_vp_optibeam': ('VP Optibeam', False),
#   'dp_condenser_reversed': ('Condenser Reversed', False),
#   'dp_z0': ('Zone 0', 'Frozen'),
#   'dp_fib_mill_probe': ('FIB Milling Probe', 'Undefined'),
#   'dp_scint': ('Scint.', True),
#   'dp_optiresmode': ('OptiBeam Res Mode', 'manual'),
#   'dp_jazz_bandwidth': ('Jazz Bandwidth', 'Low'),
#   'dp_igp_enabled': ('IGP Enabled', True),
#   'dp_gate_valve': ('WDX Gate valve', 'Closed'),
#   'dp_peltier': ('Peltier', False),
#   'dp_output_reduction': ('Output Reduction', 1),
#   'dp_4qbsd_q4': ('Q4', False),
#   'dp_aperture': ('Aperture No.', 1),
#   'dp_sem': ('Sem', 'Supra 40'),
#   'dp_scan_orthog': ('Scan Orthog', True),
#   'dp_display_channels': ('Channels', 1),
#   'dp_dual_monitor': ('Dual Monitor', False),
#   'dp_signalaz3': ('Signal A Z3', 'InLens'),
#   'dp_c3_rot_sign': ('C3 Rotn Sign', '+'),
#   'dp_stem_fast': ('STEM Fast', False),
#   'dp_out_dev': ('Output dev', '19/21 inch display'),
#   'dp_user': ('User', 'Idle'),
#   'dp_fib_track_wd': ('FIB Tracking WD', False),
#   'dp_fib_fg_interlock': ('Flood Gun Interlock', False),
#   'dp_low_kv_lens': ('Low KV Lens', 'Absent'),
#   'dp_z1': ('Zone 1', 'Frozen'),
#   'dp_cc_status': ('CC Status', False),
#   'dp_fib_gun_state': ('FIB Gun State', False),
#   'dp_ar_gun_state': ('Argon Gun is', False),
#   'dp_out_type': ('Output To', 'Display/File'),
#   'dp_column_chamber_valve': ('Column Chamber valve', 'Open'),
#   'dp_column_pumping': ('Column pumping', 'Ready'),
#   'dp_scanrate': ('Scan Speed', 9),
#   'dp_left_frozen': ('All Frozen', True),
#   'dp_operating_mode': ('Operating Mode', 'Normal'),
#   'dp_gis_channel': ('GIS Channel', 'None'),
#   'dp_fib_imaging': ('FIB Imaging', 'SEM'),
#   'dp_c3reversal': ('C3 Reversal', 'Normal'),
#   'dp_vac_mode': ('Vacuum Mode', 'High Vacuum'),
#   'dp_column_mode': ('Column Mode', 'High Resolution'),
#   'dp_stem_seg_mode': ('STEM Seg. Mode', False),
#   'dp_calmode': ('Cal Mode', False),
#   'dp_runupstate': ('Beam State', 'Beam On'),
#   'dp_noise_reduction': ('Noise Reduction', 'Pixel Avg.'),
#   'dp_optibeam_state': ('OptiBeam', False),
#   'dp_vacstatus': ('Vac Status', 'Ready'),
#   'ap_fib_fg_emission_target': ('Flood Gun Emission target', 0.0, 'µA'),
#   'ap_fib_shift_correction_y': ('FIB Shift Correction Y', 0.0, 'nm'),
#   'ap_mag': ('Mag', '399.85 K X'),
#   'ap_line_time': ('Line Time', 26.32, 'ms'),
#   'ap_fib_mag_fine_gain_y': ('FIB Mag fine gain Y', 0.0),
#   'ap_spot_posn_y': ('Spot at Y', 192),
#   'ap_scanorthog_lower': ('Orthogonality Lower', 0.0, '°'),
#   'ap_angular_3': ('Aa 4', 0.0, 'kV'),
#   'ap_stage_vector_x': ('Stage vector X', 0.0, '%'),
#   'ap_ar_condenser': ('Argon Condenser', 0, 'V'),
#   'ap_minmag': ('Min Mag', 90, 'X'),
#   'ap_stage_goto_r': ('Stage goto R', 4.2, '°'),
#   'ap_hp_target': ('VP Target', 10, 'Pa'),
#   'ap_eht_cal_100': ('EHT Cal@0.1KV', 108, 'V'),
#   'ap_ppa_6': ('Pa 7', 0.0, 'nm'),
#   'ap_v_3': ('V 4', 0.0, 'nm'),
#   'ap_stage_delta_r': ('Stage Delta R', 0.0, '°'),
#   'ap_file_number': ('File No', 1891),
#   'ap_esd_lower_y': ('ESD Lower Y', 0.0, '%'),
#   'ap_free_wd': ('Free WD', 4.0, 'mm'),
#   'ap_brightnessz3': ('Brightness D', 29.9, '%'),
#   'ap_fm_quadriture': ('Field Mode Quadriture', -1),
#   'ap_tilt_angle': ('Tilt Angle', 0.0, '°'),
#   'ap_mill_list_elapsed_time': ('Mill List Elapsed Time', 0, 'ms'),
#   'ap_stig_x': ('Stigmation X', -1.8, '%'),
#   'ap_ppb_2': ('Pb 3', 7.6, '°'),
#   'ap_magcal_upper_y': ('Calibrate Mag Upper Y', 0.0),
#   'ap_radial_1': ('Da 2', 0.0, 'nm'),
#   'ap_reduced_raster_width': ('Reduced Raster Width', 512),
#   'ap_vpse2_bias': ('VPSE G3 Bias', 60.0, '%'),
#   'ap_stage_low_z': ('Stage low Z', 0.0, 'mm'),
#   'ap_ar_mag': ('Argon Magnification', 0, 'X'),
#   'ap_ar_shift_ratio_y': ('Argon Shift Ratio Y', 0.0),
#   'ap_scan_offset_x': ('Scan X cal.', 0),
#   'ap_stage_high_t': ('Stage high T', 0.0, '°'),
#   'ap_profile_top': ('Profile Top', 300),
#   'ap_mag_gain_x': ('Mag Gain Cal X', 1000.0),
#   'ap_h_7': ('H 8', 0.0, 'nm'),
#   'ap_spacer_thickness': ('Spacer Thickness', 0.0, 'mm'),
#   'ap_stage_high_r': ('Stage high R', 380.0, '°'),
#   'ap_fib_condenser': ('FIB Condenser', 0, 'V'),
#   'ap_fib_fg_fil_current_target': ('Flood Gun Filament Target', 0, 'µA'),
#   'ap_dc_shift_x': ('Aperture Align X', 0.0, '%'),
#   'ap_sem_level_at_tilt': ('SEM Level @', 0.0, '°'),
#   'ap_vac_ready_at': ('Vac Ready @', 0.0001, 'mbar'),
#   'ap_c1rem': ('C1 Rem', 0.0105),
#   'ap_fib_slice_width': ('Slice Width', 0.0, 'nm'),
#   'ap_beamshift_y': ('Beam Shift Y', 11.6, '%'),
#   'ap_ppa_0': ('Pa 1', 20.43, 'µm'),
#   'ap_tilt_align_x': ('Tilt Align X', 0.0, '%'),
#   'ap_stage_xm_r': ('Stage X+M Rotation', 0.0, '°'),
#   'ap_si_topography': ('SmartImage Topography', 0.0, '%'),
#   'ap_stage_at_field_y': ('Stage at field Y', 1),
#   'ap_ar_angle': ('Argon Column Angle', 0.0, '°'),
#   'ap_test_n': ('Test No.', 0),
#   'ap_h_1': ('H 2', 0.0, 'nm'),
#   'ap_radial_area_0': ('Db 1', 0.0, 'nm²'),
#   'ap_opt_semiangle': ('Opt. Semi Angle', 0.0, 'µrad'),
#   'ap_fib_aperture_align_x': ('FIB Aper.Align X', 0),
#   'ap_fib_fil_i_target': ('FIB Fil I Target', 0, 'µA'),
#   'ap_dc_max_pix_error': ('Drift Max.Pix.Error', 1),
#   'ap_inlens_duo_grid_actual': ('InlensDuo Grid is', 0, 'V'),
#   'ap_fisheye_angle': ('Fisheye Angle', 0.0, '°'),
#   'ap_contrastz0': ('Contrast A', 41.5, '%'),
#   'ap_dual_mag_offset_y': ('Dual Mag Offset Y', 3.0),
#   'ap_mag_decl': ('Mag scaling decel', 1.0),
#   'ap_mag_gain_upper_x': ('Shift Amp Upper Gain X', 0.0),
#   'ap_holder_length': ('Holder Length', 0.0, 'mm'),
#   'ap_stage_fields_y': ('Stage fields Y', 1),
#   'ap_fib_source_lifetime': ('FIB Source Lifetime', 0.0, 'µAh'),
#   'ap_ar_gas_flow_actual': ('Argon Gas Flow is', 0.0, '%'),
#   'ap_gain': ('Gain A', 100.0, '%'),
#   'ap_conjugate': ('Conjugate posn.', -164.0, 'mm'),
#   'ap_mag_shift_x': ('Mag Shift Cal X', 0.0),
#   'ap_jazz_back_grid': ('Back Grid', 0, 'V'),
#   'ap_actualsupp': ('Suppressor V', 300, 'V'),
#   'ap_aperture_align_x': ('Aperture Align X', -10.4, '%'),
#   'ap_ppb_5': ('Pb 6', 0.0, '°'),
#   'ap_v_8': ('V 9', 0.0, 'nm'),
#   'ap_prof2_x2': ('Profile 2 X2', 0),
#   'ap_fib_magnification': ('FIB Mag', 0, 'X'),
#   'ap_fib_fg_emission_actual': ('Flood Gun Emission Actual', 0.0, 'µA'),
#   'ap_fib_shift_correction_x': ('FIB Shift Correction X', 0.0, 'nm'),
#   'ap_iprobe': ('I Probe', 200.0, 'nA'),
#   'ap_fcf_tilt': ('FCF Tilt Angle', 0.0, '°'),
#   'ap_fib_mag_fine_gain_x': ('FIB Mag fine gain X', 0.0),
#   'ap_stage_xm_angle': ('Stage X+M Angle', 8.0, '°'),
#   'ap_spot_posn_x': ('Spot at X', 256),
#   'ap_scanorthog_upper': ('Orthogonality Upper', 0.0, '°'),
#   'ap_angular_2': ('Aa 3', 0.0, 'kV'),
#   'ap_stage_goto_z': ('Stage goto Z', 49.5, 'mm'),
#   'ap_ar_discharge_current': ('Argon Discharge I is', 0.0, 'µA'),
#   'ap_spotsize': ('Spot Size', 1),
#   'ap_ppa_5': ('Pa 6', 0.0, 'nm'),
#   'ap_v_2': ('V 3', 0.0, 'nm'),
#   'ap_stage_delta_t': ('Stage Delta T', 0.0, '°'),
#   'ap_specimen_height': ('Specimen Height', 1, 'mm'),
#   'ap_esd_lower_x': ('ESD Lower X', 0.0, '%'),
#   'ap_fib_emission_current': ('FIB Emission I', 0.0, 'µA'),
#   'ap_fib_stig_y_centre_y': ('FIB Stig Y Centre Y', 0.0),
#   'ap_brightnessz2': ('Brightness C', 29.9, '%'),
#   'ap_fm_orthog': ('Field Mode Orthog', -1.0, '°'),
#   'ap_tilt_axis': ('Tilt Axis', 90.0, '°'),
#   'ap_mill_list_total_time': ('Mill List Total Time', 0, 'ms'),
#   'ap_apertureposn_y': ('Aperture Posn Y', 1.0, 'mm'),
#   'ap_ppb_1': ('Pb 2', 3.8, '°'),
#   'ap_magcal_upper_x': ('Calibrate Mag Upper X', 0.0),
#   'ap_radial_0': ('Da 1', 0.0, 'nm'),
#   'ap_epse_bias': ('EPSE Bias', 0.0, '%'),
#   'ap_profile_w': ('Profile width', 0.0, 'nm'),
#   'ap_stage_low_y': ('Stage low Y', 0.0, 'mm'),
#   'ap_ar_beam_shift_y': ('Argon Beam Shift Y', 0.0, 'nm'),
#   'ap_ar_shift_ratio_x': ('Argon Shift Ratio X', 0.0),
#   'ap_xtalk21': ('Xtalk21', 0.0),
#   'ap_min_ext': ('Min Extractor V', 3.0, 'kV'),
#   'ap_h_6': ('H 7', 0.0, 'nm'),
#   'ap_stage_centre_y': ('Stage Centre Y', 65.0, 'mm'),
#   'ap_fib_scan_size': ('FIB Scan Size', 0.0, 'nm'),
#   'ap_stig_cal_y': ('Stig. Cal Y', 0.0, '%'),
#   'ap_fib_ext_actual': ('FIB Extractor', 0.0, 'kV'),
#   'ap_fib_fg_energy_actual': ('Flood Gun Energy Actual', 0.0, 'V'),
#   'ap_fib_stig_x_centre_y': ('FIB Stig X Centre Y', 0.0),
#   'ap_piezo_goto_y': ('Piezo Goto Y', 0.0, 'µm'),
#   'ap_fib_tilt_comp': ('FIB Tilt Comp', 0.0, '°'),
#   'ap_c1cal': ('C1 Cal', 0.958),
#   'ap_fib_slice_y': ('Slice Y', 0.0, 'nm'),
#   'ap_beamshift_x': ('Beam Shift X', -12.9, '%'),
#   'ap_red_raster_h': ('Red.Raster Height', 151),
#   'ap_magcal_base': ('Calibrate Mag Base', 50000.0),
#   'ap_fib_nudge_step': ('FIB Nudge Step', 0.0, 'nm'),
#   'ap_piezo_exchange_y': ('Piezo Exchange Y', 0.0, 'µm'),
#   'ap_stage_at_field_x': ('Stage at field X', 1),
#   'ap_ar_acc_i': ('Argon Acc I is', 0.0, 'µA'),
#   'ap_ar_mill_progress': ('Argon Mill Progress', 0.0, '%'),
#   'ap_area_fraction': ('Area Fraction', 0.0, '%'),
#   'ap_nominalfil': ('Nominal Fil I', 2.25, 'A'),
#   'ap_gun_y': ('Gun at Y', 4.0, '%'),
#   'ap_stage_vector_m': ('Stage Vector M', 0.0, '%'),
#   'ap_h_0': ('H 1', 0.0, 'nm'),
#   'ap_semiangle': ('Semi Angle', 0.0, 'µrad'),
#   'ap_fib_scan_rotation': ('FIB Scan Rot', 0.0, '°'),
#   'ap_fib_fil_v': ('FIB Fil Voltage', 0.0, 'V'),
#   'ap_stageangle': ('Stage Angle', 180.0, '°'),
#   'ap_inlens_duo_grid': ('InlensDuo Grid', 0, 'V'),
#   'ap_manualcurrent': ('Fil I Target', 2.25, 'A'),
#   'ap_brightnessz1': ('Brightness B', 29.9, '%'),
#   'ap_dual_mag_offset_x': ('Dual Mag Offset X', 0.0),
#   'ap_mag_shift_lower_y': ('Shift Amp Lower Offset Y', 0.0),
#   'ap_holder_width': ('Holder Width', 0.0, 'mm'),
#   'ap_si_factor': ('SmartImage Sharpening', 0.0, '%'),
#   'ap_stage_fields_x': ('Stage fields X', 1),
#   'ap_fib_probe_current_actual': ('FIB Probe Current Actual', 0.0, 'pA'),
#   'ap_ar_gas_flow': ('Argon Gas Flow', 0.0, '%'),
#   'ap_gamma': ('Gamma', 1.0),
#   'ap_jazz_front_grid': ('Front Grid', 0, 'V'),
#   'ap_actualext': ('Extractor V', 5.4, 'kV'),
#   'ap_gunalign_y': ('Gun Align Y', 0.0, '%'),
#   'ap_max_extractor_v': ('Max Extractor V', 7.0, 'kV'),
#   'ap_ppb_4': ('Pb 5', 4.4, '°'),
#   'ap_v_7': ('V 8', 0.0, 'nm'),
#   'ap_prof2_x1': ('Profile 2 X1', 0),
#   'ap_fib_objective_potential': ('FIB Objective', 0, 'V'),
#   'ap_fib_fg_extractor_voltage': ('Flood Gun Extractor Voltage', 0, 'V'),
#   'ap_piezo_at_y': ('Piezo at Y', 0.0, 'µm'),
#   'ap_emissionzoom': ('Emission Zoom', 100),
#   'ap_zoom_factor': ('Zoom factor', 2.0),
#   'ap_fib_working_distance': ('FIB Working Distance', 0.0, 'mm'),
#   'ap_linetoframe_lower': ('Line To Frame Lower', 0.0),
#   'ap_angular_1': ('Aa 2', 0.0, '°'),
#   'ap_stage_goto_y': ('Stage goto Y', 50.711, 'mm'),
#   'ap_ar_discharge_actual': ('Argon Discharge is', 0, 'V'),
#   'ap_k2': ('Mix Signal', 0.0),
#   'ap_cc_pressure': ('CC Pressure', 0.0, '%'),
#   'ap_ppa_4': ('Pa 5', 218.2, 'nm'),
#   'ap_v_1': ('V 2', 0.0, 'nm'),
#   'ap_stage_delta_z': ('Stage Delta Z', 0.0, 'mm'),
#   'ap_esd_upper_y': ('ESD Upper Y', 0.0, '%'),
#   'ap_fib_abs_delta_beam_shift_y': ('FIB Abs Beam Shift Y', 0.0, 'nm'),
#   'ap_fib_suppressor_target': ('FIB Suppressor Target', 0, 'V'),
#   'ap_fib_stig_y_centre_x': ('FIB Stig Y Centre X', 0.0),
#   'ap_purge_min': ('Purge Min', 133, 'Pa'),
#   'ap_fib_column_pressure': ('FIB Column Pressure', 0.0, 'mbar'),
#   'ap_fm_angle': ('Field Mode Angle', -1.0, '°'),
#   'ap_c3rem': ('C3 Rem', 0.0137),
#   'ap_fib_pixel_size': ('FIB Pixel Size', 0.0, 'fm'),
#   'ap_apertureposn_x': ('Aperture Posn X', 5.0, 'mm'),
#   'ap_ppb_0': ('Pb 1', 0.5, '°'),
#   'ap_c3_save': ('C3 saved for beam decel', 0, 'µA'),
#   'ap_esb_grid_is': ('ESB Grid is', 0, 'V'),
#   'ap_eht_set_max': ('EHT set maximum', 30.0, 'kV'),
#   'ap_stage_low_x': ('Stage low X', 0.0, 'mm'),
#   'ap_ar_beam_shift_x': ('Argon Beam Shift X', 0.0, 'nm'),
#   'ap_ar_xy_ratio': ('Argon XY Ratio', 0.0),
#   'ap_frame_ampl': ('Frame Ampl Cal.', 0),
#   'ap_xtalk12': ('Xtalk12', 0.0),
#   'ap_manuallens': ('Liner Target', 8.0, 'kV'),
#   'ap_h_5': ('H 6', 0.0, 'nm'),
#   'ap_stage_centre_x': ('Stage Centre X', 65.0, 'mm'),
#   'ap_stig_cal_x': ('Stig. Cal X', 0.0, '%'),
#   'ap_fib_ext_target': ('FIB Extr.Target', 0.0, 'kV'),
#   'ap_fib_fg_energy_target': ('Flood Gun Energy Target', 0.0, 'V'),
#   'ap_fib_stig_x_centre_x': ('FIB Stig X Centre X', 0.0),
#   'ap_piezo_goto_x': ('Piezo Goto X', 0.0, 'µm'),
#   'ap_c2': ('C2 Lens I', 0, 'µA'),
#   'ap_mag_comp_offset': ('Mag Comp. Offset', 513),
#   'ap_fib_slice_x': ('Slice X', 0.0, 'nm'),
#   'ap_guntilt_y': ('Gun Tilt Y', 0.0, '%'),
#   'ap_red_raster_w': ('Red.Raster Width', 160),
#   'ap_scan_rotation_offset_lower': ('Scan Rotation Offset Lower', 0.0, '°'),
#   'ap_piezo_exchange_x': ('Piezo Exchange X', 0.0, 'µm'),
#   'ap_stage_goto_field_y': ('Stage goto field Y', 1),
#   'ap_ar_extractor_actual': ('Argon Extractor is', 0, 'V'),
#   'ap_auto_contrast': ('Auto C Target', 100.0, '%'),
#   'ap_implied_offset': ('Offset B', 0.0, '%'),
#   'ap_align1_y': ('Align 1 Y', 0.0, '%'),
#   'ap_beam_offset_y': ('Beam Offset Y', 1.153, 'µm'),
#   'ap_white_detect': ('White Threshold', 100.0, '%'),
#   'ap_gun_x': ('Gun at X', -9.5, '%'),
#   'ap_water_temp_limit': ('EO Temp Limit', 35.0, '°C'),
#   'ap_spot_x_cal': ('Spot X Cal', 0),
#   'ap_fib_beam_shift_y': ('FIB Beam Shift Y', 0.0, 'nm'),
#   'ap_fib_fil_i': ('FIB Fil Current', 0, 'µA'),
#   'ap_scanorthog': ('Scan Orth corrn', 0.8, '°'),
#   'ap_manualkv': ('EHT Target', 5.0, 'kV'),
#   'ap_magcalheight': ('Mag Cal Actual Height', 0.0, 'nm'),
#   'ap_brightnessz0': ('Brightness A', 29.9, '%'),
#   'ap_c3_decl': ('Decl cal 2', 1.0),
#   'ap_mag_shift_lower_x': ('Shift Amp Lower Offset X', 0.0),
#   'ap_holder_diameter': ('Holder Diameter', 50.0, 'mm'),
#   'ap_si_threshold': ('SmartImage Threshold', 0.0, '%'),
#   'ap_stage_scan_angle': ('Stage scan angle', 0.0, '°'),
#   'ap_fib_objective_actual': ('FIB Objective Actual', 0, 'V'),
#   'ap_ar_objective_actual': ('Argon Objective is', 0, 'V'),
#   'ap_line_int_count': ('Line int. count', 1),
#   'ap_filament_age': ('Filament Age', 62717.03, 'Hours'),
#   'ap_dual_mag_y_slope': ('Dual Mag Gain Y', 670.0),
#   'ap_stage_vector_t': ('Stage vector T', 0.0, '%'),
#   'ap_hcstage_temp': ('Peltier Temp', 20.0, '°C'),
#   'ap_gunalign_x': ('Gun Align X', 0.0, '%'),
#   'ap_eht_cal_30kv': ('EHT Cal@30KV', 30.06, 'kV'),
#   'ap_ppa_9': ('Pa 10', 0.0, 'nm'),
#   'ap_v_6': ('V 7', 0.0, 'nm'),
#   'ap_prof1_x2': ('Profile 1 X2', 59),
#   'ap_stage_bias_voltage': ('Stage bias Low Volts', 0.0, 'V'),
#   'ap_vp_limit': ('VP LaB6 Limit', 274, 'Pa'),
#   'ap_fib_eht_actual': ('FIB EHT', 0.0, 'kV'),
#   'ap_humidity_target': ('Humidity Target', 0.0, '%'),
#   'ap_piezo_at_x': ('Piezo at X', 0.0, 'µm'),
#   'ap_linetoframe_upper': ('Line To Frame Upper', 0.0),
#   'ap_angular_0': ('Aa 1', 0.0, '°'),
#   'ap_reduced_raster_y': ('Reduced Raster Y', 192),
#   'ap_laser_finder_illum': ('Laser Illumination', 0.0, '%'),
#   'ap_stage_goto_x': ('Stage goto X', 51.808, 'mm'),
#   'ap_column_vac': ('Gun Vacuum', 3.61e-10, 'mbar'),
#   'ap_ar_discharge': ('Argon Discharge', 0, 'V'),
#   'ap_k1': ('Signal', 1.0),
#   'ap_line_average_count': ('Line Avg.Count', 2),
#   'ap_beam_time': ('Beam Time', 4592.74, 'Hours'),
#   'ap_cursor_height': ('Cursor Height', 0.0, 'nm'),
#   'ap_profile_w2': ('Profile Width 2', 0.0, 'nm'),
#   'ap_v_0': ('V 1', 0.0, 'nm'),
#   'ap_stage_delta_y': ('Stage Delta Y', 0.0, 'mm'),
#   'ap_polaris_probe_cal': ('Probe Cal Factor', 1.0),
#   'ap_esd_upper_x': ('ESD Upper X', 0.0, '%'),
#   'ap_fib_abs_delta_beam_shift_x': ('FIB Abs Beam Shift X', 0.0, 'nm'),
#   'ap_fib_drift_y': ('FIB Drift Y', 0.0, 'nm'),
#   'ap_purge_max': ('Purge Max', 1066, 'Pa'),
#   'ap_fib_heating_limit': ('FIB Heating Limit', 0, 'µA'),
#   'ap_c3cal': ('C3 Cal', 0.939),
#   'ap_line_counter': ('Line Counter', 767),
#   'ap_aperturesize': ('Aperture Size', 30.0, 'µm'),
#   'ap_ppa_3': ('Pa 4', 239.8, 'nm'),
#   'ap_wd_save': ('wd saved for beam decel', 10.0, 'mm'),
#   'ap_liner_cal_at_10kv': ('Liner Cal @ 10KV', 10000, 'V'),
#   'ap_beam_current': ('Beam Current', 80.0, 'µA'),
#   'ap_stage_high_z': ('Stage high Z', 49.5, 'mm'),
#   'ap_ion_convertor_voltage': ('Convertor Voltage', 0.0, 'kV'),
#   'ap_ar_mag_factor': ('Argon Mag Factor', 0.0, 'nm'),
#   'ap_mag1': ('Mag Z1', 1.0),
#   'ap_manualsupp': ('Suppressor V Target', 300, 'V'),
#   'ap_h_4': ('H 5', 0.0, 'nm'),
#   'ap_sample_height': ('Compu. Height', 0.0, 'mm'),
#   'ap_fib_aper_y_actual': ('FIB Aperture Y Actual', 0),
#   'ap_fib_emission_target': ('FIB Emission Target', 0.0, 'µA'),
#   'ap_c1': ('C1 Lens I', 0, 'µA'),
#   'ap_mag_comp_ampl': ('Mag Comp. Amplitude', 37.0, '%'),
#   'ap_fib_slice_index': ('Slice Index', 0),
#   'ap_guntilt_x': ('Gun Tilt X', 0.0, '%'),
#   'ap_red_raster_posn_y': ('Red.Raster Posn Y', 244),
#   'ap_mag_gain_lower_y': ('Shift Amp Lower Gain Y', 0.0),
#   'ap_holder_height': ('Holder Height', 13.7, 'mm'),
#   'ap_specimen_diameter': ('Specimen Diameter', 10, 'mm'),
#   'ap_stage_goto_field_x': ('Stage goto field X', 1),
#   'ap_ar_extractor': ('Argon Extractor', 0, 'V'),
#   'ap_auto_bright': ('Auto B Target', 100.0, '%'),
#   'ap_implied_gain': ('Gain B', 100.0, '%'),
#   'ap_align1_x': ('Align 1 X', 0.0, '%'),
#   'ap_beam_offset_x': ('Beam Offset X', -1.26, 'µm'),
#   'ap_black_detect': ('Black Threshold', 0.0, '%'),
#   'ap_nominalext': ('Nominal extractor V', 5.4, 'kV'),
#   'ap_aperture_y': ('Aperture at Y', 1.3, '%'),
#   'ap_stage_high_m': ('Stage high M', 0.0, 'mm'),
#   'ap_water_temp': ('EO Temp', 24.0, '°C'),
#   'ap_user_max_eht': ('User Max EHT', 30.0, 'kV'),
#   'ap_ccd_illumination': ('CCD Illum.', 85.0, '%'),
#   'ap_fib_beam_shift_x': ('FIB Beam Shift X', 0.0, 'nm'),
#   'ap_scanrotation': ('Scan Rotation', 0.0, '°'),
#   'ap_fib_focus': ('FIB Focus', 0.0),
#   'ap_usermaxcurrent': ('Fil I (Usermax)', 4.0, 'A'),
#   'ap_magcalwidth': ('Mag Cal Actual Width', 0.0, 'nm'),
#   'ap_defect_id': ('Defect ID', 0),
#   'ap_wd_decl': ('Decl cal 1', 0.0),
#   'ap_mag_shift_upper_y': ('Shift Amp Upper Offset Y', 0.0),
#   'ap_si_enhancement': ('SmartImage Contrast', 0.0, '%'),
#   'ap_stage_vector_z': ('Stage vector Z', 0.0, '%'),
#   'ap_ar_objective': ('Argon Objective', 0, 'V'),
#   'ap_frame_int_count': ('Frames to Int.', 0),
#   'ap_alias_wd': ('Focus', 4.022, 'mm'),
#   'ap_stage_vector_r': ('Stage vector R', 0.0, '%'),
#   'ap_eht_cal_24kv': ('EHT Cal@24KV', 24.08, 'kV'),
#   'ap_ppa_8': ('Pa 9', 0.0, 'nm'),
#   'ap_v_5': ('V 6', 0.0, 'nm'),
#   'ap_prof1_x1': ('Profile 1 X1', 33),
#   'ap_hrru_number': ('HRRU No.', 0),
#   'ap_fib_eht_target': ('FIB EHT Target', 0.0, 'kV'),
#   'ap_humidity': ('Humidity', 0.0, '%'),
#   'ap_esb_grid_max': ('ESB Grid Max', 100, 'V'),
#   'ap_contrastz3': ('Contrast D', 41.5, '%'),
#   'ap_mill_item_elapsed_time': ('Mill Item Elapsed Time', 0, 'ms'),
#   'ap_stage_bias_voltage_high': ('Beam deceleration Volts', 0, 'V'),
#   'ap_magcal_lower_y': ('Calibrate Mag Lower Y', 0.0),
#   'ap_radial_3': ('Da 4', 0.0, 'nm'),
#   'ap_fib_condenser_actual': ('FIB Condenser actual', 0, 'V'),
#   'ap_ar_acc_actual': ('Argon Energy is', 0, 'V'),
#   'ap_scm': ('Specimen I', 0.0, 'pA'),
#   'ap_photo_number': ('Photo No.', 8273),
#   'ap_field_overlap': ('Field Overlap', 0.0, '%'),
#   'ap_spot': ('Spot signal', 0),
#   'ap_cursor_width': ('Cursor Width', 15.6, 'nm'),
#   'ap_profile_w1': ('Profile Width 1', 52.89, 'nm'),
#   'ap_h_9': ('H 10', 0.0, 'nm'),
#   'ap_stage_delta_x': ('Stage Delta X', 0.0, 'mm'),
#   'ap_compu_tilt_error': ('Compu. Tilt Error', 0.0),
#   'ap_fib_drift_x': ('FIB Drift X', 0.0, 'nm'),
#   'ap_purge_cycles': ('Purge cycles', 2),
#   'ap_c3': ('C3 Lens I', 962.37, 'mA'),
#   'ap_epd_low': ('EPD Low Limit', 0),
#   'ap_c2rem': ('C2 Rem', 0.0318),
#   'ap_fib_slice_angle': ('Slice Angle', 0.0, '°'),
#   'ap_zoompos_y': ('Zoom Posn Y', 192),
#   'ap_ppa_2': ('Pa 3', 134.0, 'nm'),
#   'ap_clip_limit': ('Clip Limit', 0),
#   'ap_liner_cal_at_100v': ('Liner cal @ 100V', 100, 'V'),
#   'ap_pixel_size': ('Pixel Size', 918.3, 'pm'),
#   'ap_stage_high_y': ('Stage high Y', 130.0, 'mm'),
#   'ap_ion_collector_voltage': ('Collector Voltage', 0.0, 'kV'),
#   'ap_ar_pixel_size': ('Argon Pixel Size', 0.0, 'fm'),
#   'ap_mag0': ('Mag Z0', 1.0),
#   'ap_min_wd': ('Focus scan min', 1, 'mm'),
#   'ap_manualext': ('Extractor V Target', 5.4, 'kV'),
#   'ap_h_3': ('H 4', 0.0, 'nm'),
#   'ap_image_pixel_size': ('Image Pixel Size', 918.3, 'pm'),
#   'ap_fib_aper_x_actual': ('FIB Aperture X Actual', 0),
#   'ap_fib_suppressor': ('FIB Suppressor', 0, 'V'),
#   'ap_dc_max_attempts': ('Drift Max Tries', 10),
#   'ap_beam_shift_align_y': ('Beam Shift Align Y', 0.0, 'nm'),
#   'ap_brightness': ('Brightness', 29.9, '%'),
#   'ap_fisheye_quadriture': ('Fisheye quadriture', 1000),
#   'ap_gunshift_y': ('Gun Shift Y', 0.0, '%'),
#   'ap_red_raster_posn_x': ('Red.Raster Posn X', 706),
#   'ap_mag_gain_lower_x': ('Shift Amp Lower Gain X', 0.0),
#   'ap_stage_field_size_y': ('Stage field size Y', 0.0, 'mm'),
#   'ap_ar_v_int_actual': ('Argon V Int is', 0, 'V'),
#   'ap_contrast': ('Contrast', 41.5, '%'),
#   'ap_height': ('Height', 705.3, 'nm'),
#   'ap_eht_set_min': ('EHT Set minimum', 0.01, 'kV'),
#   'ap_extcurrent': ('Ext I Monitor', 136.4, 'µA'),
#   'ap_aperture_x': ('Aperture at X', 8.5, '%'),
#   'ap_stage_low_m': ('Stage low M', 0.0, 'mm'),
#   'ap_fcf_setting': ('FCF Setting', 0.0, '%'),
#   'ap_radial_area_3': ('Db 4', 0.0, 'nm²'),
#   'ap_fib_stigmator_y': ('FIB Stig Y', 0.0, '%'),
#   'ap_frame_counter': ('Frame Counter', 30016),
#   'ap_fib_fg_fil_current_actual': ('Flood Gun Filament Actual', 0, 'µA'),
#   'ap_ep_target': ('EP Target', 10, 'Pa'),
#   'ap_wd': ('WD', 4.022, 'mm'),
#   'ap_hsync_delay': ('HSync delay', 0, 'ns'),
#   'ap_frame_time': ('Cycle Time', 20.2, 'Secs'),
#   'ap_fib_gun_pressure': ('FIB Gun Pressure', 0.0, 'mbar'),
#   'ap_mag_shift_upper_x': ('Shift Amp Upper Offset X', 0.0),
#   'ap_compu_tilt_offset': ('Compu. Tilt Offset', 0.0, 'mm'),
#   'ap_stage_vector_y': ('Stage vector Y', 0.0, '%'),
#   'ap_ar_condenser_actual': ('Argon Condenser is', 0, 'V'),
#   'ap_frame_average_count': ('Frames to average', 1),
#   'ap_dual_mag_slope': ('Dual Mag Gain X', 670.65),
#   'ap_stage_goto_t': ('Stage goto T', 0.0, '°'),
#   'ap_chamber_pressure': ('Chamber', 0.0, 'Pa'),
#   'ap_eht_cal_10kv': ('EHT Cal@10KV', 10.03, 'kV'),
#   'ap_ppa_7': ('Pa 8', 0.0, 'nm'),
#   'ap_v_4': ('V 5', 0.0, 'nm'),
#   'ap_stage_delta_m': ('Stage Delta M', 0.0, 'mm'),
#   'ap_print_number': ('Print No.', 0),
#   'ap_esd_excitation': ('ESD Excitation', 0.0, '%'),
#   'ap_peltier_target': ('Peltier Target', 20.0, '°C'),
#   'ap_esb_grid': ('ESB Grid', 100, 'V'),
#   'ap_contrastz2': ('Contrast C', 41.5, '%'),
#   'ap_mill_item_total_time': ('Mill Item Total Time', 0, 'ms'),
#   'ap_stig_y': ('Stigmation Y', 13.1, '%'),
#   'ap_ppb_3': ('Pb 4', 4.2, '°'),
#   'ap_magcal_lower_x': ('Calibrate Mag Lower X', 0.0),
#   'ap_radial_2': ('Da 3', 0.0, 'nm'),
#   'ap_system_vac': ('System Vacuum', 3.02e-06, 'mbar'),
#   'ap_ar_acc': ('Argon Energy', 0, 'V'),
#   'ap_scan_offset_y': ('Scan Y cal.', 0),
#   'ap_stage_low_t': ('Stage low T', 0.0, '°'),
#   'ap_mag_gain_y': ('Mag Gain Cal Y', 1000.0),
#   'ap_h_8': ('H 9', 0.0, 'nm'),
#   'ap_stage_low_r': ('Stage low R', -380.0, '°'),
#   'ap_dc_shift_y': ('Aperture Align Y', 0.0, '%'),
#   'ap_fib_sem_angle': ('FIB SEM Angle', 54.0, '°'),
#   'ap_epd_high': ('EPD High Limit', 0),
#   'ap_c2cal': ('C2 Cal', 1.063),
#   'ap_fib_slice_height': ('Slice Height', 0.0, 'nm'),
#   'ap_zoompos_x': ('Zoom Posn X', 128),
#   'ap_ppa_1': ('Pa 2', 399.5, 'nm'),
#   'ap_tilt_align_y': ('Tilt Align Y', 0.0, '%'),
#   'ap_fib_min_autoheat_current': ('FIB Min. Autoheat Current', 0, 'µA'),
#   'ap_chamber_pressure_detailed': ('Chamber Pressure Detailed', 0.0, 'Pa'),
#   'ap_stage_high_x': ('Stage high X', 130.0, 'mm'),
#   'ap_collector_bias': ('Collector Bias', 400, 'V'),
#   'ap_max_wd': ('Focus scan max', 40, 'mm'),
#   'ap_test_val': ('Test Val', 0.0),
#   'ap_h_2': ('H 3', 0.0, 'nm'),
#   'ap_radial_area_1': ('Db 2', 0.0, 'nm²'),
#   'ap_fib_aperture_align_y': ('FIB Aper.Align Y', 0),
#   'ap_fib_fil_v_target': ('FIB Fil V target', 0.0, 'V'),
#   'ap_dc_min_conf': ('Drift Min Conf', 50.0, '%'),
#   'ap_beam_shift_align_x': ('Beam Shift Align X', 0.0, 'nm'),
#   'ap_fisheye_orthog': ('Fisheye Orthog', 0.0, '°'),
#   'ap_gunshift_x': ('Gun Shift X', 0.0, '%'),
#   'ap_contrastz1': ('Contrast B', 41.5, '%'),
#   'ap_focus_rotation_comp': ('Focus Rotation comp.', -0.009, 'kV'),
#   'ap_mag_gain_upper_y': ('Shift Amp Upper Gain Y', 0.0),
#   'ap_fib_track_wd_delta': ('FIB Track WD Delta', 0.0, 'nm'),
#   'ap_stage_field_size_x': ('Stage field size X', 0.0, 'mm'),
#   'ap_ar_v_int': ('Argon V Int', 0, 'V'),
#   'ap_offset': ('Offset A', 0.0, '%'),
#   'ap_width': ('Width', 940.4, 'nm'),
#   'ap_mag_shift_y': ('Mag Shift Cal Y', 0.0),
#   'ap_pirani_pressure': ('Pirani Pressure', 0.0, 'mbar'),
#   'ap_actuallens': ('Liner Tube', 8.0, 'kV'),
#   'ap_aperture_align_y': ('Aperture Align Y', 1.3, '%'),
#   'ap_stage_goto_m': ('Stage goto M', 0.0, 'mm'),
#   'ap_ppb_6': ('Pb 7', 0.0, '°'),
#   'ap_v_9': ('V 10', 0.0, 'nm'),
#   'ap_radial_area_2': ('Db 3', 0.0, 'nm²'),
#   'ap_fib_fg_serial_number': ('Flood Gun Serial Number', 0),
#   'ap_fib_stigmator_x': ('FIB Stig X', 0.0, '%'),
#   'ap_stage_at_m': ('Stage at M', 0.0, 'mm'),
#   'ap_stage_at_z': ('Stage at Z', 48.298, 'mm'),
#   'ap_stage_at_y': ('Stage at Y', 50.7109, 'mm'),
#   'ap_actualcurrent': ('Fil I', 2.25, 'A'),
#   'ap_stage_at_x': ('Stage at X', 51.8077, 'mm'),
#   'ap_actualkv': ('EHT', 5.0, 'kV'),
#   'ap_stage_at_t': ('Stage at T', 0.0, '°'),
#   'ap_sample_at_y': ('Sample at Y', 0.0),
#   'ap_stage_at_r': ('Stage at R', 165.2, '°'),
#   'ap_sample_at_x': ('Sample at X', 0.0),
#   'ap_time': ('Time', '18:30:26'),
#   'ap_date': ('Date', '1 Apr 2015'),
#   'sv_version': ('Version', 'V05.07.00.00 : 08-Jul-14'),
#   'sv_user_text': ('User Text', ''),
#   'sv_file_name': ('File Name', 'Au-Gr_06.tif'),
#   'sv_image_path': ('Images', 'e:\\images\\alessia\\2015-04-01\\'),
#   'sv_user_name': ('User Name', 'USER'),
#   'sv_sample_id': ('Sample ID', ''),
#   'sv_serial_number': ('Serial No.', 'SUPRA 40-25-40'),
#   'sv_operator': ('Operator', '')}}

# %% [markdown]
# This also works as necessary, with the same variable names.

# %% [markdown]
# # SEM_image_sample_Thermo_Fisher_Helios_G4_PFIB_CXe.tif
#
# Helios PFIB instrument

# %%
f = hs.load(images[4])
Helios_PFIB = f.original_metadata.as_dictionary()

del Helios_PFIB['StripOffsets']
del Helios_PFIB['StripByteCounts']

Helios_PFIB
# Out:
# {'ImageWidth': 1536,
#  'ImageLength': 1094,
#  'BitsPerSample': (8, 8, 8),
#  'Compression': <COMPRESSION.NONE: 1>,
#  'PhotometricInterpretation': <PHOTOMETRIC.RGB: 2>,
#  'SamplesPerPixel': 3,
#  'RowsPerStrip': 1,
#  'XResolution': (96, 1),
#  'YResolution': (96, 1),
#  'PlanarConfiguration': <PLANARCONFIG.CONTIG: 1>,
#  'ResolutionUnit': <RESUNIT.INCH: 2>,
#  'ExifTag': {'ImageUniqueID': 'C76330991CBF832D40B3A3749A15EB30'},
#  'fei_metadata': {'User': {'Date': '03/17/2022',
#    'Time': '11:05:00 AM',
#    'User': 'user',
#    'UserText': 'HeliosPFIB',
#    'UserTextUnicode': '480065006C0069006F0073005000460049004200'},
#   'System': {'Type': 'DualBeam',
#    'Dnumber': 9952707,
#    'Software': '14.5.1.432',
#    'BuildNr': 432,
#    'Source': 'FEG',
#    'Column': 'Elstar',
#    'FinalLens': 'Elstar',
#    'Chamber': 'xT-SDB',
#    'Stage': '110 x 110',
#    'Pump': 'TMP',
#    'ESEM': 'no',
#    'Aperture': 'AVA',
#    'Scan': 'PIA 3.0',
#    'Acq': 'PIA 3.0',
#    'EucWD': 0.004,
#    'SystemType': 'Helios G4 PFIB CXe',
#    'DisplayWidth': 0.518,
#    'DisplayHeight': 0.324},
#   'Beam': {'HV': 20000,
#    'Spot': 2,
#    'StigmatorX': 0,
#    'StigmatorY': 0,
#    'BeamShiftX': -1.60064e-07,
#    'BeamShiftY': 5.87256e-06,
#    'ScanRotation': 0,
#    'ImageMode': 'Normal',
#    'FineStageBias': '',
#    'Beam': 'EBeam',
#    'Scan': 'EScan'},
#   'EBeam': {'Source': 'FEG',
#    'ColumnType': 'Elstar',
#    'FinalLens': 'Elstar',
#    'Acq': 'PIA 3.0',
#    'Aperture': 'AVA',
#    'ApertureDiameter': 6.4e-05,
#    'HV': 20000,
#    'HFW': 0.0004144,
#    'VFW': 0.000276267,
#    'WD': 0.00794789,
#    'BeamCurrent': 3.2e-09,
#    'TiltCorrectionIsOn': 'no',
#    'DynamicFocusIsOn': 'no',
#    'DynamicWDIsOn': '',
#    'ScanRotation': 0,
#    'LensMode': 'Field-Free',
#    'LensModeA': '',
#    'ATubeVoltage': '',
#    'UseCase': '',
#    'SemOpticalMode': '',
#    'ImageMode': 'Normal',
#    'SourceTiltX': 0,
#    'SourceTiltY': 0,
#    'StageX': -0.00333226,
#    'StageY': -0.0115452,
#    'StageZ': 0.00800001,
#    'StageR': 1.49703,
#    'StageTa': 1.95126e-06,
#    'StageTb': 0,
#    'StigmatorX': 0,
#    'StigmatorY': 0,
#    'BeamShiftX': -1.60064e-07,
#    'BeamShiftY': 5.87256e-06,
#    'EucWD': 0.004,
#    'EmissionCurrent': '',
#    'TiltCorrectionAngle': 1.22173,
#    'PreTilt': '',
#    'WehneltBias': '',
#    'BeamMode': 'N-Beam',
#    'MagnificationCorrection': 'Off'},
#   'GIS': {'Number': 0},
#   'Scan': {'InternalScan': True,
#    'Dwelltime': 1e-05,
#    'PixelWidth': 2.69792e-07,
#    'PixelHeight': 2.69792e-07,
#    'HorFieldsize': 0.0004144,
#    'VerFieldsize': 0.000276267,
#    'Average': 0,
#    'Integrate': 1,
#    'FrameTime': 15.8208},
#   'EScan': {'Scan': 'PIA 3.0',
#    'InternalScan': True,
#    'Dwell': 1e-05,
#    'PixelWidth': 2.69792e-07,
#    'PixelHeight': 2.69792e-07,
#    'HorFieldsize': 0.0004144,
#    'VerFieldsize': 0.000276267,
#    'FrameTime': 15.8208,
#    'LineTime': 0.01545,
#    'Mainslock': 'Off',
#    'LineIntegration': 1,
#    'ScanInterlacing': 1},
#   'Stage': {'StageX': -0.00333242,
#    'StageY': -0.0115393,
#    'StageZ': 0.00800001,
#    'StageR': 1.49703,
#    'StageT': 1.95126e-06,
#    'StageTb': 0,
#    'SpecTilt': '',
#    'WorkingDistance': 0.00794789,
#    'ActiveStage': 'Bulk'},
#   'Image': {'DigitalContrast': 1,
#    'DigitalBrightness': 0,
#    'DigitalGamma': 1,
#    'Average': 0,
#    'Integrate': 1,
#    'ResolutionX': 1536,
#    'ResolutionY': 1024,
#    'DriftCorrected': '',
#    'ZoomFactor': 1.0,
#    'ZoomPanX': 0.5,
#    'ZoomPanY': 0.5,
#    'MagCanvasRealWidth': 0.2072,
#    'MagnificationMode': 3,
#    'ScreenMagCanvasRealWidth': 0.4144,
#    'ScreenMagnificationMode': 1,
#    'PostProcessing': 'None',
#    'Transformation': 'None'},
#   'Vacuum': {'ChPressure': 8.97e-05,
#    'Gas': '',
#    'UserMode': 'High vacuum',
#    'Humidity': ''},
#   'Specimen': {'Temperature': '', 'SpecimenCurrent': 0},
#   'Detectors': {'Number': 1, 'Name': 'CBS', 'Mode': 'SE'},
#   'CBS': {'Contrast': 40.433,
#    'Brightness': 48.1873,
#    'Signal': 'BSE',
#    'Mix': 100,
#    'ContrastDB': 40.2106,
#    'BrightnessDB': 48.1873,
#    'Setting': 'A+B+C+D',
#    'MinimumDwellTime': ''},
#   'Accessories': {'Number': 0},
#   'PrivateFei': {'BitShift': 0,
#    'DataBarSelected': 'DateTime HV mag HFW Label MicronBar WD det tilt',
#    'DataBarAvailable': 'LensMode srot frame dwell curr WD PW mag HFW x y z tilt rotation filter det DateTime mode driftCorr pressure zoom HV Label MicronBar',
#    'TimeOfCreation': '17.03.2022 11:05:00',
#    'DatabarHeight': 0},
#   'HiResIllumination': {'BrightFieldIsOn': '',
#    'BrightFieldValue': '',
#    'DarkFieldIsOn': '',
#    'DarkFieldValue': ''},
#   'EasyLift': {'Rotation': 0},
#   'HotStageMEMS': {'HeatingCurrent': '',
#    'HeatingVoltage': '',
#    'TargetTemperature': '',
#    'ActualTemperature': '',
#    'HeatingPower': '',
#    'SampleBias': '',
#    'SampleResistance': ''}}}

# %% [markdown]
# Here we start getting a little bit of trouble. The output is nicely formatted, in a neat standardized way, but sadly, different from the previous entries. One could make a map for these too, but there also appear to be some components missing (units for some of the values, for one). It could be that some entries have names I don't recognize, and are therefore not missing, but I couldn't find some of the values.

# %% [markdown]
# # SEM_image_sample_FEI_Helios_Nanolab600.tif
#
# Helios Nanolab instrument

# %%
f = hs.load(images[5])
Helios_Nanolab = f.original_metadata.as_dictionary()

del Helios_Nanolab['StripOffsets']
del Helios_Nanolab['StripByteCounts']

Helios_Nanolab
# Out:
# {'NewSubfileType': <FILETYPE.UNDEFINED: 0>,
#  'ImageWidth': 1024,
#  'ImageLength': 943,
#  'BitsPerSample': (8, 8, 8),
#  'Compression': <COMPRESSION.NONE: 1>,
#  'PhotometricInterpretation': <PHOTOMETRIC.RGB: 2>,
#  'SamplesPerPixel': 3,
#  'RowsPerStrip': 1,
#  'XResolution': (68, 1),
#  'YResolution': (68, 1),
#  'PlanarConfiguration': <PLANARCONFIG.CONTIG: 1>,
#  'ResolutionUnit': <RESUNIT.CENTIMETER: 3>,
#  'fei_metadata': {'User': {'Date': '07/30/2013',
#    'Time': '11:11:11 AM',
#    'User': 'user',
#    'UserText': '',
#    'UserTextUnicode': ''},
#   'System': {'Type': 'DualBeam',
#    'Dnumber': 'D0512',
#    'Software': '3.8.9.1943',
#    'BuildNr': 1943,
#    'Source': 'FEG',
#    'Column': 'Elstar',
#    'FinalLens': 'Elstar',
#    'Chamber': 'xT-SDB',
#    'Stage': '6inch',
#    'Pump': 'TMP',
#    'ESEM': 'no',
#    'Aperture': 'AVA',
#    'Scan': 'PIA 1.0',
#    'Acq': 'PIA 1.0',
#    'EucWD': 0.004,
#    'SystemType': 'Helios NanoLab',
#    'DisplayWidth': 0.32,
#    'DisplayHeight': 0.24},
#   'Beam': {'HV': 10000,
#    'Spot': '',
#    'StigmatorX': 0.0158599,
#    'StigmatorY': -0.0259967,
#    'BeamShiftX': -2.9909e-07,
#    'BeamShiftY': 4.99693e-10,
#    'ScanRotation': 0,
#    'ImageMode': 'Normal',
#    'Beam': 'EBeam',
#    'Scan': 'EScan'},
#   'EBeam': {'Source': 'FEG',
#    'ColumnType': 'Elstar',
#    'FinalLens': 'Elstar',
#    'Acq': 'PIA 1.0',
#    'Aperture': 'AVA',
#    'ApertureDiameter': 2.30502e-08,
#    'HV': 10000,
#    'HFW': 6.4e-05,
#    'VFW': 5.525e-05,
#    'WD': 0.00382807,
#    'BeamCurrent': 8.59375e-11,
#    'TiltCorrectionIsOn': 'no',
#    'DynamicFocusIsOn': 'no',
#    'ScanRotation': 0,
#    'LensMode': 'Field-Free',
#    'SemOpticalMode': '',
#    'ImageMode': 'Normal',
#    'SourceTiltX': -0.0122206,
#    'SourceTiltY': -0.0101027,
#    'StageX': -0.00378379,
#    'StageY': 0.0050439,
#    'StageZ': 0.00399275,
#    'StageR': 7.5311e-05,
#    'StageTa': 0.907554,
#    'StageTb': 0,
#    'StigmatorX': 0.0158599,
#    'StigmatorY': -0.0259967,
#    'BeamShiftX': -2.9909e-07,
#    'BeamShiftY': 4.99693e-10,
#    'EucWD': 0.004,
#    'EmissionCurrent': '',
#    'TiltCorrectionAngle': 0,
#    'WehneltBias': ''},
#   'GIS': {'Number': 3},
#   'GIS1': {'GasType': '',
#    'HeaterState': '',
#    'NeedleState': '',
#    'GasFlow': '',
#    'Port': 'G1'},
#   'GIS2': {'GasType': 'IEE',
#    'HeaterState': 'Off',
#    'NeedleState': 'Retracted',
#    'GasFlow': 'Off',
#    'Port': 'G2'},
#   'GIS3': {'GasType': '',
#    'HeaterState': '',
#    'NeedleState': '',
#    'GasFlow': '',
#    'Port': ''},
#   'Scan': {'InternalScan': True,
#    'Dwelltime': 3e-05,
#    'PixelWidth': 6.25e-08,
#    'PixelHeight': 6.25e-08,
#    'HorFieldsize': 6.4e-05,
#    'VerFieldsize': 5.525e-05,
#    'Average': 0,
#    'Integrate': 1,
#    'FrameTime': 28.4191},
#   'EScan': {'Scan': 'PIA 1.0',
#    'InternalScan': True,
#    'Dwell': 3e-05,
#    'PixelWidth': 6.25e-08,
#    'PixelHeight': 6.25e-08,
#    'HorFieldsize': 6.4e-05,
#    'VerFieldsize': 5.525e-05,
#    'FrameTime': 28.4191,
#    'LineTime': 0.03186,
#    'Mainslock': 'Off',
#    'LineIntegration': 1,
#    'ScanInterlacing': 1},
#   'Stage': {'StageX': -0.00378409,
#    'StageY': 0.00504391,
#    'StageZ': 0.00399275,
#    'StageR': 7.5311e-05,
#    'StageT': 0.907554,
#    'StageTb': 0,
#    'SpecTilt': 0,
#    'WorkingDistance': 0.00382807},
#   'Image': {'DigitalContrast': 1,
#    'DigitalBrightness': 0,
#    'DigitalGamma': 1,
#    'Average': 0,
#    'Integrate': 1,
#    'ResolutionX': 1024,
#    'ResolutionY': 884,
#    'ZoomFactor': 1,
#    'MagCanvasRealWidth': 0.128,
#    'MagnificationMode': 3},
#   'Vacuum': {'ChPressure': 0.004758,
#    'Gas': '',
#    'UserMode': 'High vacuum',
#    'Humidity': ''},
#   'Specimen': {'Temperature': ''},
#   'Detectors': {'Number': 1, 'Name': 'ETD', 'Mode': 'SE'},
#   'ETD': {'Contrast': 81.3131,
#    'Brightness': 40.0567,
#    'Mix': 100,
#    'Signal': 'SE',
#    'Grid': 250,
#    'ContrastDB': 61.469,
#    'BrightnessDB': -2.38653,
#    'Setting': 250,
#    'MinimumDwellTime': 1e-07},
#   'Accessories': {'Number': 0},
#   'PrivateFei': {'BitShift': 0,
#    'DataBarSelected': 'HV mag HFW det tilt WD Label MicronBar',
#    'DataBarAvailable': 'HV srot frame dwell curr WD mag HFW x y tilt filter det DateTime mode zoom Label MicronBar',
#    'TimeOfCreation': '30.07.2013 11:11:11',
#    'DatabarHeight': 59}}}

# %% [markdown]
# Same story here, except the metadata seems to be even more limited. In any case, it's not the same format as the first few, meaning another map has to be made.

# %% [markdown]
# # SEM Image 2 - SliceImage - 001.tif
# This is an image from the PP13 SEM/FIB Tomography dataset.

# %%
f = hs.load(images[6])
SEMFIB = f.original_metadata.as_dictionary()

del SEMFIB['StripOffsets']
del SEMFIB['StripByteCounts']

SEMFIB
# Out:
# {'ImageWidth': 855,
#  'ImageLength': 770,
#  'BitsPerSample': 8,
#  'Compression': <COMPRESSION.NONE: 1>,
#  'PhotometricInterpretation': <PHOTOMETRIC.MINISBLACK: 1>,
#  'SamplesPerPixel': 1,
#  'RowsPerStrip': 1,
#  'PlanarConfiguration': <PLANARCONFIG.CONTIG: 1>,
#  'ExifTag': {'ImageUniqueID': 'F44788842094351134387C8FD66D0A9E'},
#  'FEI_SFEG': {},
#  'FEI_TITAN': '<?xml version="1.0"?>\r\n<Metadata xmlns:nil="http://schemas.fei.com/Metadata/v1/2013/07" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\r\n  <Core>\r\n    <Guid>1db1caee-750b-44f5-9269-45f0cb417d6b</Guid>\r\n    <UserID>user</UserID>\r\n    <ApplicationSoftware>xT</ApplicationSoftware>\r\n    <ApplicationSoftwareVersion>0</ApplicationSoftwareVersion>\r\n  </Core>\r\n  <Instrument>\r\n    <ControlSoftwareVersion>14.5.1.432</ControlSoftwareVersion>\r\n    <Manufacturer>FEI Company</Manufacturer>\r\n    <InstrumentClass>Helios G4 PFIB CXe</InstrumentClass>\r\n    <InstrumentID>9952707</InstrumentID>\r\n    <ComputerName>HPN105-MPC</ComputerName>\r\n  </Instrument>\r\n  <Acquisition>\r\n    <AcquisitionDatetime>2020-08-18T13:40:25</AcquisitionDatetime>\r\n    <BeamType>Electron</BeamType>\r\n    <ColumnType>Elstar</ColumnType>\r\n    <SourceType>FEG</SourceType>\r\n  </Acquisition>\r\n  <Optics>\r\n    <Apertures>\r\n      <Aperture>\r\n        <Number>1</Number>\r\n        <Diameter>4.53E-05</Diameter>\r\n      </Aperture>\r\n    </Apertures>\r\n    <GunTiltRaw>\r\n      <X>-0.00060763888888891915</X>\r\n      <Y>0.0022222222222222452</Y>\r\n    </GunTiltRaw>\r\n    <AccelerationVoltage>15000</AccelerationVoltage>\r\n    <SpotSize>1.0150978632147867E-08</SpotSize>\r\n    <BeamCurrent>1.6E-09</BeamCurrent>\r\n    <FullScanFieldOfView>\r\n      <X>0.0003072</X>\r\n      <Y>0.0002048</Y>\r\n    </FullScanFieldOfView>\r\n    <ScanFieldOfView>\r\n      <X>0.00017099999999999998</X>\r\n      <Y>0.000154</Y>\r\n    </ScanFieldOfView>\r\n    <WorkingDistance>0.0039780134891762037</WorkingDistance>\r\n    <EucentricWorkingDistance>0.004</EucentricWorkingDistance>\r\n    <BeamShift>\r\n      <X>1.0196359323083666E-08</X>\r\n      <Y>7.3771080439913645E-06</Y>\r\n    </BeamShift>\r\n    <SampleTiltCorrectionOn>false</SampleTiltCorrectionOn>\r\n    <SamplePreTiltAngle>0.97738438111682457</SamplePreTiltAngle>\r\n    <StigmatorRaw>\r\n      <X>0.015324313411080823</X>\r\n      <Y>0.0074750494060325627</Y>\r\n    </StigmatorRaw>\r\n    <OpticalMode>Field-Free</OpticalMode>\r\n    <CrossOverOn>false</CrossOverOn>\r\n  </Optics>\r\n  <StageSettings>\r\n    <StagePosition>\r\n      <X>0.00021884173314779088</X>\r\n      <Y>-0.0048261271080439917</Y>\r\n      <Z>0.0040406983441293592</Z>\r\n      <Rotation>0.64811935268567022</Rotation>\r\n      <Tilt>\r\n        <Alpha>1.0000626142450952</Alpha>\r\n        <Beta>0</Beta>\r\n      </Tilt>\r\n    </StagePosition>\r\n  </StageSettings>\r\n  <ScanSettings>\r\n    <DwellTime>3E-07</DwellTime>\r\n    <ScanSize>\r\n      <Width>1536</Width>\r\n      <Height>1024</Height>\r\n    </ScanSize>\r\n    <ScanArea>\r\n      <X>321</X>\r\n      <Y>124</Y>\r\n      <Width>855</Width>\r\n      <Height>770</Height>\r\n    </ScanArea>\r\n    <MainsLockOn>false</MainsLockOn>\r\n    <LineTime>0.0002787</LineTime>\r\n    <LineIntegrationCount>1</LineIntegrationCount>\r\n    <LineInterlacing>1</LineInterlacing>\r\n    <FrameTime>0.214599</FrameTime>\r\n    <ScanRotation>0</ScanRotation>\r\n  </ScanSettings>\r\n  <VacuumProperties>\r\n    <SamplePressure>0.00011999999999999981</SamplePressure>\r\n    <ElectronColumnPressure>2.6777319362736307E-05</ElectronColumnPressure>\r\n    <IonColumnPressure>0.00014396094666971847</IonColumnPressure>\r\n  </VacuumProperties>\r\n  <Detectors>\r\n    <ScanningDetector>\r\n      <DetectorName>ETD</DetectorName>\r\n      <DetectorType>ETD</DetectorType>\r\n      <Signal>SE</Signal>\r\n      <Gain>21.61749697609158</Gain>\r\n      <Offset>-2.8688569128668675</Offset>\r\n      <GridVoltage>600</GridVoltage>\r\n      <SuctionTubeVoltage>-10</SuctionTubeVoltage>\r\n      <ContrastNormalized>58.287250222912355</ContrastNormalized>\r\n      <BrightnessNormalized>38.04701008102267</BrightnessNormalized>\r\n    </ScanningDetector>\r\n  </Detectors>\r\n  <GasInjectionSystems>\r\n    <Gis>\r\n      <PortName>Port1</PortName>\r\n      <NeedleState>Retracted</NeedleState>\r\n ...
#  'fei_metadata': {'User': {'Date': '08/18/2020',
#    'Time': '01:40:25 PM',
#    'User': 'user',
#    'UserText': '',
#    'UserTextUnicode': ''},
#   'System': {'Type': 'DualBeam',
#    'Dnumber': 9952707,
#    'Software': '14.5.1.432',
#    'BuildNr': 432,
#    'Source': 'FEG',
#    'Column': 'Elstar',
#    'FinalLens': 'Elstar',
#    'Chamber': 'xT-SDB',
#    'Stage': '110 x 110',
#    'Pump': 'TMP',
#    'ESEM': 'no',
#    'Aperture': 'AVA',
#    'Scan': 'PIA 3.0',
#    'Acq': 'PIA 3.0',
#    'EucWD': 0.004,
#    'SystemType': 'Helios G4 PFIB CXe',
#    'DisplayWidth': 0.518,
#    'DisplayHeight': 0.324},
#   'Beam': {'HV': 15000,
#    'Spot': 1,
#    'StigmatorX': 0.0153243,
#    'StigmatorY': 0.00747505,
#    'BeamShiftX': 1.01964e-08,
#    'BeamShiftY': 7.37711e-06,
#    'ScanRotation': 0,
#    'ImageMode': 'Normal',
#    'FineStageBias': '',
#    'Beam': 'EBeam',
#    'Scan': 'EScan'},
#   'EBeam': {'Source': 'FEG',
#    'ColumnType': 'Elstar',
#    'FinalLens': 'Elstar',
#    'Acq': 'PIA 3.0',
#    'Aperture': 'AVA',
#    'ApertureDiameter': 4.53e-05,
#    'HV': 15000,
#    'HFW': 0.000171,
#    'VFW': 0.000154,
#    'WD': 0.00397801,
#    'BeamCurrent': 1.6e-09,
#    'TiltCorrectionIsOn': 'no',
#    'DynamicFocusIsOn': 'no',
#    'DynamicWDIsOn': '',
#    'ScanRotation': 0,
#    'LensMode': 'Field-Free',
#    'LensModeA': '',
#    'ATubeVoltage': '',
#    'UseCase': '',
#    'SemOpticalMode': '',
#    'ImageMode': 'Normal',
#    'SourceTiltX': -0.000607639,
#    'SourceTiltY': 0.00222222,
#    'StageX': 0.000218842,
#    'StageY': -0.00482613,
#    'StageZ': 0.0040407,
#    'StageR': 0.648119,
#    'StageTa': 1.00006,
#    'StageTb': 0,
#    'StigmatorX': 0.0153243,
#    'StigmatorY': 0.00747505,
#    'BeamShiftX': 1.01964e-08,
#    'BeamShiftY': 7.37711e-06,
#    'EucWD': 0.004,
#    'EmissionCurrent': '',
#    'TiltCorrectionAngle': 0.977384,
#    'PreTilt': '',
#    'WehneltBias': '',
#    'BeamMode': 'N-Beam',
#    'MagnificationCorrection': 'Off'},
#   'GIS': {'Number': 0},
#   'Scan': {'InternalScan': True,
#    'Dwelltime': 3e-07,
#    'PixelWidth': 2e-07,
#    'PixelHeight': 2e-07,
#    'HorFieldsize': 0.000171,
#    'VerFieldsize': 0.000154,
#    'Average': 0,
#    'Integrate': 0,
#    'FrameTime': 0.214599},
#   'EScan': {'Scan': 'PIA 3.0',
#    'InternalScan': True,
#    'Dwell': 3e-07,
#    'PixelWidth': 2e-07,
#    'PixelHeight': 2e-07,
#    'HorFieldsize': 0.000171,
#    'VerFieldsize': 0.000154,
#    'FrameTime': 0.214599,
#    'LineTime': 0.0002787,
#    'Mainslock': 'Off',
#    'LineIntegration': 1,
#    'ScanInterlacing': 1},
#   'Stage': {'StageX': 0.000218852,
#    'StageY': -0.00481875,
#    'StageZ': 0.0040407,
#    'StageR': 0.648119,
#    'StageT': 1.00006,
#    'StageTb': 0,
#    'SpecTilt': '',
#    'WorkingDistance': 0.00397801,
#    'ActiveStage': 'Bulk'},
#   'Image': {'DigitalContrast': 1,
#    'DigitalBrightness': 0,
#    'DigitalGamma': 1,
#    'Average': 0,
#    'Integrate': 0,
#    'ResolutionX': 1536,
#    'ResolutionY': 1024,
#    'DriftCorrected': 'Off',
#    'ZoomFactor': 1.0,
#    'ZoomPanX': '',
#    'ZoomPanY': '',
#    'MagCanvasRealWidth': '',
#    'MagnificationMode': '',
#    'ScreenMagCanvasRealWidth': '',
#    'ScreenMagnificationMode': '',
#    'PostProcessing': '',
#    'Transformation': ''},
#   'Vacuum': {'ChPressure': 0.00012,
#    'Gas': '',
#    'UserMode': 'High vacuum',
#    'Humidity': ''},
#   'Specimen': {'Temperature': '', 'SpecimenCurrent': -1.2788e-09},
#   'Detectors': {'Number': 1, 'Name': 'ETD', 'Mode': ''},
#   'ETD': {'Contrast': 58.2873,
#    'Brightness': 38.047,
#    'Mix': 100,
#    'Signal': '',
#    'Grid': 250,
#    'ContrastDB': 21.6175,
#    'BrightnessDB': -2.86886,
#    'Setting': 250,
#    'MinimumDwellTime': 1e-07},
#   'Accessories': {'Number': 0},
#   'PrivateFei': {'BitShift': 0,
#    'DataBarSelected': '',
#    'DataBarAvailable': '',
#    'TimeOfCreation': '18.08.2020 13:40:25',
#    'DatabarHeight': ''},
#   'HiResIllumination': {'BrightFieldIsOn': '',
#    'BrightFieldValue': '',
#    'DarkFieldIsOn': '',
#    'DarkFieldValue': ''},
#   'EasyLift': {'Rotation': 0},
#   'HotStageMEMS': {'HeatingCurrent': '',
#    'HeatingVoltage': '',
#    'TargetTemperature': '',
#    'ActualTemperature': '',
#    'HeatingPower': '',
#    'SampleBias': '',
#    'SampleResistance': ''}}}

# %% [markdown]
# Here is the same story. There is some additional metadata about the instrument hidden in a variable in XML format (as a string...), but it is not very useful data, it's missing units, etc. Meaning one has to either refer to some sort of external documentation in order to accurately map this metadata.

# %% [markdown]
# # TEM Images Metadata Extraction

# %% [markdown]
# As previously discussed, TEM image metadata needs to be extracted from accompanying files, as Hyperspy will only get the metadata from the TIFF image itself, and not the metadata that is "embedded" within it about the actual project. This is presumably by design, and simply because there isn't actually any project metadata embedded into the tiff's coming from TEM instruments. Luckily, the images are indeed usually (always?) accompanied by such files.

# %%
temMetadataDir = "/Users/elias/Desktop/MatWerk_Projects/testImages/Data for TEM-Schema"

def getTemMetadata(folder_path):
    mnetadataFileList = []
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path) and filename.lower().endswith('.emd'):
            mnetadataFileList.append(os.path.join(folder_path, filename))
    return mnetadataFileList

temMetadata = getTemMetadata(temMetadataDir)
temMetadata
# Out:
# ['/Users/elias/Desktop/MatWerk_Projects/testImages/Data for TEM-Schema/NEW-dimple-polish-pips 20230302 1127 Camera 3800 x Ceta.emd',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/Data for TEM-Schema/NEW-dimple-polish-pips 20230302 1244 STEM 5300 x HAADF.emd',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/Data for TEM-Schema/NEW-dimple-polish-pips 20230302 1143 STEM 7500 x HAADF.emd',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/Data for TEM-Schema/NEW-dimple-polish-pips 20230302 1146 STEM 5300 x HAADF.emd',
#  '/Users/elias/Desktop/MatWerk_Projects/testImages/Data for TEM-Schema/LaserCarbon_VS_Themis300-054 Camera 600 mm Ceta 20210421 1623.emd']

# %% [markdown]
# In this case, all the images are from the same instrument, so I only extracted the metadata from one to see how it behaves.

# %%
TEM = hs.load(temMetadata[0])
TEM.original_metadata.as_dictionary()
# Out:
# {'Core': {'MetadataDefinitionVersion': '7.9',
#   'MetadataSchemaVersion': 'v1/2013/07',
#   'guid': '00000000000000000000000000000000'},
#  'Instrument': {'ControlSoftwareVersion': '2.15.3',
#   'Manufacturer': 'FEI Company',
#   'InstrumentId': '3900',
#   'InstrumentClass': 'Titan',
#   'InstrumentModel': 'Themis',
#   'ComputerName': 'TITAN52339000'},
#  'Acquisition': {'AcquisitionStartDatetime': {'DateTime': '1677752847'},
#   'AcquisitionDatetime': {'DateTime': '1677752847'},
#   'BeamType': '',
#   'SourceType': 'XFEG'},
#  'Optics': {'GunLensSetting': '3',
#   'ExtractorVoltage': '4100',
#   'AccelerationVoltage': '300000',
#   'SpotIndex': '4',
#   'C1LensIntensity': '-0.27627953886985779',
#   'C2LensIntensity': '0.49731478095054626',
#   'C3LensIntensity': '0.28566396236419678',
#   'ObjectiveLensIntensity': '0.88349461555480957',
#   'IntermediateLensIntensity': '-0.016146063804626465',
#   'DiffractionLensIntensity': '0.32825303077697754',
#   'Projector1LensIntensity': '0.3777472972869873',
#   'Projector2LensIntensity': '0.87160289287567139',
#   'MiniCondenserLensIntensity': '0.97886407375335693',
#   'BeamConvergence': '-0.050124431132865993',
#   'ScreenCurrent': '0',
#   'LastMeasuredScreenCurrent': '3.6119270740333673e-09',
#   'Focus': '0',
#   'StemFocus': '-0.00052346950118185918',
#   'Defocus': '0',
#   'NominalMagnification': '3810.8389999999999',
#   'HighMagnificationMode': 'SA',
#   'Apertures': {'Aperture-0': {'Name': 'C1',
#     'Number': '1',
#     'MechanismType': 'Motorized',
#     'Type': 'Circular',
#     'Diameter': '0.002',
#     'Enabled': '0',
#     'PositionOffset': {'x': '0.0016697600000000002',
#      'y': '0.0011433600000000002'}},
#    'Aperture-1': {'Name': 'C2',
#     'Number': '2',
#     'MechanismType': 'Motorized',
#     'Type': 'Circular',
#     'Diameter': '0.00014999999999999999',
#     'Enabled': '0',
#     'PositionOffset': {'x': '0.0012774399999999999',
#      'y': '0.00058015999999999992'}},
#    'Aperture-2': {'Name': 'C3',
#     'Number': '3',
#     'MechanismType': 'Manual',
#     'Type': 'None'},
#    'Aperture-3': {'Name': 'OBJ',
#     'Number': '4',
#     'MechanismType': 'Motorized',
#     'Type': 'None',
#     'PositionOffset': {'x': '7.3759999999999999e-05',
#      'y': '-8.5439999999999995e-05'}},
#    'Aperture-4': {'Name': 'SA',
#     'Number': '5',
#     'MechanismType': 'Motorized',
#     'Type': 'None',
#     'PositionOffset': {'x': '9.2480000000000009e-05',
#      'y': '-0.00036128000000000001'}}},
#   'OperatingMode': '1',
#   'TemOperatingSubMode': 'BrightField',
#   'ProjectorMode': '2',
#   'EFTEMOn': 'false',
#   'ObjectiveLensMode': 'HM',
#   'IlluminationMode': 'Parallel',
#   'ProbeMode': '2',
#   'CameraLength': '0.10199999999999999'},
#  'EnergyFilter': {'EntranceApertureType': ''},
#  'Stage': {'Position': {'x': '6.8141265000000022e-05',
#    'y': '0.00037051213200000005',
#    'z': '-6.465228000000005e-05'},
#   'AlphaTilt': '0.00011022388514011876',
#   'BetaTilt': '0.34905844075679776',
#   'HolderType': 'FEI Double Tilt'},
#  'Scan': {'ScanSize': {'width': '0', 'height': '0'},
#   'MainsLockOn': 'false',
#   'FrameTime': '10.428428'},
#  'Vacuum': {'VacuumMode': 'Ready'},
#  'Detectors': {'Detector-0': {'DetectorName': 'BF',
#    'DetectorType': 'ScanningDetector',
#    'Inserted': 'false',
#    'Enabled': 'true',
#    'Gain': '44.071741500000208',
#    'Offset': '-5.4728999999999797',
#    'CollectionAngleRange': {'begin': '0', 'end': '0'}},
#   'Detector-1': {'DetectorName': 'BM-Ceta',
#    'DetectorType': 'ImagingDetector',
#    'ExposureMode': '',
#    'Binning': {'width': '2', 'height': '2'},
#    'ReadOutArea': {'left': '0', 'top': '0', 'right': '2048', 'bottom': '2048'},
#    'ExposureTime': '0.5',
#    'Shutters': {'Shutter-0': {'Position': 'PostSpecimen',
#      'Type': 'Electrostatic'}},
#    'DarkGainCorrectionType': '2'},
#   'Detector-2': {'DetectorName': 'DF2',
#    'DetectorType': 'ScanningDetector',
#    'Inserted': 'false',
#    'Enabled': 'true',
#    'Gain': '57.146716051967509',
#    'Offset': '-4.6574734773365343',
#    'CollectionAngleRange': {'begin': '0', 'end': '0'}},
#   'Detector-3': {'DetectorName': 'DF4',
#    'DetectorType': 'ScanningDetector',
#    'Inserted': 'false',
#    'Enabled': 'true',
#    'Gain': '16.7970705',
#    'Offset': '-15.396040283203126',
#    'CollectionAngleRange': {'begin': '0', 'end': '0'}},
#   'Detector-4': {'DetectorName': 'HAADF',
#    'DetectorType': 'ScanningDetector',
#    'Inserted': 'false',
#    'Enabled': 'true',
#    'Gain': '40.142253007158622',
#    'Offset': '-1.9878327758789016',
#    'CollectionAngleRange': {'begin': '0', 'end': '0'}},
#   'Detector-5': {'DetectorName': 'SuperXG21',
#    'DetectorType': 'AnalyticalDetector',
#    'Inserted': 'true',
#    'Enabled': 'false',
#    'ElevationAngle': '0.31415926999999999',
#    'AzimuthAngle': '0.78539816339744828',
#    'CollectionAngle': '0.17499999999999999',
#    'Dispersion': '5',
#    'PulseProcessTime': '3.0000000000000001e-06',
#    'AnalyticalDetectorShutterState': '4',
#    'OffsetEnergy': '-250',
#    'ElectronicsNoise': '25.289999999999999',
#    'BeginEnergy': '120'},
#   'Detector-6': {'DetectorName': 'SuperXG22',
#    'DetectorType': 'AnalyticalDetector',
#    'Inserted': 'true',
#    'Enabled': 'false',
#    'ElevationAngle': '0.31415926999999999',
#    'AzimuthAngle': '2.3561944901923448',
#    'CollectionAngle': '0.17499999999999999',
#    'Dispersion': '5',
#    'PulseProcessTime': '3.0000000000000001e-06',
#    'AnalyticalDetectorShutterState': '4',
#    'OffsetEnergy': '-250',
#    'ElectronicsNoise': '31.149999999999999',
#    'BeginEnergy': '120'},
#   'Detector-7': {'DetectorName': 'SuperXG23',
#    'DetectorType': 'AnalyticalDetector',
#    'Inserted': 'true',
#    'Enabled': 'false',
#    'ElevationAngle': '0.31415926999999999',
#    'AzimuthAngle': '3.9269908169872414',
#    'CollectionAngle': '0.17499999999999999',
#    'Dispersion': '5',
#    'PulseProcessTime': '3.0000000000000001e-06',
#    'AnalyticalDetectorShutterState': '4',
#    'OffsetEnergy': '-250',
#    'ElectronicsNoise': '40.359999999999999',
#    'BeginEnergy': '120'},
#   'Detector-8': {'DetectorName': 'SuperXG24',
#    'DetectorType': 'AnalyticalDetector',
#    'Inserted': 'true',
#    'Enabled': 'false',
#    'ElevationAngle': '0.31415926999999999',
#    'AzimuthAngle': '5.497787143782138',
#    'CollectionAngle': '0.17499999999999999',
#    'Dispersion': '5',
#    'PulseProcessTime': '3.0000000000000001e-06',
#    'AnalyticalDetectorShutterState': '4',
#    'OffsetEnergy': '-250',
#    'ElectronicsNoise': '35.5',
#    'BeginEnergy': '120'}},
#  'BinaryResult': {'AcquisitionUnit': 'CameraImage',
#   'CompositionType': '',
#   'ImageSize': {'width': '4096', 'height': '4096'},
#   'DetectorIndex': '1',
#   'Detector': 'BM-Ceta',
#   'PixelSize': {'width': '5.6034020176028184e-09',
#    'height': '5.6034020176028184e-09'},
#   'PixelUnitX': 'm',
#   'PixelUnitY': 'm',
#   'Offset': {'x': '-5.737883666025286e-06', 'y': '-5.737883666025286e-06'},
#   'Encoding': 'Signed',
#   'BitsPerPixel': '32'},
#  'Sample': '',
#  'GasInjectionSystems': '',
#  'CustomProperties': {'Aperture[C1].Name': {'type': 'string', 'value': '2000'},
#   'Aperture[C2].Name': {'type': 'string', 'value': '150'},
#   'Aperture[C3].Name': {'type': 'string', 'value': 'None'},
#   'Aperture[OBJ].Name': {'type': 'string', 'value': 'None'},
#   'Aperture[SA].Name': {'type': 'string', 'value': 'None'},
#   'Detectors[BM-Ceta].CombinedSubFrames': {'type': 'long', 'value': '1'},
#   'Detectors[BM-Ceta].DigitalGain': {'type': 'double', 'value': '1'},
#   'Detectors[BM-Ceta].FrameID': {'type': 'long', 'value': '0'},
#   'Detectors[BM-Ceta].MaxPossiblePixelValue': {'type': 'long',
#    'value': '38492'},
#   'Detectors[BM-Ceta].SaturationPoint': {'type': 'long', 'value': '21344'},
#   'Detectors[BM-Ceta].TimeStamp': {'type': 'int64',
#    'value': '1677752848992578'},
#   'Detectors[BM-Ceta].TransferOK': {'type': 'bool', 'value': '1'},
#   'Detectors[SuperXG21].BilatThresholdHi': {'type': 'double',
#    'value': '0.0033087514768000001'},
#   'Detectors[SuperXG21].IncidentAngle': {'type': 'double',
#    'value': '0.094596840000000001'},
#   'Detectors[SuperXG21].KMax': {'type': 'double', 'value': '180'},
#   'Detectors[SuperXG21].KMin': {'type': 'double', 'value': '120'},
#   'Detectors[SuperXG21].PulsePairResolutionTime': {'type': 'double',
#    'value': '4.9999999999999998e-07'},
#   'Detectors[SuperXG21].SpectrumBeginEnergy': {'type': 'long', 'value': '120'},
#   'Detectors[SuperXG22].BilatThresholdHi': {'type': 'double',
#    'value': '0.00330858542536'},
#   'Detectors[SuperXG22].IncidentAngle': {'type': 'double',
#    'value': '0.094596840000000001'},
#   'Detectors[SuperXG22].KMax': {'type': 'double', 'value': '180'},
#   'Detectors[SuperXG22].KMin': {'type': 'double', 'value': '120'},
#   'Detectors[SuperXG22].PulsePairResolutionTime': {'type': 'double',
#    'value': '4.9999999999999998e-07'},
#   'Detectors[SuperXG22].SpectrumBeginEnergy': {'type': 'long', 'value': '120'},
#   'Detectors[SuperXG23].BilatThresholdHi': {'type': 'double',
#    'value': '0.0033608542496499998'},
#   'Detectors[SuperXG23].IncidentAngle': {'type': 'double',
#    'value': '0.094596840000000001'},
#   'Detectors[SuperXG23].KMax': {'type': 'double', 'value': '180'},
#   'Detectors[SuperXG23].KMin': {'type': 'double', 'value': '120'},
#   'Detectors[SuperXG23].PulsePairResolutionTime': {'type': 'double',
#    'value': '4.9999999999999998e-07'},
#   'Detectors[SuperXG23].SpectrumBeginEnergy': {'type': 'long', 'value': '120'},
#   'Detectors[SuperXG24].BilatThresholdHi': {'type': 'double',
#    'value': '0.0035366405453899998'},
#   'Detectors[SuperXG24].IncidentAngle': {'type': 'double',
#    'value': '0.094596840000000001'},
#   'Detectors[SuperXG24].KMax': {'type': 'double', 'value': '180'},
#   'Detectors[SuperXG24].KMin': {'type': 'double', 'value': '120'},
#   'Detectors[SuperXG24].PulsePairResolutionTime': {'type': 'double',
#    'value': '4.9999999999999998e-07'},
#   'Detectors[SuperXG24].SpectrumBeginEnergy': {'type': 'long', 'value': '120'},
#   'RecodeFactor': {'type': 'double', 'value': '0.25'},
#   'StemMagnification': {'type': 'bool', 'value': '0'}},
#  'Operations': {'CameraInputOperation': {'97d3ebdce3344f8a9afbf34350d32361': {'dataPath': '/Data/Image/c771bf2b502e4234abfafcf57656eb87',
#     'cameraName': 'Ceta',
#     'outputs': ''}},
#   'Operations': {'operations': [{'CameraInputOperation': '/Operations/CameraInputOperation/97d3ebdce3344f8a9afbf34350d32361'}]}},
#  'DetectorMetadata': None}

# %% [markdown]
# As no map file exists for a TEM Schema (which is still in the works, awaiting on feedback from INT colleagues), it is not yet verifiable if everything required by the schema is extracted. However, it can be immediately noted that the metadata read from the these `.emd` files is much more complete than that from the TIFFs. If such a file format can be provided by all instruments, it's likely that hyperspy reads it all the same, regardless of which instrument it came from. There are also additional metadata export formats beyond simple tiffs which are meant to accompany the research images generated, and therefore can be "linked" to the image in some way. These also provide us with more options and a better way to standardize the metadata extraction process by requiring a metadata file which is automatically generated by most, if not all, instruments (if possible of course). Currently awaiting feedback from the SEM/TEM experts on whether or not these metadata files may be generated along with the TIFFs on all instruments.

# %% [markdown]
# # Conclusion

# %% [markdown]
# While Hyperspy is not the end-all solution that we were hoping it would be, it does provide a significant boost and efficiency to the metadata extraction. I would indeed recommend that it be implemented, but it needs to be discussed with Reetu and Rossella in how exactly this could be done. We need to also wait on information from INT about whether or not these file formats can be easily provided, and whether this is even an acceptable solution needs to be discussed.
#
# Hyperspy does pave the way to a "universal" extractor, but it's not the magic tool we were hoping that it would turn out to be. Its extraction algorithm is eons ahead of my manual extraction, but more research is needed to understand exactly how it is completing this extraction under the hood and why some tiffs are treated differently and not extracted under the same schema as others. It appears that it has different structures/schemas for various metadata formats which it receives, but I'm still looking into it. The next steps would be to reformat the codebase of the existing metadata mappings to be more in line with the polished and published tools (i.e. Nicolas' DICOM mapper), and then look into how Hyperspy fits into this.
